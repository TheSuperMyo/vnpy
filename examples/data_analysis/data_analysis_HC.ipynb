# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="HC9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 1/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-09 12:29:30.355487	开始加载历史数据
# 2019-12-09 12:29:55.591175	历史数据加载完成，数据量：414600

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-09 12:30:14.507129	第一步:画出行情图，检查数据断点
# 2019-12-09 12:30:25.751790	第二步：随机性检验：非纯随机性
# 2019-12-09 12:30:25.751790	白噪声检验结果:(array([414595.86917175]), array([0.]))
#
# 2019-12-09 12:33:01.404585	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:33:01.410591	ADF检验结果：(-1.1691838082362134, 0.6867096413986336, 90, 414509, {'1%': -3.430365776112211, '5%': -2.8615469728527363, '10%': -2.5667737113953537}, 2086500.4721011245)
#
# 2019-12-09 12:33:01.410591	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:33:16.561436	第五步：相对波动率分析
# 2019-12-09 12:33:17.407247	样本平均数：2.7826, 中位数: 2.6964
# 2019-12-09 12:33:17.425263	偏度为：0.8498，属于分布偏左；峰度为：1.6487，属于分布陡峭
#
# 2019-12-09 12:33:17.426264	第六步：变化率分析
# 2019-12-09 12:33:19.137027	样本平均数：0.0002, 中位数: 0.0
# 2019-12-09 12:33:19.156044	偏度为：398.0603，属于分布偏左；峰度为：218683.8912，属于分布陡峭
#
# 2019-12-09 12:33:19.157045	ER位移路程比
# 2019-12-09 12:33:20.083888	样本平均数：0.2159, 中位数: 0.1765
# 2019-12-09 12:33:20.101411	偏度为：1.671，属于分布偏左；峰度为：4.0538，属于分布陡峭
#
# 2019-12-09 12:33:20.102412	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-09 12:34:27.999932	------------------------------------------------
# 2019-12-09 12:34:28.000932	合成5min周期K先并开始数据分析
# 2019-12-09 12:34:30.099333	第一步:画出行情图，检查数据断点
# 2019-12-09 12:34:30.991253	第二步：随机性检验：非纯随机性
# 2019-12-09 12:34:30.991253	白噪声检验结果:(array([82916.45266284]), array([0.]))
#
# 2019-12-09 12:34:41.724917	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:34:41.724917	ADF检验结果：(-1.180938862836464, 0.6817411201041021, 16, 82903, {'1%': -3.430428881373281, '5%': -2.861574864251928, '10%': -2.566788557035125}, 543278.2037185273)
#
# 2019-12-09 12:34:41.724917	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:34:42.762216	第五步：相对波动率分析
# 2019-12-09 12:34:43.354780	样本平均数：7.0437, 中位数: 6.8168
# 2019-12-09 12:34:43.356781	偏度为：0.7115，属于分布偏左；峰度为：0.4796，属于分布陡峭
#
# 2019-12-09 12:34:43.356781	第六步：变化率分析
# 2019-12-09 12:34:44.822677	样本平均数：0.001, 中位数: 0.0
# 2019-12-09 12:34:44.824774	偏度为：185.4872，属于分布偏左；峰度为：46220.7337，属于分布陡峭
#
# 2019-12-09 12:34:44.824774	ER位移路程比
# 2019-12-09 12:34:45.274158	样本平均数：0.227, 中位数: 0.2
# 2019-12-09 12:34:45.276533	偏度为：0.8774，属于分布偏左；峰度为：0.539，属于分布陡峭
#
# 2019-12-09 12:34:45.276533	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:34:45.282540	------------------------------------------------
# 2019-12-09 12:34:45.282540	合成15min周期K先并开始数据分析
# 2019-12-09 12:34:46.011813	第一步:画出行情图，检查数据断点
# 2019-12-09 12:34:46.298604	第二步：随机性检验：非纯随机性
# 2019-12-09 12:34:46.299604	白噪声检验结果:(array([27636.51287962]), array([0.]))
#
# 2019-12-09 12:34:48.117184	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:34:48.117184	ADF检验结果：(-1.1760977954412706, 0.6837924109174617, 47, 27592, {'1%': -3.4305870219074035, '5%': -2.8616447569405215, '10%': -2.5668257589810404}, 211054.66140918975)
#
# 2019-12-09 12:34:48.118185	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:34:48.503649	第五步：相对波动率分析
# 2019-12-09 12:34:49.057324	样本平均数：12.9242, 中位数: 12.4449
# 2019-12-09 12:34:49.058324	偏度为：0.6543，属于分布偏左；峰度为：0.1039，属于分布陡峭
#
# 2019-12-09 12:34:49.058324	第六步：变化率分析
# 2019-12-09 12:34:50.490964	样本平均数：0.0031, 中位数: 0.0
# 2019-12-09 12:34:50.491967	偏度为：107.5203，属于分布偏左；峰度为：15489.2188，属于分布陡峭
#
# 2019-12-09 12:34:50.491967	ER位移路程比
# 2019-12-09 12:34:50.762090	样本平均数：0.245, 中位数: 0.2121
# 2019-12-09 12:34:50.763090	偏度为：0.8377，属于分布偏左；峰度为：0.4076，属于分布陡峭
#
# 2019-12-09 12:34:50.764091	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:34:50.767095	------------------------------------------------
# 2019-12-09 12:34:50.767095	合成30min周期K先并开始数据分析
# 2019-12-09 12:34:51.160453	第一步:画出行情图，检查数据断点
# 2019-12-09 12:34:51.373157	第二步：随机性检验：非纯随机性
# 2019-12-09 12:34:51.373157	白噪声检验结果:(array([14400.38697674]), array([0.]))
#
# 2019-12-09 12:34:52.063789	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:34:52.063789	ADF检验结果：(-1.165169024794983, 0.6883968624700414, 34, 14369, {'1%': -3.430805179107388, '5%': -2.8617411688256698, '10%': -2.566877077422945}, 119489.96996368986)
#
# 2019-12-09 12:34:52.063789	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:34:52.392104	第五步：相对波动率分析
# 2019-12-09 12:34:52.935225	样本平均数：18.3208, 中位数: 17.76
# 2019-12-09 12:34:52.936226	偏度为：0.6059，属于分布偏左；峰度为：-0.1108，属于分布平缓
#
# 2019-12-09 12:34:52.936226	第六步：变化率分析
# 2019-12-09 12:34:54.358987	样本平均数：0.0059, 中位数: 0.0
# 2019-12-09 12:34:54.359987	偏度为：77.2717，属于分布偏左；峰度为：8024.1251，属于分布陡峭
#
# 2019-12-09 12:34:54.359987	ER位移路程比
# 2019-12-09 12:34:54.594711	样本平均数：0.2516, 中位数: 0.2197
# 2019-12-09 12:34:54.595712	偏度为：0.8093，属于分布偏左；峰度为：0.3661，属于分布陡峭
#
# 2019-12-09 12:34:54.595712	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:34:54.597714	------------------------------------------------
# 2019-12-09 12:34:54.597714	合成60min周期K先并开始数据分析
# 2019-12-09 12:34:54.767870	第一步:画出行情图，检查数据断点
# 2019-12-09 12:34:54.944963	第二步：随机性检验：非纯随机性
# 2019-12-09 12:34:54.944963	白噪声检验结果:(array([8366.30618681]), array([0.]))
#
# 2019-12-09 12:34:55.246236	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:34:55.246236	ADF检验结果：(-1.1549297294675023, 0.6926773313351685, 17, 8352, {'1%': -3.431133202940222, '5%': -2.8618861215898526, '10%': -2.5669542356712918}, 73901.19257990299)
#
# 2019-12-09 12:34:55.247237	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:34:55.603574	第五步：相对波动率分析
# 2019-12-09 12:34:56.138100	样本平均数：24.538, 中位数: 23.9525
# 2019-12-09 12:34:56.138100	偏度为：0.5497，属于分布偏左；峰度为：-0.3404，属于分布平缓
#
# 2019-12-09 12:34:56.139100	第六步：变化率分析
# 2019-12-09 12:34:57.535798	样本平均数：0.0101, 中位数: 0.0
# 2019-12-09 12:34:57.536799	偏度为：58.6612，属于分布偏左；峰度为：4639.7724，属于分布陡峭
#
# 2019-12-09 12:34:57.536799	ER位移路程比
# 2019-12-09 12:34:57.739984	样本平均数：0.2548, 中位数: 0.2256
# 2019-12-09 12:34:57.740984	偏度为：0.7796，属于分布偏左；峰度为：0.3367，属于分布陡峭
#
# 2019-12-09 12:34:57.740984	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
