# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="CU9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.5/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 21:06:38.285434	开始加载历史数据
# 2019-12-08 21:07:13.955345	历史数据加载完成，数据量：559140

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-08 21:08:48.842554	第一步:画出行情图，检查数据断点
# 2019-12-08 21:09:11.420948	第二步：随机性检验：非纯随机性
# 2019-12-08 21:09:11.421949	白噪声检验结果:(array([559131.23697363]), array([0.]))
#
# 2019-12-08 21:13:45.901762	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 21:13:45.935793	ADF检验结果：(-1.7042744406590877, 0.4289115130497938, 91, 559048, {'1%': -3.4303616972603894, '5%': -2.861545170052614, '10%': -2.5667727518299404}, 5157407.696071091)
#
# 2019-12-08 21:13:45.936795	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 21:14:14.291409	第五步：相对波动率分析
# 2019-12-08 21:14:15.318753	样本平均数：25.116, 中位数: 22.6186
# 2019-12-08 21:14:15.344775	偏度为：3.0037，属于分布偏左；峰度为：25.3262，属于分布陡峭
#
# 2019-12-08 21:14:15.344775	第六步：变化率分析
# 2019-12-08 21:14:17.177033	样本平均数：0.0001, 中位数: 0.0
# 2019-12-08 21:14:17.203055	偏度为：592.5523，属于分布偏左；峰度为：410044.6706，属于分布陡峭
#
# 2019-12-08 21:14:17.203055	ER位移路程比
# 2019-12-08 21:14:18.317691	样本平均数：0.1985, 中位数: 0.1667
# 2019-12-08 21:14:18.343714	偏度为：0.9611，属于分布偏左；峰度为：0.7584，属于分布陡峭
#
# 2019-12-08 21:14:18.343714	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-08 22:27:51.800528	------------------------------------------------
# 2019-12-08 22:27:51.801529	合成5min周期K先并开始数据分析
# 2019-12-08 22:27:54.089048	第一步:画出行情图，检查数据断点
# 2019-12-08 22:27:55.559925	第二步：随机性检验：非纯随机性
# 2019-12-08 22:27:55.559925	白噪声检验结果:(array([111820.25063183]), array([0.]))
#
# 2019-12-08 22:28:13.851219	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 22:28:13.852220	ADF检验结果：(-1.6979250292929329, 0.432181880077147, 17, 111810, {'1%': -3.430408487166944, '5%': -2.8615658504415618, '10%': -2.5667837592802343}, 1199970.9130575866)
#
# 2019-12-08 22:28:13.852220	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 22:28:15.413640	第五步：相对波动率分析
# 2019-12-08 22:28:16.015187	样本平均数：60.4516, 中位数: 55.4561
# 2019-12-08 22:28:16.017189	偏度为：2.8979，属于分布偏左；峰度为：21.6286，属于分布陡峭
#
# 2019-12-08 22:28:16.017189	第六步：变化率分析
# 2019-12-08 22:28:17.508544	样本平均数：0.0008, 中位数: 0.0
# 2019-12-08 22:28:17.512549	偏度为：270.7637，属于分布偏左；峰度为：84400.7251，属于分布陡峭
#
# 2019-12-08 22:28:17.513549	ER位移路程比
# 2019-12-08 22:28:18.048035	样本平均数：0.2335, 中位数: 0.2
# 2019-12-08 22:28:18.053040	偏度为：0.7772，属于分布偏左；峰度为：0.1314，属于分布陡峭
#
# 2019-12-08 22:28:18.053040	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 22:28:18.060046	------------------------------------------------
# 2019-12-08 22:28:18.060046	合成15min周期K先并开始数据分析
# 2019-12-08 22:28:18.857771	第一步:画出行情图，检查数据断点
# 2019-12-08 22:28:19.241119	第二步：随机性检验：非纯随机性
# 2019-12-08 22:28:19.242120	白噪声检验结果:(array([37268.30198537]), array([0.]))
#
# 2019-12-08 22:28:22.278882	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 22:28:22.278882	ADF检验结果：(-1.5952396717873831, 0.48598432908517253, 46, 37229, {'1%': -3.4305256628150733, '5%': -2.8616176387697076, '10%': -2.566811324651533}, 440319.9030319951)
#
# 2019-12-08 22:28:22.278882	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 22:28:22.791348	第五步：相对波动率分析
# 2019-12-08 22:28:23.375880	样本平均数：109.1939, 中位数: 100.8406
# 2019-12-08 22:28:23.376880	偏度为：2.7028，属于分布偏左；峰度为：16.0622，属于分布陡峭
#
# 2019-12-08 22:28:23.376880	第六步：变化率分析
# 2019-12-08 22:28:24.843214	样本平均数：0.0023, 中位数: 0.0
# 2019-12-08 22:28:24.844214	偏度为：156.5096，属于分布偏左；峰度为：28179.993，属于分布陡峭
#
# 2019-12-08 22:28:24.845216	ER位移路程比
# 2019-12-08 22:28:25.185525	样本平均数：0.247, 中位数: 0.2152
# 2019-12-08 22:28:25.186526	偏度为：0.7749，属于分布偏左；峰度为：0.0902，属于分布陡峭
#
# 2019-12-08 22:28:25.186526	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 22:28:25.190530	------------------------------------------------
# 2019-12-08 22:28:25.190530	合成30min周期K先并开始数据分析
# 2019-12-08 22:28:25.621922	第一步:画出行情图，检查数据断点
# 2019-12-08 22:28:25.877153	第二步：随机性检验：非纯随机性
# 2019-12-08 22:28:25.877153	白噪声检验结果:(array([19240.37264237]), array([0.]))
#
# 2019-12-08 22:28:26.984160	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 22:28:26.984160	ADF检验结果：(-1.6684841282744303, 0.4474191487265808, 33, 19214, {'1%': -3.430690385856613, '5%': -2.861690438246519, '10%': -2.566850074226891}, 239549.16277563057)
#
# 2019-12-08 22:28:26.984160	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 22:28:27.338483	第五步：相对波动率分析
# 2019-12-08 22:28:27.900994	样本平均数：155.5355, 中位数: 144.0188
# 2019-12-08 22:28:27.901995	偏度为：2.5619，属于分布偏左；峰度为：13.638，属于分布陡峭
#
# 2019-12-08 22:28:27.901995	第六步：变化率分析
# 2019-12-08 22:28:29.356317	样本平均数：0.0044, 中位数: 0.0
# 2019-12-08 22:28:29.357318	偏度为：112.8269，属于分布偏左；峰度为：14611.6861，属于分布陡峭
#
# 2019-12-08 22:28:29.357318	ER位移路程比
# 2019-12-08 22:28:29.626563	样本平均数：0.245, 中位数: 0.2121
# 2019-12-08 22:28:29.627564	偏度为：0.8192，属于分布偏左；峰度为：0.2407，属于分布陡峭
#
# 2019-12-08 22:28:29.627564	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 22:28:29.630567	------------------------------------------------
# 2019-12-08 22:28:29.630567	合成60min周期K先并开始数据分析
# 2019-12-08 22:28:29.824743	第一步:画出行情图，检查数据断点
# 2019-12-08 22:28:30.017919	第二步：随机性检验：非纯随机性
# 2019-12-08 22:28:30.018920	白噪声检验结果:(array([10836.24196874]), array([0.]))
#
# 2019-12-08 22:28:30.586435	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 22:28:30.587436	ADF检验结果：(-1.6698159122652096, 0.44672745842991535, 17, 10826, {'1%': -3.4309541798636847, '5%': -2.861807013803542, '10%': -2.566912126313315}, 141132.90994346509)
#
# 2019-12-08 22:28:30.587436	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 22:28:30.894716	第五步：相对波动率分析
# 2019-12-08 22:28:31.447219	样本平均数：211.2659, 中位数: 196.6776
# 2019-12-08 22:28:31.447219	偏度为：2.3203，属于分布偏左；峰度为：10.3856，属于分布陡峭
#
# 2019-12-08 22:28:31.448219	第六步：变化率分析
# 2019-12-08 22:28:32.869512	样本平均数：0.0078, 中位数: 0.0
# 2019-12-08 22:28:32.870513	偏度为：84.4656，属于分布偏左；峰度为：8203.5418，属于分布陡峭
#
# 2019-12-08 22:28:32.870513	ER位移路程比
# 2019-12-08 22:28:33.097719	样本平均数：0.2386, 中位数: 0.2068
# 2019-12-08 22:28:33.098721	偏度为：0.8571，属于分布偏左；峰度为：0.4228，属于分布陡峭
#
# 2019-12-08 22:28:33.098721	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
