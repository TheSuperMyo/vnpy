# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="BU9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 1/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-09 12:44:27.444535	开始加载历史数据
# 2019-12-09 12:44:52.937686	历史数据加载完成，数据量：426300

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-09 12:45:45.571126	第一步:画出行情图，检查数据断点
# 2019-12-09 12:45:58.526512	第二步：随机性检验：非纯随机性
# 2019-12-09 12:45:58.526512	白噪声检验结果:(array([426287.24586242]), array([0.]))
#
# 2019-12-09 12:48:40.382938	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:48:40.398953	ADF检验结果：(-2.10977644825621, 0.24060165784947118, 88, 426211, {'1%': -3.430365342962487, '5%': -2.8615467814062385, '10%': -2.566773609495275}, 2317269.043428636)
#
# 2019-12-09 12:48:40.398953	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:48:56.445600	第五步：相对波动率分析
# 2019-12-09 12:48:57.323400	样本平均数：2.8895, 中位数: 2.8897
# 2019-12-09 12:48:57.340417	偏度为：1.1628，属于分布偏左；峰度为：10.4894，属于分布陡峭
#
# 2019-12-09 12:48:57.341418	第六步：变化率分析
# 2019-12-09 12:48:59.093009	样本平均数：0.0, 中位数: 0.0
# 2019-12-09 12:48:59.110026	偏度为：290.677，属于分布偏左；峰度为：144719.8098，属于分布陡峭
#
# 2019-12-09 12:48:59.110026	ER位移路程比
# 2019-12-09 12:48:59.957513	样本平均数：0.199, 中位数: 0.1429
# 2019-12-09 12:48:59.977060	偏度为：2.0506，属于分布偏左；峰度为：5.5818，属于分布陡峭
#
# 2019-12-09 12:48:59.977060	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-09 12:52:28.780183	------------------------------------------------
# 2019-12-09 12:52:28.780183	合成5min周期K先并开始数据分析
# 2019-12-09 12:52:30.878333	第一步:画出行情图，检查数据断点
# 2019-12-09 12:52:31.815235	第二步：随机性检验：非纯随机性
# 2019-12-09 12:52:31.816232	白噪声检验结果:(array([85249.69473092]), array([0.]))
#
# 2019-12-09 12:52:43.013359	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:52:43.013359	ADF检验结果：(-2.108900908663293, 0.24095059707628286, 59, 85200, {'1%': -3.430426754659973, '5%': -2.8615739242922578, '10%': -2.566788056724994}, 579159.0615254794)
#
# 2019-12-09 12:52:43.013359	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:52:44.024341	第五步：相对波动率分析
# 2019-12-09 12:52:44.622310	样本平均数：6.5851, 中位数: 6.284
# 2019-12-09 12:52:44.623311	偏度为：1.0807，属于分布偏左；峰度为：4.5525，属于分布陡峭
#
# 2019-12-09 12:52:44.623311	第六步：变化率分析
# 2019-12-09 12:52:46.082431	样本平均数：0.0003, 中位数: 0.0
# 2019-12-09 12:52:46.084433	偏度为：152.3406，属于分布偏左；峰度为：35704.8148，属于分布陡峭
#
# 2019-12-09 12:52:46.085434	ER位移路程比
# 2019-12-09 12:52:46.521832	样本平均数：0.2285, 中位数: 0.1852
# 2019-12-09 12:52:46.523834	偏度为：1.4236，属于分布偏左；峰度为：2.7754，属于分布陡峭
#
# 2019-12-09 12:52:46.523834	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:52:46.528841	------------------------------------------------
# 2019-12-09 12:52:46.529841	合成15min周期K先并开始数据分析
# 2019-12-09 12:52:47.292800	第一步:画出行情图，检查数据断点
# 2019-12-09 12:52:47.591577	第二步：随机性检验：非纯随机性
# 2019-12-09 12:52:47.592616	白噪声检验结果:(array([28411.01770272]), array([0.]))
#
# 2019-12-09 12:52:49.536364	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:52:49.536364	ADF检验结果：(-2.101511276929945, 0.24390734385581103, 42, 28377, {'1%': -3.430580464518238, '5%': -2.861641858873562, '10%': -2.566824216407253}, 219428.03752790682)
#
# 2019-12-09 12:52:49.536364	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:52:49.939307	第五步：相对波动率分析
# 2019-12-09 12:52:50.481395	样本平均数：11.9281, 中位数: 11.2478
# 2019-12-09 12:52:50.482370	偏度为：1.1338，属于分布偏左；峰度为：3.6719，属于分布陡峭
#
# 2019-12-09 12:52:50.482370	第六步：变化率分析
# 2019-12-09 12:52:51.902647	样本平均数：0.0009, 中位数: 0.0
# 2019-12-09 12:52:51.903648	偏度为：93.6289，属于分布偏左；峰度为：12926.8593，属于分布陡峭
#
# 2019-12-09 12:52:51.903648	ER位移路程比
# 2019-12-09 12:52:52.178408	样本平均数：0.2447, 中位数: 0.2045
# 2019-12-09 12:52:52.179409	偏度为：0.9791，属于分布偏左；峰度为：0.802，属于分布陡峭
#
# 2019-12-09 12:52:52.179409	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:52:52.182412	------------------------------------------------
# 2019-12-09 12:52:52.182412	合成30min周期K先并开始数据分析
# 2019-12-09 12:52:52.591787	第一步:画出行情图，检查数据断点
# 2019-12-09 12:52:52.809488	第二步：随机性检验：非纯随机性
# 2019-12-09 12:52:52.809488	白噪声检验结果:(array([14811.39781129]), array([0.]))
#
# 2019-12-09 12:52:53.511127	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:52:53.512128	ADF检验结果：(-2.093432952394545, 0.2471634305922824, 41, 14778, {'1%': -3.430792579255743, '5%': -2.8617356006692596, '10%': -2.566874113552568}, 123447.64638888226)
#
# 2019-12-09 12:52:53.512128	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:52:53.818406	第五步：相对波动率分析
# 2019-12-09 12:52:54.358912	样本平均数：16.9619, 中位数: 16.0627
# 2019-12-09 12:52:54.358912	偏度为：1.1159，属于分布偏左；峰度为：3.241，属于分布陡峭
#
# 2019-12-09 12:52:54.358912	第六步：变化率分析
# 2019-12-09 12:52:55.770887	样本平均数：0.0018, 中位数: 0.0
# 2019-12-09 12:52:55.771397	偏度为：68.02，属于分布偏左；峰度为：6794.277，属于分布陡峭
#
# 2019-12-09 12:52:55.771397	ER位移路程比
# 2019-12-09 12:52:56.001602	样本平均数：0.2534, 中位数: 0.2195
# 2019-12-09 12:52:56.003604	偏度为：0.8404，属于分布偏左；峰度为：0.3407，属于分布陡峭
#
# 2019-12-09 12:52:56.003604	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:52:56.005606	------------------------------------------------
# 2019-12-09 12:52:56.005606	合成60min周期K先并开始数据分析
# 2019-12-09 12:52:56.184809	第一步:画出行情图，检查数据断点
# 2019-12-09 12:52:56.361479	第二步：随机性检验：非纯随机性
# 2019-12-09 12:52:56.362480	白噪声检验结果:(array([8622.33338289]), array([0.]))
#
# 2019-12-09 12:52:56.660796	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:52:56.660796	ADF检验结果：(-2.025522639844417, 0.2754956323117399, 22, 8607, {'1%': -3.4311099920233863, '5%': -2.8618758652800826, '10%': -2.566948776154556}, 75807.12919343653)
#
# 2019-12-09 12:52:56.661796	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:52:57.023883	第五步：相对波动率分析
# 2019-12-09 12:52:57.564376	样本平均数：22.7349, 中位数: 21.5919
# 2019-12-09 12:52:57.565376	偏度为：0.7679，属于分布偏左；峰度为：1.4531，属于分布陡峭
#
# 2019-12-09 12:52:57.565376	第六步：变化率分析
# 2019-12-09 12:52:58.955736	样本平均数：0.0032, 中位数: 0.0
# 2019-12-09 12:52:58.956738	偏度为：52.8485，属于分布偏左；峰度为：4061.4207，属于分布陡峭
#
# 2019-12-09 12:52:58.956738	ER位移路程比
# 2019-12-09 12:52:59.161427	样本平均数：0.261, 中位数: 0.2296
# 2019-12-09 12:52:59.162429	偏度为：0.8641，属于分布偏左；峰度为：0.533，属于分布陡峭
#
# 2019-12-09 12:52:59.162429	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
