# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="RB9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 1/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 15:34:58.097659	开始加载历史数据
# 2019-12-08 15:35:22.462957	历史数据加载完成，数据量：426300

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-08 15:35:32.231971	第一步:画出行情图，检查数据断点
# 2019-12-08 15:35:40.273851	第二步：随机性检验：非纯随机性
# 2019-12-08 15:35:40.274852	白噪声检验结果:(array([426295.2155296]), array([0.]))
#
# 2019-12-08 15:38:03.942970	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:38:03.957983	ADF检验结果：(-1.276494528722144, 0.6398563237620507, 69, 426230, {'1%': -3.4303653422785416, '5%': -2.8615467811039434, '10%': -2.566773609334374}, 2126908.815055794)
#
# 2019-12-08 15:38:03.957983	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:38:15.668322	第五步：相对波动率分析
# 2019-12-08 15:38:16.518736	样本平均数：3.0035, 中位数: 2.71
# 2019-12-08 15:38:16.535751	偏度为：1.4668，属于分布偏左；峰度为：5.2334，属于分布陡峭
#
# 2019-12-08 15:38:16.536752	第六步：变化率分析
# 2019-12-08 15:38:18.182696	样本平均数：0.0002, 中位数: 0.0
# 2019-12-08 15:38:18.197702	偏度为：391.0331，属于分布偏左；峰度为：215887.4048，属于分布陡峭
#
# 2019-12-08 15:38:18.198703	ER位移路程比
# 2019-12-08 15:38:19.096519	样本平均数：0.1853, 中位数: 0.1549
# 2019-12-08 15:38:19.114535	偏度为：1.0009，属于分布偏左；峰度为：1.0048，属于分布陡峭
#
# 2019-12-08 15:38:19.114535	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-08 15:50:05.944187	------------------------------------------------
# 2019-12-08 15:50:05.945180	合成5min周期K先并开始数据分析
# 2019-12-08 15:50:08.012069	第一步:画出行情图，检查数据断点
# 2019-12-08 15:50:08.759749	第二步：随机性检验：非纯随机性
# 2019-12-08 15:50:08.760750	白噪声检验结果:(array([85255.72164028]), array([0.]))
#
# 2019-12-08 15:50:18.997643	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:50:18.998644	ADF检验结果：(-1.3004486803310353, 0.6289670168907024, 57, 85202, {'1%': -3.4304267528582084, '5%': -2.861573923495918, '10%': -2.566788056301128}, 555503.4987612487)
#
# 2019-12-08 15:50:18.998644	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:50:19.996055	第五步：相对波动率分析
# 2019-12-08 15:50:20.574094	样本平均数：6.966, 中位数: 6.466
# 2019-12-08 15:50:20.575094	偏度为：0.9148，属于分布偏左；峰度为：1.2243，属于分布陡峭
#
# 2019-12-08 15:50:20.575094	第六步：变化率分析
# 2019-12-08 15:50:22.029921	样本平均数：0.0009, 中位数: 0.0
# 2019-12-08 15:50:22.031924	偏度为：182.718，属于分布偏左；峰度为：45793.3667，属于分布陡峭
#
# 2019-12-08 15:50:22.031924	ER位移路程比
# 2019-12-08 15:50:22.458310	样本平均数：0.2301, 中位数: 0.2
# 2019-12-08 15:50:22.460312	偏度为：0.8301，属于分布偏左；峰度为：0.3385，属于分布陡峭
#
# 2019-12-08 15:50:22.460312	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:50:22.466318	------------------------------------------------
# 2019-12-08 15:50:22.466318	合成15min周期K先并开始数据分析
# 2019-12-08 15:50:23.252549	第一步:画出行情图，检查数据断点
# 2019-12-08 15:50:23.528789	第二步：随机性检验：非纯随机性
# 2019-12-08 15:50:23.528789	白噪声检验结果:(array([28415.81187718]), array([0.]))
#
# 2019-12-08 15:50:25.218833	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:50:25.218833	ADF检验结果：(-1.2380414682107719, 0.6570209896212368, 47, 28372, {'1%': -3.430580505136695, '5%': -2.8616418768250873, '10%': -2.56682422596243}, 215701.42198831541)
#
# 2019-12-08 15:50:25.218833	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:50:25.586167	第五步：相对波动率分析
# 2019-12-08 15:50:26.135184	样本平均数：12.5153, 中位数: 11.8213
# 2019-12-08 15:50:26.136185	偏度为：0.7491，属于分布偏左；峰度为：0.4164，属于分布陡峭
#
# 2019-12-08 15:50:26.136185	第六步：变化率分析
# 2019-12-08 15:50:27.544971	样本平均数：0.0027, 中位数: 0.0
# 2019-12-08 15:50:27.545972	偏度为：106.1836，属于分布偏左；峰度为：15398.8097，属于分布陡峭
#
# 2019-12-08 15:50:27.545972	ER位移路程比
# 2019-12-08 15:50:27.834731	样本平均数：0.2538, 中位数: 0.2186
# 2019-12-08 15:50:27.835732	偏度为：0.8294，属于分布偏左；峰度为：0.3032，属于分布陡峭
#
# 2019-12-08 15:50:27.835732	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:50:27.838734	------------------------------------------------
# 2019-12-08 15:50:27.839735	合成30min周期K先并开始数据分析
# 2019-12-08 15:50:28.261119	第一步:画出行情图，检查数据断点
# 2019-12-08 15:50:28.481318	第二步：随机性检验：非纯随机性
# 2019-12-08 15:50:28.482319	白噪声检验结果:(array([14815.60825161]), array([0.]))
#
# 2019-12-08 15:50:29.149926	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:50:29.149926	ADF检验结果：(-1.2215878170313597, 0.6642409268233411, 31, 14788, {'1%': -3.4307922799210693, '5%': -2.8617354683862812, '10%': -2.5668740431397965}, 122438.96549901072)
#
# 2019-12-08 15:50:29.149926	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:50:29.442193	第五步：相对波动率分析
# 2019-12-08 15:50:29.990197	样本平均数：17.6253, 中位数: 16.8131
# 2019-12-08 15:50:29.991197	偏度为：0.6461，属于分布偏左；峰度为：-0.0297，属于分布平缓
#
# 2019-12-08 15:50:29.991197	第六步：变化率分析
# 2019-12-08 15:50:31.395508	样本平均数：0.0052, 中位数: 0.0
# 2019-12-08 15:50:31.396510	偏度为：75.7825，属于分布偏左；峰度为：7904.2678，属于分布陡峭
#
# 2019-12-08 15:50:31.396510	ER位移路程比
# 2019-12-08 15:50:31.634224	样本平均数：0.264, 中位数: 0.2337
# 2019-12-08 15:50:31.635225	偏度为：0.8013，属于分布偏左；峰度为：0.3269，属于分布陡峭
#
# 2019-12-08 15:50:31.635225	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:50:31.638227	------------------------------------------------
# 2019-12-08 15:50:31.638227	合成60min周期K先并开始数据分析
# 2019-12-08 15:50:31.821405	第一步:画出行情图，检查数据断点
# 2019-12-08 15:50:32.000556	第二步：随机性检验：非纯随机性
# 2019-12-08 15:50:32.001558	白噪声检验结果:(array([8625.55561526]), array([0.]))
#
# 2019-12-08 15:50:32.282813	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:50:32.282813	ADF检验结果：(-1.2276738484844103, 0.6615792913374368, 18, 8611, {'1%': -3.4311096388849545, '5%': -2.8618757092366347, '10%': -2.5669486930914713}, 75885.40511319708)
#
# 2019-12-08 15:50:32.282813	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:50:32.656153	第五步：相对波动率分析
# 2019-12-08 15:50:33.188638	样本平均数：23.5208, 中位数: 22.697
# 2019-12-08 15:50:33.189638	偏度为：0.5943，属于分布偏左；峰度为：-0.2968，属于分布平缓
#
# 2019-12-08 15:50:33.189638	第六步：变化率分析
# 2019-12-08 15:50:34.587304	样本平均数：0.0088, 中位数: 0.0
# 2019-12-08 15:50:34.588305	偏度为：57.5114，属于分布偏左；峰度为：4569.6839，属于分布陡峭
#
# 2019-12-08 15:50:34.588305	ER位移路程比
# 2019-12-08 15:50:34.791479	样本平均数：0.2639, 中位数: 0.2347
# 2019-12-08 15:50:34.792481	偏度为：0.7512，属于分布偏左；峰度为：0.1455，属于分布陡峭
#
# 2019-12-08 15:50:34.792481	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
