# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="IC9999",
    exchange=Exchange.CFFEX,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.25/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 23:01:49.323594	开始加载历史数据
# 2019-12-08 23:02:03.187468	历史数据加载完成，数据量：222960

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-08 23:02:06.475230	第一步:画出行情图，检查数据断点
# 2019-12-08 23:02:10.585822	第二步：随机性检验：非纯随机性
# 2019-12-08 23:02:10.586823	白噪声检验结果:(array([222941.16160278]), array([0.]))
#
# 2019-12-08 23:03:01.145663	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 23:03:01.145663	ADF检验结果：(-1.7188434540963657, 0.42143084525173535, 83, 222876, {'1%': -3.4303793408680923, '5%': -2.861552968282803, '10%': -2.566776902549415}, 1659501.1009164217)
#
# 2019-12-08 23:03:01.145663	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 23:03:05.740369	第五步：相对波动率分析
# 2019-12-08 23:03:06.350924	样本平均数：8.8236, 中位数: 5.895
# 2019-12-08 23:03:06.360934	偏度为：3.5562，属于分布偏左；峰度为：17.5609，属于分布陡峭
#
# 2019-12-08 23:03:06.360934	第六步：变化率分析
# 2019-12-08 23:03:07.786242	样本平均数：0.0001, 中位数: 0.0
# 2019-12-08 23:03:07.794249	偏度为：265.084，属于分布偏左；峰度为：103222.4278，属于分布陡峭
#
# 2019-12-08 23:03:07.794249	ER位移路程比
# 2019-12-08 23:03:08.542434	样本平均数：0.2226, 中位数: 0.1937
# 2019-12-08 23:03:08.550441	偏度为：0.873，属于分布偏左；峰度为：0.5623，属于分布陡峭
#
# 2019-12-08 23:03:08.550441	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-08 23:04:43.395004	------------------------------------------------
# 2019-12-08 23:04:43.395004	合成5min周期K先并开始数据分析
# 2019-12-08 23:04:44.993468	第一步:画出行情图，检查数据断点
# 2019-12-08 23:04:45.391831	第二步：随机性检验：非纯随机性
# 2019-12-08 23:04:45.392832	白噪声检验结果:(array([44573.308897]), array([0.]))
#
# 2019-12-08 23:04:48.987786	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 23:04:48.987786	ADF检验结果：(-2.050762375957251, 0.2647682790691547, 54, 44537, {'1%': -3.430496836943219, '5%': -2.861604898737841, '10%': -2.566804543482299}, 402767.95583396783)
#
# 2019-12-08 23:04:48.987786	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 23:04:49.451209	第五步：相对波动率分析
# 2019-12-08 23:04:49.996209	样本平均数：21.4074, 中位数: 14.2499
# 2019-12-08 23:04:49.996209	偏度为：3.1164，属于分布偏左；峰度为：11.631，属于分布陡峭
#
# 2019-12-08 23:04:49.997211	第六步：变化率分析
# 2019-12-08 23:04:51.410516	样本平均数：0.0003, 中位数: 0.0
# 2019-12-08 23:04:51.411518	偏度为：119.7597，属于分布偏左；峰度为：20930.1664，属于分布陡峭
#
# 2019-12-08 23:04:51.411518	ER位移路程比
# 2019-12-08 23:04:51.730807	样本平均数：0.2337, 中位数: 0.1976
# 2019-12-08 23:04:51.732809	偏度为：0.8887，属于分布偏左；峰度为：0.4015，属于分布陡峭
#
# 2019-12-08 23:04:51.732809	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 23:04:51.735812	------------------------------------------------
# 2019-12-08 23:04:51.735812	合成15min周期K先并开始数据分析
# 2019-12-08 23:04:52.267800	第一步:画出行情图，检查数据断点
# 2019-12-08 23:04:52.478992	第二步：随机性检验：非纯随机性
# 2019-12-08 23:04:52.478992	白噪声检验结果:(array([14845.91230441]), array([0.]))
#
# 2019-12-08 23:04:53.097060	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 23:04:53.097060	ADF检验结果：(-1.911091454880093, 0.32686146498499125, 42, 14821, {'1%': -3.4307912949830484, '5%': -2.8617350331190887, '10%': -2.566873811451884}, 149833.35066649568)
#
# 2019-12-08 23:04:53.097060	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 23:04:53.414349	第五步：相对波动率分析
# 2019-12-08 23:04:53.931325	样本平均数：39.3565, 中位数: 25.7789
# 2019-12-08 23:04:53.932326	偏度为：2.8866，属于分布偏左；峰度为：9.6179，属于分布陡峭
#
# 2019-12-08 23:04:53.932326	第六步：变化率分析
# 2019-12-08 23:04:55.318600	样本平均数：0.001, 中位数: 0.0
# 2019-12-08 23:04:55.318600	偏度为：69.9948，属于分布偏左；峰度为：7089.687，属于分布陡峭
#
# 2019-12-08 23:04:55.319600	ER位移路程比
# 2019-12-08 23:04:55.554813	样本平均数：0.245, 中位数: 0.2086
# 2019-12-08 23:04:55.555814	偏度为：0.8948，属于分布偏左；峰度为：0.49，属于分布陡峭
#
# 2019-12-08 23:04:55.555814	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 23:04:55.567825	------------------------------------------------
# 2019-12-08 23:04:55.567825	合成30min周期K先并开始数据分析
# 2019-12-08 23:04:55.880109	第一步:画出行情图，检查数据断点
# 2019-12-08 23:04:56.059273	第二步：随机性检验：非纯随机性
# 2019-12-08 23:04:56.060274	白噪声检验结果:(array([7590.16304219]), array([0.]))
#
# 2019-12-08 23:04:56.295487	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 23:04:56.295487	ADF检验结果：(-2.1064313230083047, 0.24193641059182353, 36, 7571, {'1%': -3.431214023052456, '5%': -2.8619218333030956, '10%': -2.5669732454128913}, 81870.14933723006)
#
# 2019-12-08 23:04:56.296487	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 23:04:56.549718	第五步：相对波动率分析
# 2019-12-08 23:04:57.071698	样本平均数：57.2626, 中位数: 38.2093
# 2019-12-08 23:04:57.071698	偏度为：2.6137，属于分布偏左；峰度为：7.4726，属于分布陡峭
#
# 2019-12-08 23:04:57.072699	第六步：变化率分析
# 2019-12-08 23:04:58.444453	样本平均数：0.0019, 中位数: 0.0
# 2019-12-08 23:04:58.445455	偏度为：48.9225，属于分布偏左；峰度为：3523.8902，属于分布陡峭
#
# 2019-12-08 23:04:58.445455	ER位移路程比
# 2019-12-08 23:04:58.647142	样本平均数：0.2497, 中位数: 0.2159
# 2019-12-08 23:04:58.648144	偏度为：0.8179，属于分布偏左；峰度为：0.3576，属于分布陡峭
#
# 2019-12-08 23:04:58.648144	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 23:04:58.650145	------------------------------------------------
# 2019-12-08 23:04:58.650145	合成60min周期K先并开始数据分析
# 2019-12-08 23:04:58.777261	第一步:画出行情图，检查数据断点
# 2019-12-08 23:04:58.937407	第二步：随机性检验：非纯随机性
# 2019-12-08 23:04:58.937407	白噪声检验结果:(array([4692.19726186]), array([0.]))
#
# 2019-12-08 23:04:59.063025	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 23:04:59.064027	ADF检验结果：(-2.313856005135145, 0.16753806865696907, 32, 4678, {'1%': -3.4317486515424056, '5%': -2.8621580433769385, '10%': -2.567098986847004}, 52860.51730348257)
#
# 2019-12-08 23:04:59.064027	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 23:04:59.376311	第五步：相对波动率分析
# 2019-12-08 23:04:59.884773	样本平均数：72.7586, 中位数: 49.4366
# 2019-12-08 23:04:59.885774	偏度为：2.5256，属于分布偏左；峰度为：6.5779，属于分布陡峭
#
# 2019-12-08 23:04:59.885774	第六步：变化率分析
# 2019-12-08 23:05:01.248025	样本平均数：0.0025, 中位数: -0.0026
# 2019-12-08 23:05:01.249026	偏度为：38.1631，属于分布偏左；峰度为：2160.3166，属于分布陡峭
#
# 2019-12-08 23:05:01.249026	ER位移路程比
# 2019-12-08 23:05:01.430190	样本平均数：0.2477, 中位数: 0.2129
# 2019-12-08 23:05:01.431192	偏度为：0.8542，属于分布偏左；峰度为：0.4235，属于分布陡峭
#
# 2019-12-08 23:05:01.431192	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
