# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="I9999",
    exchange=Exchange.DCE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 1/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-09 12:56:52.940235	开始加载历史数据
# 2019-12-09 12:57:19.352281	历史数据加载完成，数据量：431760

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-09 12:57:45.618501	第一步:画出行情图，检查数据断点
# 2019-12-09 12:57:59.070894	第二步：随机性检验：非纯随机性
# 2019-12-09 12:57:59.070894	白噪声检验结果:(array([431730.1078775]), array([0.]))
#
# 2019-12-09 13:00:42.620886	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:00:42.643907	ADF检验结果：(-3.683779713036767, 0.004347178874294036, 34, 431725, {'1%': -3.43036514700071, '5%': -2.861546694793694, '10%': -2.5667735633945368}, 972762.8992556947)
#
# 2019-12-09 13:00:42.653916	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:01:00.133656	第五步：相对波动率分析
# 2019-12-09 13:01:00.966413	样本平均数：0.9041, 中位数: 0.8433
# 2019-12-09 13:01:00.986430	偏度为：1.4976，属于分布偏左；峰度为：8.5842，属于分布陡峭
#
# 2019-12-09 13:01:00.986430	第六步：变化率分析
# 2019-12-09 13:01:02.630559	样本平均数：-0.0, 中位数: 0.0
# 2019-12-09 13:01:02.648575	偏度为：229.8208，属于分布偏左；峰度为：107783.7221，属于分布陡峭
#
# 2019-12-09 13:01:02.648575	ER位移路程比
# 2019-12-09 13:01:03.460346	样本平均数：0.1623, 中位数: 0.1333
# 2019-12-09 13:01:03.478349	偏度为：1.5219，属于分布偏左；峰度为：4.1931，属于分布陡峭
#
# 2019-12-09 13:01:03.479350	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-09 13:05:39.467036	------------------------------------------------
# 2019-12-09 13:05:39.467036	合成5min周期K先并开始数据分析
# 2019-12-09 13:05:41.712937	第一步:画出行情图，检查数据断点
# 2019-12-09 13:05:42.656110	第二步：随机性检验：非纯随机性
# 2019-12-09 13:05:42.657111	白噪声检验结果:(array([86327.55468872]), array([0.]))
#
# 2019-12-09 13:05:54.592203	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:05:54.592203	ADF检验结果：(-3.623608550554095, 0.005325396162219502, 46, 86305, {'1%': -3.430425771907849, '5%': -2.861573489937593, '10%': -2.566787825532094}, 307384.2926383409)
#
# 2019-12-09 13:05:54.592203	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:05:55.663195	第五步：相对波动率分析
# 2019-12-09 13:05:56.227850	样本平均数：1.7723, 中位数: 1.6198
# 2019-12-09 13:05:56.229851	偏度为：1.6529，属于分布偏左；峰度为：5.5563，属于分布陡峭
#
# 2019-12-09 13:05:56.229851	第六步：变化率分析
# 2019-12-09 13:05:57.715939	样本平均数：0.0, 中位数: 0.0
# 2019-12-09 13:05:57.718427	偏度为：131.2303，属于分布偏左；峰度为：29860.6818，属于分布陡峭
#
# 2019-12-09 13:05:57.718427	ER位移路程比
# 2019-12-09 13:05:58.141052	样本平均数：0.2108, 中位数: 0.1724
# 2019-12-09 13:05:58.143054	偏度为：1.1218，属于分布偏左；峰度为：1.4692，属于分布陡峭
#
# 2019-12-09 13:05:58.143054	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:05:58.149058	------------------------------------------------
# 2019-12-09 13:05:58.149058	合成15min周期K先并开始数据分析
# 2019-12-09 13:05:58.907888	第一步:画出行情图，检查数据断点
# 2019-12-09 13:05:59.205159	第二步：随机性检验：非纯随机性
# 2019-12-09 13:05:59.206160	白噪声检验结果:(array([28760.3003669]), array([0.]))
#
# 2019-12-09 13:06:01.248124	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:06:01.248124	ADF检验结果：(-3.607413987237742, 0.005620859898327951, 27, 28756, {'1%': -3.4305774267573756, '5%': -2.8616405163196292, '10%': -2.566823501797328}, 132388.79484535678)
#
# 2019-12-09 13:06:01.248124	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:06:01.658169	第五步：相对波动率分析
# 2019-12-09 13:06:02.205508	样本平均数：2.9939, 中位数: 2.6979
# 2019-12-09 13:06:02.206509	偏度为：1.4691，属于分布偏左；峰度为：3.2794，属于分布陡峭
#
# 2019-12-09 13:06:02.206509	第六步：变化率分析
# 2019-12-09 13:06:03.660437	样本平均数：0.0002, 中位数: 0.0
# 2019-12-09 13:06:03.661438	偏度为：78.3618，属于分布偏左；峰度为：10433.0012，属于分布陡峭
#
# 2019-12-09 13:06:03.661438	ER位移路程比
# 2019-12-09 13:06:03.951429	样本平均数：0.2436, 中位数: 0.2048
# 2019-12-09 13:06:03.952430	偏度为：0.8853，属于分布偏左；峰度为：0.4106，属于分布陡峭
#
# 2019-12-09 13:06:03.952430	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:06:03.955433	------------------------------------------------
# 2019-12-09 13:06:03.955433	合成30min周期K先并开始数据分析
# 2019-12-09 13:06:04.368581	第一步:画出行情图，检查数据断点
# 2019-12-09 13:06:04.589287	第二步：随机性检验：非纯随机性
# 2019-12-09 13:06:04.590288	白噪声检验结果:(array([14978.98359665]), array([0.]))
#
# 2019-12-09 13:06:05.326209	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:06:05.326209	ADF检验结果：(-3.5517462556299355, 0.00675344263881728, 34, 14967, {'1%': -3.430786989502815, '5%': -2.8617331304247857, '10%': -2.5668727986690425}, 78410.69791974215)
#
# 2019-12-09 13:06:05.326209	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:06:05.645509	第五步：相对波动率分析
# 2019-12-09 13:06:06.186000	样本平均数：4.1202, 中位数: 3.7251
# 2019-12-09 13:06:06.186000	偏度为：1.3353，属于分布偏左；峰度为：2.2856，属于分布陡峭
#
# 2019-12-09 13:06:06.186000	第六步：变化率分析
# 2019-12-09 13:06:07.614988	样本平均数：0.0005, 中位数: 0.0
# 2019-12-09 13:06:07.615989	偏度为：57.241，属于分布偏左；峰度为：5516.5144，属于分布陡峭
#
# 2019-12-09 13:06:07.615989	ER位移路程比
# 2019-12-09 13:06:07.854971	样本平均数：0.2617, 中位数: 0.2267
# 2019-12-09 13:06:07.855972	偏度为：0.7753，属于分布偏左；峰度为：0.0981，属于分布陡峭
#
# 2019-12-09 13:06:07.855972	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:06:07.858974	------------------------------------------------
# 2019-12-09 13:06:07.858974	合成60min周期K先并开始数据分析
# 2019-12-09 13:06:08.040139	第一步:画出行情图，检查数据断点
# 2019-12-09 13:06:08.222334	第二步：随机性检验：非纯随机性
# 2019-12-09 13:06:08.223336	白噪声检验结果:(array([9173.25124218]), array([0.]))
#
# 2019-12-09 13:06:08.566218	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:06:08.566740	ADF检验结果：(-3.5523141481072273, 0.006740915851609123, 23, 9172, {'1%': -3.4310631630047332, '5%': -2.8618551724921812, '10%': -2.5669377612579782}, 52485.59269823735)
#
# 2019-12-09 13:06:08.566740	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:06:08.927730	第五步：相对波动率分析
# 2019-12-09 13:06:09.461429	样本平均数：5.2526, 中位数: 4.765
# 2019-12-09 13:06:09.461429	偏度为：1.2591，属于分布偏左；峰度为：1.8476，属于分布陡峭
#
# 2019-12-09 13:06:09.461429	第六步：变化率分析
# 2019-12-09 13:06:10.868435	样本平均数：0.0008, 中位数: 0.0
# 2019-12-09 13:06:10.869437	偏度为：44.7061，属于分布偏左；峰度为：3377.2884，属于分布陡峭
#
# 2019-12-09 13:06:10.869437	ER位移路程比
# 2019-12-09 13:06:11.080439	样本平均数：0.265, 中位数: 0.2308
# 2019-12-09 13:06:11.081439	偏度为：0.7888，属于分布偏左；峰度为：0.1326，属于分布陡峭
#
# 2019-12-09 13:06:11.081439	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
