# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="RU9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.45/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 20:52:49.756604	开始加载历史数据
# 2019-12-08 20:53:12.536808	历史数据加载完成，数据量：388500

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-08 20:53:40.681753	第一步:画出行情图，检查数据断点
# 2019-12-08 20:53:52.166590	第二步：随机性检验：非纯随机性
# 2019-12-08 20:53:52.167592	白噪声检验结果:(array([388476.96113329]), array([0.]))
#
# 2019-12-08 20:56:21.332887	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 20:56:21.351901	ADF检验结果：(-2.6161306674646716, 0.08970900472989668, 31, 388468, {'1%': -3.4303668336728155, '5%': -2.8615474402805368, '10%': -2.566773960190366}, 3312258.2097795866)
#
# 2019-12-08 20:56:21.364911	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 20:56:36.226778	第五步：相对波动率分析
# 2019-12-08 20:56:37.039517	样本平均数：17.5189, 中位数: 15.528
# 2019-12-08 20:56:37.054530	偏度为：2.1909，属于分布偏左；峰度为：11.4594，属于分布陡峭
#
# 2019-12-08 20:56:37.054530	第六步：变化率分析
# 2019-12-08 20:56:38.696033	样本平均数：0.0001, 中位数: 0.0
# 2019-12-08 20:56:38.713049	偏度为：314.6697，属于分布偏左；峰度为：153491.0818，属于分布陡峭
#
# 2019-12-08 20:56:38.714050	ER位移路程比
# 2019-12-08 20:56:39.611867	样本平均数：0.1901, 中位数: 0.1579
# 2019-12-08 20:56:39.627880	偏度为：1.0444，属于分布偏左；峰度为：1.1442，属于分布陡峭
#
# 2019-12-08 20:56:39.627880	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-08 21:00:16.233979	------------------------------------------------
# 2019-12-08 21:00:16.234980	合成5min周期K先并开始数据分析
# 2019-12-08 21:00:18.441872	第一步:画出行情图，检查数据断点
# 2019-12-08 21:00:19.327184	第二步：随机性检验：非纯随机性
# 2019-12-08 21:00:19.328185	白噪声检验结果:(array([77677.97528507]), array([0.]))
#
# 2019-12-08 21:00:29.537482	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 21:00:29.538483	ADF检验结果：(-2.621980577194378, 0.08853889011713811, 6, 77693, {'1%': -3.4304341712389617, '5%': -2.861577202251209, '10%': -2.566789801477033}, 783498.7635516133)
#
# 2019-12-08 21:00:29.538483	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 21:00:30.494366	第五步：相对波动率分析
# 2019-12-08 21:00:31.100422	样本平均数：40.7032, 中位数: 36.8801
# 2019-12-08 21:00:31.101423	偏度为：1.6689，属于分布偏左；峰度为：4.6683，属于分布陡峭
#
# 2019-12-08 21:00:31.101423	第六步：变化率分析
# 2019-12-08 21:00:32.612825	样本平均数：0.0003, 中位数: 0.0
# 2019-12-08 21:00:32.614811	偏度为：145.6711，属于分布偏左；峰度为：32127.7211，属于分布陡峭
#
# 2019-12-08 21:00:32.614811	ER位移路程比
# 2019-12-08 21:00:33.060216	样本平均数：0.2272, 中位数: 0.1915
# 2019-12-08 21:00:33.062217	偏度为：0.9307，属于分布偏左；峰度为：0.5641，属于分布陡峭
#
# 2019-12-08 21:00:33.063218	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 21:00:33.068223	------------------------------------------------
# 2019-12-08 21:00:33.068223	合成15min周期K先并开始数据分析
# 2019-12-08 21:00:33.840430	第一步:画出行情图，检查数据断点
# 2019-12-08 21:00:34.136700	第二步：随机性检验：非纯随机性
# 2019-12-08 21:00:34.137701	白噪声检验结果:(array([25878.37133158]), array([0.]))
#
# 2019-12-08 21:00:35.919855	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 21:00:35.920858	ADF检验结果：(-2.5986029456897453, 0.09328635406909702, 10, 25889, {'1%': -3.4306026149523734, '5%': -2.861651648329565, '10%': -2.5668294271119656}, 288983.9301638942)
#
# 2019-12-08 21:00:35.920858	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 21:00:36.318723	第五步：相对波动率分析
# 2019-12-08 21:00:36.866220	样本平均数：73.3632, 中位数: 66.9789
# 2019-12-08 21:00:36.867221	偏度为：1.4873，属于分布偏左；峰度为：2.9905，属于分布陡峭
#
# 2019-12-08 21:00:36.867221	第六步：变化率分析
# 2019-12-08 21:00:38.329560	样本平均数：0.001, 中位数: 0.0
# 2019-12-08 21:00:38.330562	偏度为：84.8349，属于分布偏左；峰度为：10841.5615，属于分布陡峭
#
# 2019-12-08 21:00:38.330562	ER位移路程比
# 2019-12-08 21:00:38.611818	样本平均数：0.2432, 中位数: 0.2
# 2019-12-08 21:00:38.611818	偏度为：0.9143，属于分布偏左；峰度为：0.3804，属于分布陡峭
#
# 2019-12-08 21:00:38.611818	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 21:00:38.614821	------------------------------------------------
# 2019-12-08 21:00:38.614821	合成30min周期K先并开始数据分析
# 2019-12-08 21:00:39.029577	第一步:画出行情图，检查数据断点
# 2019-12-08 21:00:39.247775	第二步：随机性检验：非纯随机性
# 2019-12-08 21:00:39.248776	白噪声检验结果:(array([13537.6833775]), array([0.]))
#
# 2019-12-08 21:00:39.862842	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 21:00:39.863843	ADF检验结果：(-2.6496580729648507, 0.08316200356953496, 0, 13559, {'1%': -3.43083237616557, '5%': -2.8617531877338087, '10%': -2.56688347497372}, 160239.4592113506)
#
# 2019-12-08 21:00:39.863843	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 21:00:40.185139	第五步：相对波动率分析
# 2019-12-08 21:00:40.741147	样本平均数：103.5734, 中位数: 95.0652
# 2019-12-08 21:00:40.742148	偏度为：1.4762，属于分布偏左；峰度为：2.7111，属于分布陡峭
#
# 2019-12-08 21:00:40.742148	第六步：变化率分析
# 2019-12-08 21:00:42.202997	样本平均数：0.0018, 中位数: 0.0
# 2019-12-08 21:00:42.202997	偏度为：60.6054，属于分布偏左；峰度为：5585.3609，属于分布陡峭
#
# 2019-12-08 21:00:42.203998	ER位移路程比
# 2019-12-08 21:00:42.447219	样本平均数：0.2468, 中位数: 0.2059
# 2019-12-08 21:00:42.448220	偏度为：0.8435，属于分布偏左；峰度为：0.1739，属于分布陡峭
#
# 2019-12-08 21:00:42.448220	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 21:00:42.451223	------------------------------------------------
# 2019-12-08 21:00:42.451223	合成60min周期K先并开始数据分析
# 2019-12-08 21:00:42.633388	第一步:画出行情图，检查数据断点
# 2019-12-08 21:00:42.826070	第二步：随机性检验：非纯随机性
# 2019-12-08 21:00:42.826070	白噪声检验结果:(array([7977.19652477]), array([0.]))
#
# 2019-12-08 21:00:43.097826	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 21:00:43.097826	ADF检验结果：(-2.6669586227012956, 0.07993245221736067, 0, 7999, {'1%': -3.4311677771913693, '5%': -2.8619013989176083, '10%': -2.566962367942105}, 98769.40011020892)
#
# 2019-12-08 21:00:43.097826	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 21:00:43.473674	第五步：相对波动率分析
# 2019-12-08 21:00:44.027177	样本平均数：137.4008, 中位数: 127.3486
# 2019-12-08 21:00:44.028178	偏度为：1.472，属于分布偏左；峰度为：2.5282，属于分布陡峭
#
# 2019-12-08 21:00:44.028178	第六步：变化率分析
# 2019-12-08 21:00:45.447481	样本平均数：0.003, 中位数: 0.0
# 2019-12-08 21:00:45.447481	偏度为：45.893，属于分布偏左；峰度为：3236.5134，属于分布陡峭
#
# 2019-12-08 21:00:45.448481	ER位移路程比
# 2019-12-08 21:00:45.669683	样本平均数：0.2539, 中位数: 0.2188
# 2019-12-08 21:00:45.670683	偏度为：0.814，属于分布偏左；峰度为：0.1711，属于分布陡峭
#
# 2019-12-08 21:00:45.670683	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
