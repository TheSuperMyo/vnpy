# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="M9999",
    exchange=Exchange.DCE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.5/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-09 13:09:21.836808	开始加载历史数据
# 2019-12-09 13:09:48.081457	历史数据加载完成，数据量：431760

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-09 13:09:51.601818	第一步:画出行情图，检查数据断点
# 2019-12-09 13:10:05.183880	第二步：随机性检验：非纯随机性
# 2019-12-09 13:10:05.183880	白噪声检验结果:(array([431734.76742189]), array([0.]))
#
# 2019-12-09 13:12:50.817314	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:12:50.834333	ADF检验结果：(-2.458869532953972, 0.12580514529655829, 38, 431721, {'1%': -3.4303651471410515, '5%': -2.861546694855723, '10%': -2.5667735634275526}, 1887615.3238642798)
#
# 2019-12-09 13:12:50.834333	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:13:07.433695	第五步：相对波动率分析
# 2019-12-09 13:13:08.292122	样本平均数：2.1052, 中位数: 1.884
# 2019-12-09 13:13:08.312140	偏度为：2.5331，属于分布偏左；峰度为：14.2341，属于分布陡峭
#
# 2019-12-09 13:13:08.312140	第六步：变化率分析
# 2019-12-09 13:13:10.021910	样本平均数：0.0001, 中位数: 0.0
# 2019-12-09 13:13:10.037924	偏度为：476.3119，属于分布偏左；峰度为：282370.3238，属于分布陡峭
#
# 2019-12-09 13:13:10.038925	ER位移路程比
# 2019-12-09 13:13:11.028387	样本平均数：0.1867, 中位数: 0.1579
# 2019-12-09 13:13:11.046403	偏度为：1.0616，属于分布偏左；峰度为：1.1983，属于分布陡峭
#
# 2019-12-09 13:13:11.047404	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-09 13:14:08.363708	------------------------------------------------
# 2019-12-09 13:14:08.363708	合成5min周期K先并开始数据分析
# 2019-12-09 13:14:10.522406	第一步:画出行情图，检查数据断点
# 2019-12-09 13:14:11.461409	第二步：随机性检验：非纯随机性
# 2019-12-09 13:14:11.461409	白噪声检验结果:(array([86329.95519893]), array([0.]))
#
# 2019-12-09 13:14:23.205164	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:14:23.206164	ADF检验结果：(-2.4852687394644906, 0.11909986570423747, 32, 86319, {'1%': -3.4304257596181067, '5%': -2.8615734845057985, '10%': -2.5667878226409258}, 504793.8516520639)
#
# 2019-12-09 13:14:23.206164	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:14:24.279269	第五步：相对波动率分析
# 2019-12-09 13:14:24.850312	样本平均数：4.6351, 中位数: 4.1751
# 2019-12-09 13:14:24.852315	偏度为：1.9984，属于分布偏左；峰度为：6.639，属于分布陡峭
#
# 2019-12-09 13:14:24.853317	第六步：变化率分析
# 2019-12-09 13:14:26.301170	样本平均数：0.0008, 中位数: 0.0
# 2019-12-09 13:14:26.304173	偏度为：221.4011，属于分布偏左；峰度为：59458.7282，属于分布陡峭
#
# 2019-12-09 13:14:26.304173	ER位移路程比
# 2019-12-09 13:14:26.744574	样本平均数：0.234, 中位数: 0.2
# 2019-12-09 13:14:26.745575	偏度为：0.8516，属于分布偏左；峰度为：0.3814，属于分布陡峭
#
# 2019-12-09 13:14:26.746575	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:14:26.751579	------------------------------------------------
# 2019-12-09 13:14:26.751579	合成15min周期K先并开始数据分析
# 2019-12-09 13:14:27.509522	第一步:画出行情图，检查数据断点
# 2019-12-09 13:14:27.812285	第二步：随机性检验：非纯随机性
# 2019-12-09 13:14:27.813286	白噪声检验结果:(array([28763.15453971]), array([0.]))
#
# 2019-12-09 13:14:29.742754	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:14:29.743755	ADF检验结果：(-2.475855175329162, 0.12146008317857676, 11, 28772, {'1%': -3.4305773002749334, '5%': -2.861640460420038, '10%': -2.5668234720432936}, 198155.4007246104)
#
# 2019-12-09 13:14:29.743755	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:14:30.154336	第五步：相对波动率分析
# 2019-12-09 13:14:30.717848	样本平均数：8.2356, 中位数: 7.4585
# 2019-12-09 13:14:30.718850	偏度为：1.8193，属于分布偏左；峰度为：4.9258，属于分布陡峭
#
# 2019-12-09 13:14:30.718850	第六步：变化率分析
# 2019-12-09 13:14:32.158192	样本平均数：0.0023, 中位数: 0.0
# 2019-12-09 13:14:32.159194	偏度为：129.6217，属于分布偏左；峰度为：20189.3096，属于分布陡峭
#
# 2019-12-09 13:14:32.159194	ER位移路程比
# 2019-12-09 13:14:32.456534	样本平均数：0.2599, 中位数: 0.2281
# 2019-12-09 13:14:32.457535	偏度为：0.7176，属于分布偏左；峰度为：-0.035，属于分布平缓
#
# 2019-12-09 13:14:32.457535	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:14:32.460537	------------------------------------------------
# 2019-12-09 13:14:32.460537	合成30min周期K先并开始数据分析
# 2019-12-09 13:14:32.878277	第一步:画出行情图，检查数据断点
# 2019-12-09 13:14:33.102995	第二步：随机性检验：非纯随机性
# 2019-12-09 13:14:33.103996	白噪声检验结果:(array([14980.61289903]), array([0.]))
#
# 2019-12-09 13:14:33.807651	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:14:33.808652	ADF检验结果：(-2.4619381225996193, 0.12501191904947273, 14, 14987, {'1%': -3.430786406244813, '5%': -2.861732872668965, '10%': -2.566872661468546}, 113398.13708947628)
#
# 2019-12-09 13:14:33.808652	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:14:34.122748	第五步：相对波动率分析
# 2019-12-09 13:14:34.672462	样本平均数：11.6617, 中位数: 10.6554
# 2019-12-09 13:14:34.673463	偏度为：1.7457，属于分布偏左；峰度为：4.3972，属于分布陡峭
#
# 2019-12-09 13:14:34.673463	第六步：变化率分析
# 2019-12-09 13:14:36.084772	样本平均数：0.0044, 中位数: 0.0
# 2019-12-09 13:14:36.086775	偏度为：92.8414，属于分布偏左；峰度为：10412.7279，属于分布陡峭
#
# 2019-12-09 13:14:36.086775	ER位移路程比
# 2019-12-09 13:14:36.327498	样本平均数：0.263, 中位数: 0.2366
# 2019-12-09 13:14:36.328499	偏度为：0.6691，属于分布偏左；峰度为：-0.0769，属于分布平缓
#
# 2019-12-09 13:14:36.328499	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 13:14:36.331502	------------------------------------------------
# 2019-12-09 13:14:36.331502	合成60min周期K先并开始数据分析
# 2019-12-09 13:14:36.511672	第一步:画出行情图，检查数据断点
# 2019-12-09 13:14:36.699365	第二步：随机性检验：非纯随机性
# 2019-12-09 13:14:36.699365	白噪声检验结果:(array([9174.98569849]), array([0.]))
#
# 2019-12-09 13:14:37.029910	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 13:14:37.030911	ADF检验结果：(-2.4244155744635805, 0.13496352950980073, 9, 9186, {'1%': -3.4310620757987484, '5%': -2.861854692074167, '10%': -2.566937505529221}, 73828.99002932332)
#
# 2019-12-09 13:14:37.030911	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 13:14:37.398846	第五步：相对波动率分析
# 2019-12-09 13:14:37.924088	样本平均数：15.0362, 中位数: 13.8134
# 2019-12-09 13:14:37.925088	偏度为：1.6378，属于分布偏左；峰度为：3.9065，属于分布陡峭
#
# 2019-12-09 13:14:37.925088	第六步：变化率分析
# 2019-12-09 13:14:39.315973	样本平均数：0.0072, 中位数: 0.0
# 2019-12-09 13:14:39.317263	偏度为：72.8914，属于分布偏左；峰度为：6406.7002，属于分布陡峭
#
# 2019-12-09 13:14:39.317263	ER位移路程比
# 2019-12-09 13:14:39.523999	样本平均数：0.2726, 中位数: 0.2474
# 2019-12-09 13:14:39.525003	偏度为：0.6492，属于分布偏左；峰度为：-0.0018，属于分布平缓
#
# 2019-12-09 13:14:39.525003	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
