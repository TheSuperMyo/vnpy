# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="IF9999",
    exchange=Exchange.CFFEX,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.25/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 15:53:19.346205	开始加载历史数据
# 2019-12-08 15:53:37.610148	历史数据加载完成，数据量：307470

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-08 15:12:51.446884	第一步:画出行情图，检查数据断点
# 2019-12-08 15:12:56.323343	第二步：随机性检验：非纯随机性
# 2019-12-08 15:12:56.324344	白噪声检验结果:(array([307459.98029919]), array([0.]))
#
# 2019-12-08 15:14:20.253808	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:14:20.253808	ADF检验结果：(-1.8532705862218863, 0.35435304770852893, 85, 307384, {'1%': -3.43037127421925, '5%': -2.8615494029415154, '10%': -2.566775004844554}, 1706689.9994092686)
#
# 2019-12-08 15:14:20.254809	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:14:27.500655	第五步：相对波动率分析
# 2019-12-08 15:14:28.131733	样本平均数：3.6629, 中位数: 2.6651
# 2019-12-08 15:14:28.143744	偏度为：4.1552，属于分布偏左；峰度为：28.7835，属于分布陡峭
#
# 2019-12-08 15:14:28.144744	第六步：变化率分析
# 2019-12-08 15:14:29.653258	样本平均数：0.0003, 中位数: 0.0
# 2019-12-08 15:14:29.666270	偏度为：350.9208，属于分布偏左；峰度为：167023.0971，属于分布陡峭
#
# 2019-12-08 15:14:29.667271	ER位移路程比
# 2019-12-08 15:14:30.507048	样本平均数：0.2215, 中位数: 0.193
# 2019-12-08 15:14:30.520060	偏度为：0.8313，属于分布偏左；峰度为：0.3788，属于分布陡峭
#
# 2019-12-08 15:14:30.521061	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-08 15:54:20.096621	------------------------------------------------
# 2019-12-08 15:54:20.096621	合成5min周期K先并开始数据分析
# 2019-12-08 15:54:22.047429	第一步:画出行情图，检查数据断点
# 2019-12-08 15:54:22.527875	第二步：随机性检验：非纯随机性
# 2019-12-08 15:54:22.528876	白噪声检验结果:(array([61483.89813707]), array([0.]))
#
# 2019-12-08 15:54:28.485338	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:54:28.485338	ADF检验结果：(-1.9617312628751864, 0.3036004500963494, 60, 61433, {'1%': -3.4304564504950403, '5%': -2.8615870491255717, '10%': -2.566795042659883}, 440256.13399800076)
#
# 2019-12-08 15:54:28.485338	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:54:29.162954	第五步：相对波动率分析
# 2019-12-08 15:54:29.697958	样本平均数：8.8181, 中位数: 6.4408
# 2019-12-08 15:54:29.698959	偏度为：3.5851，属于分布偏左；峰度为：19.3189，属于分布陡峭
#
# 2019-12-08 15:54:29.698959	第六步：变化率分析
# 2019-12-08 15:54:31.109150	样本平均数：0.0017, 中位数: 0.0
# 2019-12-08 15:54:31.110151	偏度为：156.9062，属于分布偏左；峰度为：33405.0976，属于分布陡峭
#
# 2019-12-08 15:54:31.110151	ER位移路程比
# 2019-12-08 15:54:31.493005	样本平均数：0.2331, 中位数: 0.1988
# 2019-12-08 15:54:31.495008	偏度为：0.8322，属于分布偏左；峰度为：0.2255，属于分布陡峭
#
# 2019-12-08 15:54:31.495008	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:54:31.499011	------------------------------------------------
# 2019-12-08 15:54:31.499011	合成15min周期K先并开始数据分析
# 2019-12-08 15:54:32.216677	第一步:画出行情图，检查数据断点
# 2019-12-08 15:54:32.454391	第二步：随机性检验：非纯随机性
# 2019-12-08 15:54:32.454391	白噪声检验结果:(array([20488.28670142]), array([0.]))
#
# 2019-12-08 15:54:33.458812	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:54:33.458812	ADF检验结果：(-1.9102879492807818, 0.32723692014558947, 40, 20457, {'1%': -3.4306697008720843, '5%': -2.861681296723195, '10%': -2.5668452083547155}, 168267.03553944762)
#
# 2019-12-08 15:54:33.458812	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:54:33.767093	第五步：相对波动率分析
# 2019-12-08 15:54:34.278572	样本平均数：16.0398, 中位数: 11.6625
# 2019-12-08 15:54:34.279562	偏度为：3.1868，属于分布偏左；峰度为：14.2443，属于分布陡峭
#
# 2019-12-08 15:54:34.280574	第六步：变化率分析
# 2019-12-08 15:54:35.635814	样本平均数：0.0052, 中位数: 0.0
# 2019-12-08 15:54:35.636816	偏度为：91.5679，属于分布偏左；峰度为：11292.7678，属于分布陡峭
#
# 2019-12-08 15:54:35.637816	ER位移路程比
# 2019-12-08 15:54:35.882038	样本平均数：0.2443, 中位数: 0.2109
# 2019-12-08 15:54:35.883039	偏度为：0.7818，属于分布偏左；峰度为：0.1055，属于分布陡峭
#
# 2019-12-08 15:54:35.883039	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:54:35.894049	------------------------------------------------
# 2019-12-08 15:54:35.894049	合成30min周期K先并开始数据分析
# 2019-12-08 15:54:36.272393	第一步:画出行情图，检查数据断点
# 2019-12-08 15:54:36.457066	第二步：随机性检验：非纯随机性
# 2019-12-08 15:54:36.458067	白噪声检验结果:(array([10728.76075494]), array([0.]))
#
# 2019-12-08 15:54:36.849422	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:54:36.850423	ADF检验结果：(-1.9532786922094825, 0.30742672724356745, 38, 10699, {'1%': -3.43096135336252, '5%': -2.8618101837636893, '10%': -2.5669138136786525}, 95001.35638545275)
#
# 2019-12-08 15:54:36.850423	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:54:37.101652	第五步：相对波动率分析
# 2019-12-08 15:54:37.614118	样本平均数：22.6628, 中位数: 16.8911
# 2019-12-08 15:54:37.614118	偏度为：2.9202，属于分布偏左；峰度为：11.7962，属于分布陡峭
#
# 2019-12-08 15:54:37.615119	第六步：变化率分析
# 2019-12-08 15:54:38.973879	样本平均数：0.01, 中位数: 0.0
# 2019-12-08 15:54:38.974872	偏度为：66.1281，属于分布偏左；峰度为：5905.8202，属于分布陡峭
#
# 2019-12-08 15:54:38.974872	ER位移路程比
# 2019-12-08 15:54:39.186064	样本平均数：0.2491, 中位数: 0.2174
# 2019-12-08 15:54:39.187065	偏度为：0.7445，属于分布偏左；峰度为：0.0815，属于分布陡峭
#
# 2019-12-08 15:54:39.187065	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-08 15:54:39.190067	------------------------------------------------
# 2019-12-08 15:54:39.190067	合成60min周期K先并开始数据分析
# 2019-12-08 15:54:39.356219	第一步:画出行情图，检查数据断点
# 2019-12-08 15:54:39.522875	第二步：随机性检验：非纯随机性
# 2019-12-08 15:54:39.522875	白噪声检验结果:(array([6579.64926562]), array([0.]))
#
# 2019-12-08 15:54:39.735067	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-08 15:54:39.735067	ADF检验结果：(-2.0354705868362246, 0.271240225238806, 34, 6554, {'1%': -3.431348148158869, '5%': -2.8619810965745867, '10%': -2.56700479227849}, 61318.698536214295)
#
# 2019-12-08 15:54:39.735067	第四步：画出自相关性图，观察自相关特性
# 2019-12-08 15:54:40.048352	第五步：相对波动率分析
# 2019-12-08 15:54:40.559346	样本平均数：29.0408, 中位数: 21.9924
# 2019-12-08 15:54:40.560336	偏度为：2.6864，属于分布偏左；峰度为：9.5805，属于分布陡峭
#
# 2019-12-08 15:54:40.560336	第六步：变化率分析
# 2019-12-08 15:54:41.899559	样本平均数：0.0163, 中位数: 0.0
# 2019-12-08 15:54:41.900561	偏度为：51.7842，属于分布偏左；峰度为：3625.2993，属于分布陡峭
#
# 2019-12-08 15:54:41.900561	ER位移路程比
# 2019-12-08 15:54:42.092736	样本平均数：0.2555, 中位数: 0.2248
# 2019-12-08 15:54:42.092736	偏度为：0.8257，属于分布偏左；峰度为：0.4523，属于分布陡峭
#
# 2019-12-08 15:54:42.093737	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
