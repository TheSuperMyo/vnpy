# %%
from vnpy.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#import pdb
#pdb.set_trace()
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="NI9999",
    exchange=Exchange.SHFE,
    interval=Interval.MINUTE, 
    start=datetime(2014, 1, 1), 
    end=datetime(2019, 1, 1),
    rate = 0.5/10000,
    index_3to1 = ["ATR"],
    index_1to1 = ["STDDEV","SMA","RSI"],
    index_2to2 = [],
    index_2to1 = [],
    index_4to1 = [],
    window_index=20,
)
# Out:
# 2019-12-08 23:08:25.916416	开始加载历史数据
# 2019-12-08 23:08:50.830164	历史数据加载完成，数据量：421560

# %%
data = herramiento.base_analysis()
# Out:
# 2019-12-09 12:05:24.154158	第一步:画出行情图，检查数据断点
# 2019-12-09 12:05:37.054293	第二步：随机性检验：非纯随机性
# 2019-12-09 12:05:37.055295	白噪声检验结果:(array([421551.17086019]), array([0.]))
#
# 2019-12-09 12:08:15.702869	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:08:15.707873	ADF检验结果：(-1.7053814151270086, 0.42834196461283164, 66, 421493, {'1%': -3.4303655147056427, '5%': -2.8615468573144645, '10%': -2.5667736498984906}, 4764673.649899054)
#
# 2019-12-09 12:08:15.708874	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:08:31.325519	第五步：相对波动率分析
# 2019-12-09 12:08:32.227844	样本平均数：74.5335, 中位数: 68.7712
# 2019-12-09 12:08:32.244860	偏度为：3.0204，属于分布偏左；峰度为：34.6295，属于分布陡峭
#
# 2019-12-09 12:08:32.245860	第六步：变化率分析
# 2019-12-09 12:08:34.022972	样本平均数：0.0002, 中位数: 0.0
# 2019-12-09 12:08:34.038986	偏度为：459.5496，属于分布偏左；峰度为：266131.7098，属于分布陡峭
#
# 2019-12-09 12:08:34.038986	ER位移路程比
# 2019-12-09 12:08:34.953082	样本平均数：0.2046, 中位数: 0.1739
# 2019-12-09 12:08:34.972100	偏度为：0.9229，属于分布偏左；峰度为：0.6413，属于分布陡峭
#
# 2019-12-09 12:08:34.972100	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(data,['SMA'])
data["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
data["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","60min"]
herramiento.multi_time_frame_analysis(intervals)
# Out:
# 2019-12-09 12:20:37.670971	------------------------------------------------
# 2019-12-09 12:20:37.670971	合成5min周期K先并开始数据分析
# 2019-12-09 12:20:39.311089	第一步:画出行情图，检查数据断点
# 2019-12-09 12:20:40.236456	第二步：随机性检验：非纯随机性
# 2019-12-09 12:20:40.237457	白噪声检验结果:(array([84303.71142987]), array([0.]))
#
# 2019-12-09 12:20:51.094010	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:20:51.094010	ADF检验结果：(-1.716959280839936, 0.4223964077133459, 23, 84288, {'1%': -3.430427585174185, '5%': -2.8615742913610265, '10%': -2.5667882521038132}, 1083922.0345304161)
#
# 2019-12-09 12:20:51.094010	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:20:52.092131	第五步：相对波动率分析
# 2019-12-09 12:20:52.664664	样本平均数：182.0948, 中位数: 171.8266
# 2019-12-09 12:20:52.666667	偏度为：2.2645，属于分布偏左；峰度为：16.2653，属于分布陡峭
#
# 2019-12-09 12:20:52.666667	第六步：变化率分析
# 2019-12-09 12:20:54.113170	样本平均数：0.0009, 中位数: 0.0
# 2019-12-09 12:20:54.115173	偏度为：209.3561，属于分布偏左；峰度为：54541.0813，属于分布陡峭
#
# 2019-12-09 12:20:54.115173	ER位移路程比
# 2019-12-09 12:20:54.557364	样本平均数：0.2317, 中位数: 0.2
# 2019-12-09 12:20:54.559366	偏度为：0.8325，属于分布偏左；峰度为：0.2856，属于分布陡峭
#
# 2019-12-09 12:20:54.559366	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:20:54.564371	------------------------------------------------
# 2019-12-09 12:20:54.564371	合成15min周期K先并开始数据分析
# 2019-12-09 12:20:55.133168	第一步:画出行情图，检查数据断点
# 2019-12-09 12:20:55.430946	第二步：随机性检验：非纯随机性
# 2019-12-09 12:20:55.430946	白噪声检验结果:(array([28095.7725026]), array([0.]))
#
# 2019-12-09 12:20:57.360185	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:20:57.361186	ADF检验结果：(-1.6978405068634919, 0.4322254547782026, 22, 28081, {'1%': -3.430582894051902, '5%': -2.8616429326173884, '10%': -2.566824787936044}, 391691.6755540299)
#
# 2019-12-09 12:20:57.361186	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:20:57.764553	第五步：相对波动率分析
# 2019-12-09 12:20:58.319277	样本平均数：330.6696, 中位数: 316.2746
# 2019-12-09 12:20:58.320278	偏度为：1.7251，属于分布偏左；峰度为：8.23，属于分布陡峭
#
# 2019-12-09 12:20:58.321280	第六步：变化率分析
# 2019-12-09 12:20:59.741266	样本平均数：0.0027, 中位数: 0.0
# 2019-12-09 12:20:59.742267	偏度为：120.8661，属于分布偏左；峰度为：18177.4852，属于分布陡峭
#
# 2019-12-09 12:20:59.742267	ER位移路程比
# 2019-12-09 12:21:00.019518	样本平均数：0.2419, 中位数: 0.2079
# 2019-12-09 12:21:00.021520	偏度为：0.8376，属于分布偏左；峰度为：0.3095，属于分布陡峭
#
# 2019-12-09 12:21:00.021520	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:21:00.024522	------------------------------------------------
# 2019-12-09 12:21:00.024522	合成30min周期K先并开始数据分析
# 2019-12-09 12:21:00.364336	第一步:画出行情图，检查数据断点
# 2019-12-09 12:21:00.590049	第二步：随机性检验：非纯随机性
# 2019-12-09 12:21:00.590049	白噪声检验结果:(array([14503.7508804]), array([0.]))
#
# 2019-12-09 12:21:01.260659	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:21:01.260659	ADF检验结果：(-1.6931855610983855, 0.4346268567597313, 2, 14509, {'1%': -3.4308007862233376, '5%': -2.8617392275145823, '10%': -2.5668760440832568}, 211508.74450567857)
#
# 2019-12-09 12:21:01.260659	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:21:01.571301	第五步：相对波动率分析
# 2019-12-09 12:21:02.124046	样本平均数：470.268, 中位数: 452.3792
# 2019-12-09 12:21:02.124046	偏度为：1.5384，属于分布偏左；峰度为：6.2427，属于分布陡峭
#
# 2019-12-09 12:21:02.125041	第六步：变化率分析
# 2019-12-09 12:21:03.527345	样本平均数：0.0052, 中位数: 0.0
# 2019-12-09 12:21:03.528346	偏度为：87.0998，属于分布偏左；峰度为：9419.7345，属于分布陡峭
#
# 2019-12-09 12:21:03.528346	ER位移路程比
# 2019-12-09 12:21:03.764072	样本平均数：0.2465, 中位数: 0.2121
# 2019-12-09 12:21:03.765071	偏度为：0.8809，属于分布偏左；峰度为：0.4861，属于分布陡峭
#
# 2019-12-09 12:21:03.765071	第七步：计算相关技术指标，返回DataFrame
#
# 2019-12-09 12:21:03.768074	------------------------------------------------
# 2019-12-09 12:21:03.768074	合成60min周期K先并开始数据分析
# 2019-12-09 12:21:03.910280	第一步:画出行情图，检查数据断点
# 2019-12-09 12:21:04.094447	第二步：随机性检验：非纯随机性
# 2019-12-09 12:21:04.095448	白噪声检验结果:(array([8167.83757786]), array([0.]))
#
# 2019-12-09 12:21:04.371699	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-12-09 12:21:04.372700	ADF检验结果：(-1.7062880702244008, 0.42787562083825514, 9, 8166, {'1%': -3.4311510478554452, '5%': -2.8618940067464798, '10%': -2.5669584330133803}, 123586.19171285212)
#
# 2019-12-09 12:21:04.372700	第四步：画出自相关性图，观察自相关特性
# 2019-12-09 12:21:04.740567	第五步：相对波动率分析
# 2019-12-09 12:21:05.285877	样本平均数：639.5238, 中位数: 623.5668
# 2019-12-09 12:21:05.286878	偏度为：1.23，属于分布偏左；峰度为：3.5172，属于分布陡峭
#
# 2019-12-09 12:21:05.286878	第六步：变化率分析
# 2019-12-09 12:21:06.701610	样本平均数：0.0093, 中位数: 0.0
# 2019-12-09 12:21:06.702610	偏度为：65.3232，属于分布偏左；峰度为：5301.802，属于分布陡峭
#
# 2019-12-09 12:21:06.702610	ER位移路程比
# 2019-12-09 12:21:06.911801	样本平均数：0.2479, 中位数: 0.2156
# 2019-12-09 12:21:06.912801	偏度为：0.8451，属于分布偏左；峰度为：0.4638，属于分布陡峭
#
# 2019-12-09 12:21:06.912801	第七步：计算相关技术指标，返回DataFrame

# %%
herramiento.show_index(herramiento.results["5min"],['SMA'])
herramiento.results["5min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["5min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["15min"],['SMA'])
herramiento.results["15min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["15min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["30min"],['SMA'])
herramiento.results["30min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["30min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_index(herramiento.results["60min"],['SMA'])
herramiento.results["60min"]["RSI"].hist(bins=200, figsize=(20, 6), grid=False)
plt.show()
herramiento.results["60min"]["ER"].hist(bins=200, figsize=(20, 6), grid=False)

# %%
herramiento.show_chart(herramiento.results["15min"][:1500], boll_wide=2.8)
