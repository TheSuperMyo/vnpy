# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 6, 'atr_window': 8}, 目标：0.09138185741872716
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 14, 'atr_window': 24}, 目标：0.08626719868721
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.25, 'atr_ma_len': 6, 'atr_window': 8}, 目标：0.08210083344105848
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 28}, 目标：0.08101946591858201
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 8}, 目标：0.08028682337475254
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 12, 'atr_window': 32}, 目标：0.06685374328534706
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 8, 'atr_window': 8}, 目标：0.06260790418948892
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 16}, 目标：0.06048797130028594
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 24}, 目标：0.05983772915506586
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 20}, 目标：0.059287763300850525
# 2019-12-12 13:03:13.037020	参数：{'range_wide': 0.2, 'atr_ma_len': 12, 'atr_window': 24}, 目标：0.058220570239076716
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.25, 'atr_ma_len': 16, 'atr_window': 32}, 目标：0.05772839713354552
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 14, 'atr_window': 32}, 目标：0.05744554254799928
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 10, 'atr_window': 32}, 目标：0.05631372988737629
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.05, 'atr_ma_len': 16, 'atr_window': 32}, 目标：0.05223091230666553
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 10, 'atr_window': 28}, 目标：0.05042805485174671
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 14, 'atr_window': 20}, 目标：0.04905124783829519
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 16}, 目标：0.04446394379818447
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.25, 'atr_ma_len': 4, 'atr_window': 8}, 目标：0.04036042830268083
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 8}, 目标：0.03709972487302432
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 16}, 目标：0.03469246739478121
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 12, 'atr_window': 28}, 目标：0.03335116337787894
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.3, 'atr_ma_len': 16, 'atr_window': 32}, 目标：0.022443010752021385
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 4, 'atr_window': 12}, 目标：0.02099222966851558
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 28}, 目标：0.017856893289557314
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.3, 'atr_ma_len': 4, 'atr_window': 12}, 目标：0.01695499535572356
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 28}, 目标：0.014582955621194367
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 24}, 目标：0.014136852184726515
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 20}, 目标：0.0034395110335944576
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 12, 'atr_window': 8}, 目标：0.00036793468108512584
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 32}, 目标：-0.0003529219872699576
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 8, 'atr_window': 32}, 目标：-0.00211072510815741
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 14, 'atr_window': 28}, 目标：-0.0026022820121882595
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 8}, 目标：-0.011645551885398727
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 24}, 目标：-0.014764737972875771
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 16}, 目标：-0.020246770802091984
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 8, 'atr_window': 28}, 目标：-0.02100884777499401
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 20}, 目标：-0.042868385718526476
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 20}, 目标：-0.04593621643451771
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 12}, 目标：-0.055031076598674206
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 10, 'atr_window': 32}, 目标：-0.05876110599724998
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 32}, 目标：-0.07272744500871234
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 8}, 目标：-0.08003200728362983
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 28}, 目标：-0.0869737603196144
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.25, 'atr_ma_len': 4, 'atr_window': 12}, 目标：-0.0881334219655868
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 32}, 目标：-0.08813431672761958
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 28}, 目标：-0.12239998417520011
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 24}, 目标：-0.1389487638247023
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 12}, 目标：-0.17223426452387075
# 2019-12-12 13:03:13.038021	参数：{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 32}, 目标：-0.19761200735415854
# [("{'range_wide': 0.3, 'atr_ma_len': 10, 'atr_window': 16}",
#   0.6129653340930868,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 306,
#    'loss_days': 285,
#    'capital': 1000000,
#    'end_balance': 1349582.600200001,
#    'max_drawdown': -140293.89119999972,
#    'max_ddpercent': -12.325725671881287,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 349582.6002000008,
#    'daily_net_pnl': 287.72230469135866,
#    'total_commission': 50677.3998,
#    'daily_commission': 41.709794074074075,
#    'total_slippage': 100080.0,
#    'daily_slippage': 82.37037037037037,
#    'total_turnover': 1689246660.0,
#    'daily_turnover': 1390326.4691358025,
#    'total_trade_count': 1668,
#    'daily_trade_count': 1.3728395061728396,
#    'total_return': 34.95826002000009,
#    'annual_return': 6.9053353125926105,
#    'daily_return': 0.024674515193889142,
#    'return_std': 0.6236175594697619,
#    'sharpe_ratio': 0.6129653340930868,
#    'return_drawdown_ratio': 2.836202991256772}),
#  ("{'range_wide': 0.25, 'atr_ma_len': 10, 'atr_window': 16}",
#   0.5742880216593186,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 288,
#    'loss_days': 272,
#    'capital': 1000000,
#    'end_balance': 1329556.9744000016,
#    'max_drawdown': -166401.90719999967,
#    'max_ddpercent': -14.697870112454817,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': 329556.97440000135,
#    'daily_net_pnl': 271.24030814814927,
#    'total_commission': 47003.02559999999,
#    'daily_commission': 38.68561777777777,
#    'total_slippage': 93240.0,
#    'daily_slippage': 76.74074074074075,
#    'total_turnover': 1566767520.0,
#    'daily_turnover': 1289520.5925925926,
#    'total_trade_count': 1554,
#    'daily_trade_count': 1.2790123456790123,
#    'total_return': 32.95569744000015,
#    'annual_return': 6.509767395555585,
#    'daily_return': 0.023444097513415262,
#    'return_std': 0.6324255134137826,
#    'sharpe_ratio': 0.5742880216593186,
#    'return_drawdown_ratio': 2.242209053954957}),
#  ("{'range_wide': 0.05, 'atr_ma_len': 4, 'atr_window': 20}",
#   0.5548863507260332,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 267,
#    'loss_days': 278,
#    'capital': 1000000,
#    'end_balance': 1312965.8350000016,
#    'max_drawdown': -162074.06759999937,
#    'max_ddpercent': -14.970971696661788,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': 312965.8350000015,
#    'daily_net_pnl': 257.5850493827173,
#    'total_commission': 37374.16499999999,
#    'daily_commission': 30.760629629629623,
#    'total_slippage': 73560.0,
#    'daily_slippage': 60.54320987654321,
#    'total_turnover': 1245805500.0,
#    'daily_turnover': 1025354.3209876543,
#    'total_trade_count': 1226,
#    'daily_trade_count': 1.0090534979423869,
#    'total_return': 31.296583500000153,
#    'annual_return': 6.1820411851852155,
#    'daily_return': 0.022349708724277727,
#    'return_std': 0.6239839892868584,
#    'sharpe_ratio': 0.5548863507260332,
#    'return_drawdown_ratio': 2.090484447778272}),
#  ("{'range_wide': 0.05, 'atr_ma_len': 4, 'atr_window': 16}",
#   0.5542118970564827,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 269,
#    'loss_days': 290,
#    'capital': 1000000,
#    'end_balance': 1312740.550600002,
#    'max_drawdown': -164163.31619999907,
#    'max_ddpercent': -15.152579664967197,
#    'max_drawdown_duration': 170,
#    'total_net_pnl': 312740.5506000018,
#    'daily_net_pnl': 257.3996301234583,
#    'total_commission': 38319.4494,
#    'daily_commission': 31.53864148148148,
#    'total_slippage': 75600.0,
#    'daily_slippage': 62.22222222222222,
#    'total_turnover': 1277314980.0,
#    'daily_turnover': 1051288.049382716,
#    'total_trade_count': 1260,
#    'daily_trade_count': 1.037037037037037,
#    'total_return': 31.274055060000205,
#    'annual_return': 6.177591122963004,
#    'daily_return': 0.02233558534317683,
#    'return_std': 0.624348560695745,
#    'sharpe_ratio': 0.5542118970564827,
#    'return_drawdown_ratio': 2.0639426257105185}),
#  ("{'range_wide': 0.3, 'atr_ma_len': 12, 'atr_window': 12}",
#   0.5410801196177399,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 319,
#    'loss_days': 282,
#    'capital': 1000000,
#    'end_balance': 1305369.2152000016,
#    'max_drawdown': -167023.00859999983,
#    'max_ddpercent': -13.651977766215706,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 305369.2152000015,
#    'daily_net_pnl': 251.33268740740863,
#    'total_commission': 51750.784799999994,
#    'daily_commission': 42.59323851851851,
#    'total_slippage': 102720.0,
#    'daily_slippage': 84.54320987654322,
#    'total_turnover': 1725026160.0,
#    'daily_turnover': 1419774.6172839506,
#    'total_trade_count': 1712,
#    'daily_trade_count': 1.4090534979423868,
#    'total_return': 30.53692152000016,
#    'annual_return': 6.03198449777781,
#    'daily_return': 0.02193299788347749,
#    'return_std': 0.6279745453972565,
#    'sharpe_ratio': 0.5410801196177399,
#    'return_drawdown_ratio': 2.2368130129518162}),
#  ("{'range_wide': 0.3, 'atr_ma_len': 10, 'atr_window': 12}",
#   0.5353618295234439,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 313,
#    'loss_days': 297,
#    'capital': 1000000,
#    'end_balance': 1308011.407600002,
#    'max_drawdown': -146911.29179999977,
#    'max_ddpercent': -13.124304871221101,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': 308011.40760000143,
#    'daily_net_pnl': 253.50733135802588,
#    'total_commission': 52108.592399999994,
#    'daily_commission': 42.88773037037036,
#    'total_slippage': 103080.0,
#    'daily_slippage': 84.8395061728395,
#    'total_turnover': 1736953080.0,
#    'daily_turnover': 1429591.012345679,
#    'total_trade_count': 1718,
#    'daily_trade_count': 1.4139917695473252,
#    'total_return': 30.8011407600002,
#    'annual_return': 6.084175952592632,
#    'daily_return': 0.022099421761621926,
#    'return_std': 0.6394979075722649,
#    'sharpe_ratio': 0.5353618295234439,
#    'return_drawdown_ratio': 2.3468778775126418}),
#  ("{'range_wide': 0.1, 'atr_ma_len': 16, 'atr_window': 12}",
#   0.5203320178511532,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 225,
#    'loss_days': 207,
#    'capital': 1000000,
#    'end_balance': 1273581.766600001,
#    'max_drawdown': -180714.69899999956,
#    'max_ddpercent': -17.158311842868375,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': 273581.7666000007,
#    'daily_net_pnl': 225.1701782716055,
#    'total_commission': 35358.2334,
#    'daily_commission': 29.101426666666665,
#    'total_slippage': 70560.0,
#    'daily_slippage': 58.074074074074076,
#    'total_turnover': 1178607780.0,
#    'daily_turnover': 970047.5555555555,
#    'total_trade_count': 1176,
#    'daily_trade_count': 0.9679012345679012,
#    'total_return': 27.35817666000009,
#    'annual_return': 5.404084278518536,
#    'daily_return': 0.01990396868968076,
#    'return_std': 0.592604234326547,
#    'sharpe_ratio': 0.5203320178511532,
#    'return_drawdown_ratio': 1.5944561977040388}),
#  ("{'range_wide': 0.1, 'atr_ma_len': 4, 'atr_window': 16}",
#   0.5120770327703549,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 290,
#    'loss_days': 303,
#    'capital': 1000000,
#    'end_balance': 1294426.7086000023,
#    'max_drawdown': -152049.071999999,
#    'max_ddpercent': -14.13050888706743,
#    'max_drawdown_duration': 140,
#    'total_net_pnl': 294426.70860000217,
#    'daily_net_pnl': 242.32650913580426,
#    'total_commission': 44273.2914,
#    'daily_commission': 36.43892296296296,
#    'total_slippage': 87360.0,
#    'daily_slippage': 71.90123456790124,
#    'total_turnover': 1475776380.0,
#    'daily_turnover': 1214630.7654320989,
#    'total_trade_count': 1456,
#    'daily_trade_count': 1.1983539094650206,
#    'total_return': 29.44267086000023,
#    'annual_return': 5.815836219259305,
#    'daily_return': 0.021179282934349314,
#    'return_std': 0.6407396140817393,
#    'sharpe_ratio': 0.5120770327703549,
#    'return_drawdown_ratio': 2.0836242413708717}),
#  ("{'range_wide': 0.25, 'atr_ma_len': 10, 'atr_window': 12}",
#   0.5050545473684795,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 296,
#    'loss_days': 282,
#    'capital': 1000000,
#    'end_balance': 1290958.7884000028,
#    'max_drawdown': -179624.19719999935,
#    'max_ddpercent': -15.758877843187612,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': 290958.78840000223,
#    'daily_net_pnl': 239.47225382716232,
#    'total_commission': 48401.211599999995,
#    'daily_commission': 39.836388148148146,
#    'total_slippage': 96000.0,
#    'daily_slippage': 79.01234567901234,
#    'total_turnover': 1613373720.0,
#    'daily_turnover': 1327879.6049382717,
#    'total_trade_count': 1600,
#    'daily_trade_count': 1.316872427983539,
#    'total_return': 29.095878840000267,
#    'annual_return': 5.747334091851905,
#    'daily_return': 0.02101935712955995,
#    'return_std': 0.6447431908884736,
#    'sharpe_ratio': 0.5050545473684795,
#    'return_drawdown_ratio': 1.8463166685804404}),
#  ("{'range_wide': 0.3, 'atr_ma_len': 16, 'atr_window': 12}",
#   0.505027840373584,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 322,
#    'loss_days': 283,
#    'capital': 1000000,
#    'end_balance': 1306053.6058,
#    'max_drawdown': -182055.73440000007,
#    'max_ddpercent': -15.15362048712844,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 306053.60579999996,
#    'daily_net_pnl': 251.8959718518518,
#    'total_commission': 53766.394199999995,
#    'daily_commission': 44.25217629629629,
#    'total_slippage': 107160.0,
#    'daily_slippage': 88.19753086419753,
#    'total_turnover': 1792213140.0,
#    'daily_turnover': 1475072.5432098766,
#    'total_trade_count': 1786,
#    'daily_trade_count': 1.4699588477366254,
#    'total_return': 30.605360580000006,
#    'annual_return': 6.045503324444446,
#    'daily_return': 0.021976137925971296,
#    'return_std': 0.674126924474368,
#    'sharpe_ratio': 0.505027840373584,
#    'return_drawdown_ratio': 2.019673160351109}),
#  ("{'range_wide': 0.3, 'atr_ma_len': 12, 'atr_window': 16}",
#   0.5041268414418348,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 311,
#    'loss_days': 272,
#    'capital': 1000000,
#    'end_balance': 1298386.0660000006,
#    'max_drawdown': -199875.95160000038,
#    'max_ddpercent': -16.41622630728776,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 298386.0660000005,
#    'daily_net_pnl': 245.58523950617325,
#    'total_commission': 50933.933999999994,
#    'daily_commission': 41.92093333333333,
#    'total_slippage': 101280.0,
#    'daily_slippage': 83.35802469135803,
#    'total_turnover': 1697797800.0,
#    'daily_turnover': 1397364.4444444445,
#    'total_trade_count': 1688,
#    'daily_trade_count': 1.3893004115226337,
#    'total_return': 29.838606600000062,
#    'annual_return': 5.8940457481481605,
#    'daily_return': 0.021491523085671798,
#    'return_std': 0.6604394303416018,
#    'sharpe_ratio': 0.5041268414418348,
#    'return_drawdown_ratio': 1.8176288533957172}),
#  ("{'range_wide': 0.05, 'atr_ma_len': 4, 'atr_window': 24}",
#   0.5040823270275389,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 260,
#    'loss_days': 274,
#    'capital': 1000000,
#    'end_balance': 1282978.2958000014,
#    'max_drawdown': -174687.6515999994,
#    'max_ddpercent': -16.118533256343987,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': 282978.29580000124,
#    'daily_net_pnl': 232.90394716049485,
#    'total_commission': 36761.70419999999,
#    'daily_commission': 30.25654666666666,
#    'total_slippage': 72600.0,
#    'daily_slippage': 59.75308641975309,
#    'total_turnover': 1225390140.0,
#    'daily_turnover': 1008551.5555555555,
#    'total_trade_count': 1210,
#    'daily_trade_count': 0.9958847736625515,
#    'total_return': 28.297829580000133,
#    'annual_return': 5.589694731851878,
#    'daily_return': 0.020448111548498737,
#    'return_std': 0.6284306450950073,
#    'sharpe_ratio': 0.5040823270275389,
#    'return_drawdown_ratio': 1.7556082262548658}),
#  ("{'range_wide': 0.3, 'atr_ma_len': 14, 'atr_window': 8}",
#   0.499540550242912,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 335,
#    'loss_days': 298,
#    'capital': 1000000,
#    'end_balance': 1289096.4484000008,
#    'max_drawdown': -179923.6368000001,
#    'max_ddpercent': -15.741736205814183,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 289096.4484000006,
#    'daily_net_pnl': 237.93946370370418,
#    'total_commission': 53983.55159999999,
#    'daily_commission': 44.43090666666666,
#    'total_slippage': 107160.0,
#    'daily_slippage': 88.19753086419753,
#    'total_turnover': 1799451720.0,
#    'daily_turnover': 1481030.2222222222,
#    'total_trade_count': 1786,
#    'daily_trade_count': 1.4699588477366254,
#    'total_return': 28.90964484000007,
#    'annual_return': 5.710547128888903,
#    'daily_return': 0.02090053871297705,
#    'return_std': 0.6481751146949823,
#    'sharpe_ratio': 0.499540550242912,
#    'return_drawdown_ratio': 1.8364965885606914}),
#  ("{'range_wide': 0.1, 'atr_ma_len': 10, 'atr_window': 16}",
#   0.49372709157637545,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 220,
#    'loss_days': 222,
#    'capital': 1000000,
#    'end_balance': 1256677.6318000008,
#    'max_drawdown': -156345.3833999997,
#    'max_ddpercent': -14.60765886029659,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': 256677.63180000082,
#    'daily_net_pnl': 211.25731012345747,
#    'total_commission': 34262.3682,
#    'daily_commission': 28.199479999999998,
#    'total_slippage': 67920.0,
#    'daily_slippage': 55.901234567901234,
#    'total_turnover': 1142078940.0,
#    'daily_turnover': 939982.6666666666,
#    'total_trade_count': 1132,
#    'daily_trade_count': 0.9316872427983539,
#    'total_return': 25.66776318000008,
#    'annual_return': 5.070175442962979,
#    'daily_return': 0.018804233606916375,
#    'return_std': 0.590030280617202,
#    'sharpe_ratio': 0.49372709157637545,
#    'return_drawdown_ratio': 1.757144209450612}),
#  ("{'range_wide': 0.1, 'atr_ma_len': 4, 'atr_window': 20}",
#   0.49190189321649247,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 287,
#    'loss_days': 292,
#    'capital': 1000000,
#    'end_balance': 1281436.183600002,
#    'max_drawdown': -148610.75939999917,
#    'max_ddpercent': -13.838778500060378,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': 281436.1836000017,
#    'daily_net_pnl': 231.63471901234706,
#    'total_commission': 43523.816399999996,
# ...
#    'daily_trade_count': 1.1275720164609053,
#    'total_return': -0.8627644799999001,
#    'annual_return': -0.1704226133333136,
#    'daily_return': -0.000713175176302134,
#    'return_std': 0.7483006026442116,
#    'sharpe_ratio': -0.014764737972875771,
#    'return_drawdown_ratio': -0.04079177462820992}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 16}",
#   -0.020246770802091984,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 260,
#    'loss_days': 267,
#    'capital': 1000000,
#    'end_balance': 988246.1218000016,
#    'max_drawdown': -241391.02139999985,
#    'max_ddpercent': -23.760569985689685,
#    'max_drawdown_duration': 244,
#    'total_net_pnl': -11753.878199998493,
#    'daily_net_pnl': -9.673973827159253,
#    'total_commission': 45533.8782,
#    'daily_commission': 37.47644296296296,
#    'total_slippage': 91320.0,
#    'daily_slippage': 75.1604938271605,
#    'total_turnover': 1517795940.0,
#    'daily_turnover': 1249214.7654320989,
#    'total_trade_count': 1522,
#    'daily_trade_count': 1.2526748971193415,
#    'total_return': -1.1753878199998402,
#    'annual_return': -0.23217537185182027,
#    'daily_return': -0.0009731276645013897,
#    'return_std': 0.7445942417559607,
#    'sharpe_ratio': -0.020246770802091984,
#    'return_drawdown_ratio': -0.04946799764095486}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 8, 'atr_window': 28}",
#   -0.02100884777499401,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 261,
#    'loss_days': 268,
#    'capital': 1000000,
#    'end_balance': 988223.7256000014,
#    'max_drawdown': -221625.30959999957,
#    'max_ddpercent': -21.690090008365992,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': -11776.274399998661,
#    'daily_net_pnl': -9.692406913579145,
#    'total_commission': 44776.274399999995,
#    'daily_commission': 36.852900740740736,
#    'total_slippage': 88680.0,
#    'daily_slippage': 72.98765432098766,
#    'total_turnover': 1492542480.0,
#    'daily_turnover': 1228430.024691358,
#    'total_trade_count': 1478,
#    'daily_trade_count': 1.2164609053497943,
#    'total_return': -1.177627439999862,
#    'annual_return': -0.23261776592589867,
#    'daily_return': -0.0009749929179932048,
#    'return_std': 0.7189601970561059,
#    'sharpe_ratio': -0.02100884777499401,
#    'return_drawdown_ratio': -0.05429334039396076}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 20}",
#   -0.042868385718526476,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 259,
#    'loss_days': 265,
#    'capital': 1000000,
#    'end_balance': 975515.3350000016,
#    'max_drawdown': -213902.81940000085,
#    'max_ddpercent': -21.214798645693524,
#    'max_drawdown_duration': 432,
#    'total_net_pnl': -24484.66499999845,
#    'daily_net_pnl': -20.15198765431971,
#    'total_commission': 45784.66499999999,
#    'daily_commission': 37.682851851851844,
#    'total_slippage': 91800.0,
#    'daily_slippage': 75.55555555555556,
#    'total_turnover': 1526155500.0,
#    'daily_turnover': 1256095.061728395,
#    'total_trade_count': 1530,
#    'daily_trade_count': 1.2592592592592593,
#    'total_return': -2.4484664999998462,
#    'annual_return': -0.4836477037036734,
#    'daily_return': -0.002040279744774802,
#    'return_std': 0.7373237261604768,
#    'sharpe_ratio': -0.042868385718526476,
#    'return_drawdown_ratio': -0.11541313876655013}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 20}",
#   -0.04593621643451771,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 255,
#    'loss_days': 267,
#    'capital': 1000000,
#    'end_balance': 973634.9050000005,
#    'max_drawdown': -205255.61759999942,
#    'max_ddpercent': -20.369585241982588,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': -26365.094999999466,
#    'daily_net_pnl': -21.69966666666623,
#    'total_commission': 44905.095,
#    'daily_commission': 36.958925925925925,
#    'total_slippage': 89640.0,
#    'daily_slippage': 73.77777777777777,
#    'total_turnover': 1496836500.0,
#    'daily_turnover': 1231964.1975308643,
#    'total_trade_count': 1494,
#    'daily_trade_count': 1.2296296296296296,
#    'total_return': -2.6365094999999505,
#    'annual_return': -0.5207919999999903,
#    'daily_return': -0.002199085306372047,
#    'return_std': 0.7416388574892254,
#    'sharpe_ratio': -0.04593621643451771,
#    'return_drawdown_ratio': -0.12943363689929197}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 12}",
#   -0.055031076598674206,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 296,
#    'loss_days': 325,
#    'capital': 1000000,
#    'end_balance': 967949.8612000006,
#    'max_drawdown': -226841.7180000001,
#    'max_ddpercent': -21.135579052797492,
#    'max_drawdown_duration': 140,
#    'total_net_pnl': -32050.13879999929,
#    'daily_net_pnl': -26.37871506172781,
#    'total_commission': 51370.1388,
#    'daily_commission': 42.27994962962963,
#    'total_slippage': 101280.0,
#    'daily_slippage': 83.35802469135803,
#    'total_turnover': 1712337960.0,
#    'daily_turnover': 1409331.6543209876,
#    'total_trade_count': 1688,
#    'daily_trade_count': 1.3893004115226337,
#    'total_return': -3.2050138799999406,
#    'annual_return': -0.6330891614814698,
#    'daily_return': -0.002766611278142311,
#    'return_std': 0.7788355284281631,
#    'sharpe_ratio': -0.055031076598674206,
#    'return_drawdown_ratio': -0.15164069420542925}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 10, 'atr_window': 32}",
#   -0.05876110599724998,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 247,
#    'loss_days': 263,
#    'capital': 1000000,
#    'end_balance': 964819.2010000013,
#    'max_drawdown': -225761.4852,
#    'max_ddpercent': -21.895097513788812,
#    'max_drawdown_duration': 148,
#    'total_net_pnl': -35180.79899999871,
#    'daily_net_pnl': -28.95539012345573,
#    'total_commission': 43400.799,
#    'daily_commission': 35.720822222222225,
#    'total_slippage': 85920.0,
#    'daily_slippage': 70.71604938271605,
#    'total_turnover': 1446693300.0,
#    'daily_turnover': 1190694.0740740742,
#    'total_trade_count': 1432,
#    'daily_trade_count': 1.1786008230452676,
#    'total_return': -3.518079899999871,
#    'annual_return': -0.6949293629629375,
#    'daily_return': -0.002947699726193403,
#    'return_std': 0.7771393513050282,
#    'sharpe_ratio': -0.05876110599724998,
#    'return_drawdown_ratio': -0.1606788870332411}),
#  ("{'range_wide': 0.15000000000000002, 'atr_ma_len': 16, 'atr_window': 32}",
#   -0.07272744500871234,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 224,
#    'loss_days': 241,
#    'capital': 1000000,
#    'end_balance': 957922.0083999999,
#    'max_drawdown': -213885.16979999945,
#    'max_ddpercent': -20.581407208991358,
#    'max_drawdown_duration': 229,
#    'total_net_pnl': -42077.99160000012,
#    'daily_net_pnl': -34.632091851851946,
#    'total_commission': 40637.991599999994,
#    'daily_commission': 33.44690666666666,
#    'total_slippage': 81360.0,
#    'daily_slippage': 66.96296296296296,
#    'total_turnover': 1354599720.0,
#    'daily_turnover': 1114896.888888889,
#    'total_trade_count': 1356,
#    'daily_trade_count': 1.1160493827160494,
#    'total_return': -4.207799160000003,
#    'annual_return': -0.831170204444445,
#    'daily_return': -0.003538182319446082,
#    'return_std': 0.7536808805764385,
#    'sharpe_ratio': -0.07272744500871234,
#    'return_drawdown_ratio': -0.20444662103384992}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 6, 'atr_window': 8}",
#   -0.08003200728362983,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 311,
#    'loss_days': 348,
#    'capital': 1000000,
#    'end_balance': 949557.2962000004,
#    'max_drawdown': -225348.36120000016,
#    'max_ddpercent': -21.56124890057047,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': -50442.70379999955,
#    'daily_net_pnl': -41.51662864197494,
#    'total_commission': 54702.70379999999,
#    'daily_commission': 45.02280148148147,
#    'total_slippage': 107520.0,
#    'daily_slippage': 88.49382716049382,
#    'total_turnover': 1823423460.0,
#    'daily_turnover': 1500760.049382716,
#    'total_trade_count': 1792,
#    'daily_trade_count': 1.4748971193415639,
#    'total_return': -5.0442703799999595,
#    'annual_return': -0.9963990874073995,
#    'daily_return': -0.00432090703042877,
#    'return_std': 0.8364054101531548,
#    'sharpe_ratio': -0.08003200728362983,
#    'return_drawdown_ratio': -0.23395075133456197}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 28}",
#   -0.0869737603196144,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 253,
#    'loss_days': 263,
#    'capital': 1000000,
#    'end_balance': 949152.8752000004,
#    'max_drawdown': -237874.7789999994,
#    'max_ddpercent': -23.343557844393324,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': -50847.12479999984,
#    'daily_net_pnl': -41.84948543209863,
#    'total_commission': 46047.1248,
#    'daily_commission': 37.898868148148146,
#    'total_slippage': 91920.0,
#    'daily_slippage': 75.65432098765432,
#    'total_turnover': 1534904160.0,
#    'daily_turnover': 1263295.6049382717,
#    'total_trade_count': 1532,
#    'daily_trade_count': 1.2609053497942386,
#    'total_return': -5.084712479999965,
#    'annual_return': -1.0043876503703635,
#    'daily_return': -0.00429509485707729,
#    'return_std': 0.7650505527511368,
#    'sharpe_ratio': -0.0869737603196144,
#    'return_drawdown_ratio': -0.21782080152024536}),
#  ("{'range_wide': 0.25, 'atr_ma_len': 4, 'atr_window': 12}",
#   -0.0881334219655868,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 372,
#    'loss_days': 392,
#    'capital': 1000000,
#    'end_balance': 942386.8978000028,
#    'max_drawdown': -360344.8925999993,
#    'max_ddpercent': -32.27660974640777,
#    'max_drawdown_duration': 199,
#    'total_net_pnl': -57613.10219999732,
#    'daily_net_pnl': -47.41819111110891,
#    'total_commission': 62833.1022,
#    'daily_commission': 51.71448740740741,
#    'total_slippage': 124080.0,
#    'daily_slippage': 102.12345679012346,
#    'total_turnover': 2094436740.0,
#    'daily_turnover': 1723816.2469135802,
#    'total_trade_count': 2068,
#    'daily_trade_count': 1.7020576131687242,
#    'total_return': -5.761310219999716,
#    'annual_return': -1.1380365866666107,
#    'daily_return': -0.004944772231571489,
#    'return_std': 0.8691831124470852,
#    'sharpe_ratio': -0.0881334219655868,
#    'return_drawdown_ratio': -0.17849799793923282}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 32}",
#   -0.08813431672761958,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 253,
#    'loss_days': 261,
#    'capital': 1000000,
#    'end_balance': 946930.0791999995,
#    'max_drawdown': -250977.43319999962,
#    'max_ddpercent': -24.5110306187076,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': -53069.92080000053,
#    'daily_net_pnl': -43.67894716049427,
#    'total_commission': 44909.92079999999,
#    'daily_commission': 36.96289777777777,
#    'total_slippage': 89760.0,
#    'daily_slippage': 73.87654320987654,
#    'total_turnover': 1496997360.0,
#    'daily_turnover': 1232096.5925925926,
#    'total_trade_count': 1496,
#    'daily_trade_count': 1.231275720164609,
#    'total_return': -5.30699208000005,
#    'annual_return': -1.0482947318518618,
#    'daily_return': -0.004488067697451491,
#    'return_std': 0.7888964069512708,
#    'sharpe_ratio': -0.08813431672761958,
#    'return_drawdown_ratio': -0.21651444048009896}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 14, 'atr_window': 28}",
#   -0.12239998417520011,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 254,
#    'loss_days': 266,
#    'capital': 1000000,
#    'end_balance': 928719.8548,
#    'max_drawdown': -219362.6543999993,
#    'max_ddpercent': -21.691919747094754,
#    'max_drawdown_duration': 174,
#    'total_net_pnl': -71280.14519999994,
#    'daily_net_pnl': -58.66678617283946,
#    'total_commission': 44880.1452,
#    'daily_commission': 36.93839111111111,
#    'total_slippage': 89520.0,
#    'daily_slippage': 73.67901234567901,
#    'total_turnover': 1496004840.0,
#    'daily_turnover': 1231279.7037037036,
#    'total_trade_count': 1492,
#    'daily_trade_count': 1.2279835390946503,
#    'total_return': -7.128014520000003,
#    'annual_return': -1.4080028681481487,
#    'daily_return': -0.006086266773381436,
#    'return_std': 0.7703272190016464,
#    'sharpe_ratio': -0.12239998417520011,
#    'return_drawdown_ratio': -0.3286022907656513}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 24}",
#   -0.1389487638247023,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 257,
#    'loss_days': 271,
#    'capital': 1000000,
#    'end_balance': 916918.0780000009,
#    'max_drawdown': -261465.66120000114,
#    'max_ddpercent': -25.73756382212617,
#    'max_drawdown_duration': 432,
#    'total_net_pnl': -83081.92199999905,
#    'daily_net_pnl': -68.3801827160486,
#    'total_commission': 46481.92199999999,
#    'daily_commission': 38.25672592592592,
#    'total_slippage': 92880.0,
#    'daily_slippage': 76.44444444444444,
#    'total_turnover': 1549397400.0,
#    'daily_turnover': 1275224.1975308643,
#    'total_trade_count': 1548,
#    'daily_trade_count': 1.2740740740740741,
#    'total_return': -8.308192199999908,
#    'annual_return': -1.6411243851851671,
#    'daily_return': -0.007138859891755655,
#    'return_std': 0.795939012643806,
#    'sharpe_ratio': -0.1389487638247023,
#    'return_drawdown_ratio': -0.32280414173689154}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 4, 'atr_window': 12}",
#   -0.17223426452387075,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 335,
#    'loss_days': 369,
#    'capital': 1000000,
#    'end_balance': 890007.2152000028,
#    'max_drawdown': -299939.01659999904,
#    'max_ddpercent': -28.221872231009566,
#    'max_drawdown_duration': 199,
#    'total_net_pnl': -109992.78479999749,
#    'daily_net_pnl': -90.52904098765225,
#    'total_commission': 57312.7848,
#    'daily_commission': 47.171016296296294,
#    'total_slippage': 112920.0,
#    'daily_slippage': 92.93827160493827,
#    'total_turnover': 1910426160.0,
#    'daily_turnover': 1572367.2098765431,
#    'total_trade_count': 1882,
#    'daily_trade_count': 1.5489711934156378,
#    'total_return': -10.999278479999719,
#    'annual_return': -2.172696983703648,
#    'daily_return': -0.009651466892268914,
#    'return_std': 0.8681192593950804,
#    'sharpe_ratio': -0.17223426452387075,
#    'return_drawdown_ratio': -0.38974304716445973}),
#  ("{'range_wide': 0.2, 'atr_ma_len': 16, 'atr_window': 32}",
#   -0.19761200735415854,
#   {'start_date': datetime.date(2014, 1, 9),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 1215,
#    'profit_days': 250,
#    'loss_days': 263,
#    'capital': 1000000,
#    'end_balance': 881278.9372,
#    'max_drawdown': -266020.2707999995,
#    'max_ddpercent': -26.04175129060652,
#    'max_drawdown_duration': 229,
#    'total_net_pnl': -118721.06279999993,
#    'daily_net_pnl': -97.71280888888883,
#    'total_commission': 46001.0628,
#    'daily_commission': 37.86095703703704,
#    'total_slippage': 91680.0,
#    'daily_slippage': 75.45679012345678,
#    'total_turnover': 1533368760.0,
#    'daily_turnover': 1262031.9012345679,
#    'total_trade_count': 1528,
#    'daily_trade_count': 1.2576131687242798,
#    'total_return': -11.872106279999993,
#    'annual_return': -2.345107413333332,
#    'daily_return': -0.010401735708292826,
#    'return_std': 0.8154514436497647,
#    'sharpe_ratio': -0.19761200735415854,
#    'return_drawdown_ratio': -0.45588739971886466})]

# %%
#%%
#%%
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="