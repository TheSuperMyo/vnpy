{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 82, 'rsi_len': 20}",
#   0.8900570806487085,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 46,
#    'loss_days': 40,
#    'capital': 500000,
#    'end_balance': 681152.8834999991,
#    'max_drawdown': -17812.231499999878,
#    'max_ddpercent': -3.184054660992012,
#    'max_drawdown_duration': 131,
#    'total_net_pnl': 181152.88349999918,
#    'daily_net_pnl': 77.2506965884858,
#    'total_commission': 3947.1165,
#    'daily_commission': 1.683205330490405,
#    'total_slippage': 10560.0,
#    'daily_slippage': 4.50319829424307,
#    'total_turnover': 157884660.0,
#    'daily_turnover': 67328.2132196162,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.07505330490405117,
#    'total_return': 36.23057669999981,
#    'annual_return': 3.708033436247315,
#    'daily_return': 0.013184591942979372,
#    'return_std': 0.22948507969615778,
#    'sharpe_ratio': 0.8900570806487085,
#    'return_drawdown_ratio': 11.37875462499502}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 82, 'rsi_len': 20}",
#   0.8900570806487085,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 46,
#    'loss_days': 40,
#    'capital': 500000,
#    'end_balance': 681152.8834999991,
#    'max_drawdown': -17812.231499999878,
#    'max_ddpercent': -3.184054660992012,
#    'max_drawdown_duration': 131,
#    'total_net_pnl': 181152.88349999918,
#    'daily_net_pnl': 77.2506965884858,
#    'total_commission': 3947.1165,
#    'daily_commission': 1.683205330490405,
#    'total_slippage': 10560.0,
#    'daily_slippage': 4.50319829424307,
#    'total_turnover': 157884660.0,
#    'daily_turnover': 67328.2132196162,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.07505330490405117,
#    'total_return': 36.23057669999981,
#    'annual_return': 3.708033436247315,
#    'daily_return': 0.013184591942979372,
#    'return_std': 0.22948507969615778,
#    'sharpe_ratio': 0.8900570806487085,
#    'return_drawdown_ratio': 11.37875462499502}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 82, 'rsi_len': 20}",
#   0.8900570806487085,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 46,
#    'loss_days': 40,
#    'capital': 500000,
#    'end_balance': 681152.8834999991,
#    'max_drawdown': -17812.231499999878,
#    'max_ddpercent': -3.184054660992012,
#    'max_drawdown_duration': 131,
#    'total_net_pnl': 181152.88349999918,
#    'daily_net_pnl': 77.2506965884858,
#    'total_commission': 3947.1165,
#    'daily_commission': 1.683205330490405,
#    'total_slippage': 10560.0,
#    'daily_slippage': 4.50319829424307,
#    'total_turnover': 157884660.0,
#    'daily_turnover': 67328.2132196162,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.07505330490405117,
#    'total_return': 36.23057669999981,
#    'annual_return': 3.708033436247315,
#    'daily_return': 0.013184591942979372,
#    'return_std': 0.22948507969615778,
#    'sharpe_ratio': 0.8900570806487085,
#    'return_drawdown_ratio': 11.37875462499502}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 82, 'rsi_len': 20}",
#   0.8900570806487085,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 46,
#    'loss_days': 40,
#    'capital': 500000,
#    'end_balance': 681152.8834999991,
#    'max_drawdown': -17812.231499999878,
#    'max_ddpercent': -3.184054660992012,
#    'max_drawdown_duration': 131,
#    'total_net_pnl': 181152.88349999918,
#    'daily_net_pnl': 77.2506965884858,
#    'total_commission': 3947.1165,
#    'daily_commission': 1.683205330490405,
#    'total_slippage': 10560.0,
#    'daily_slippage': 4.50319829424307,
#    'total_turnover': 157884660.0,
#    'daily_turnover': 67328.2132196162,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.07505330490405117,
#    'total_return': 36.23057669999981,
#    'annual_return': 3.708033436247315,
#    'daily_return': 0.013184591942979372,
#    'return_std': 0.22948507969615778,
#    'sharpe_ratio': 0.8900570806487085,
#    'return_drawdown_ratio': 11.37875462499502}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 82, 'rsi_len': 20}",
#   0.8900570806487085,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 46,
#    'loss_days': 40,
#    'capital': 500000,
#    'end_balance': 681152.8834999991,
#    'max_drawdown': -17812.231499999878,
#    'max_ddpercent': -3.184054660992012,
#    'max_drawdown_duration': 131,
#    'total_net_pnl': 181152.88349999918,
#    'daily_net_pnl': 77.2506965884858,
#    'total_commission': 3947.1165,
#    'daily_commission': 1.683205330490405,
#    'total_slippage': 10560.0,
#    'daily_slippage': 4.50319829424307,
#    'total_turnover': 157884660.0,
#    'daily_turnover': 67328.2132196162,
#    'total_trade_count': 176,
#    'daily_trade_count': 0.07505330490405117,
#    'total_return': 36.23057669999981,
#    'annual_return': 3.708033436247315,
#    'daily_return': 0.013184591942979372,
#    'return_std': 0.22948507969615778,
#    'sharpe_ratio': 0.8900570806487085,
#    'return_drawdown_ratio': 11.37875462499502}),
#  ("{'rsi_fliter_slow': 55, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 70, 'rsi_len': 17}",
#   0.8476730588340934,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 667,
#    'loss_days': 875,
#    'capital': 500000,
#    'end_balance': 1161654.7265000038,
#    'max_drawdown': -183660.08099999884,
#    'max_ddpercent': -20.234648330758876,
#    'max_drawdown_duration': 118,
#    'total_net_pnl': 661654.7265000032,
#    'daily_net_pnl': 282.15553368870076,
#    'total_commission': 94645.27350000001,
#    'daily_commission': 40.360457782515994,
#    'total_slippage': 240960.0,
#    'daily_slippage': 102.7547974413646,
#    'total_turnover': 3785810940.0,
#    'daily_turnover': 1614418.3113006398,
#    'total_trade_count': 4016,
#    'daily_trade_count': 1.7125799573560767,
#    'total_return': 132.3309453000008,
#    'annual_return': 13.54346561705765,
#    'daily_return': 0.0358504008675999,
#    'return_std': 0.6551960290258544,
#    'sharpe_ratio': 0.8476730588340934,
#    'return_drawdown_ratio': 6.539819379951531}),
#  ("{'rsi_fliter_slow': 55, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 79, 'rsi_len': 5}",
#   0.8268136432797433,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1077,
#    'loss_days': 1257,
#    'capital': 500000,
#    'end_balance': 1439059.069999999,
#    'max_drawdown': -329501.1509999996,
#    'max_ddpercent': -30.598528869845186,
#    'max_drawdown_duration': 697,
#    'total_net_pnl': 939059.0699999977,
#    'daily_net_pnl': 400.45162899786686,
#    'total_commission': 230820.93,
#    'daily_commission': 98.43110021321961,
#    'total_slippage': 584880.0,
#    'daily_slippage': 249.41577825159914,
#    'total_turnover': 9232837200.0,
#    'daily_turnover': 3937244.008528785,
#    'total_trade_count': 9748,
#    'daily_trade_count': 4.156929637526653,
#    'total_return': 187.8118139999998,
#    'annual_return': 19.221678191897634,
#    'daily_return': 0.044976271885598246,
#    'return_std': 0.8427163891318751,
#    'sharpe_ratio': 0.8268136432797433,
#    'return_drawdown_ratio': 6.137936068720222}),
#  ("{'rsi_fliter_slow': 55, 'rsi_fliter_fast': 73, 'rsi_len': 20}",
#   0.815456442783001,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 334,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 897849.7685000007,
#    'max_drawdown': -74073.0824999999,
#    'max_ddpercent': -8.954323340696925,
#    'max_drawdown_duration': 499,
#    'total_net_pnl': 397849.76850000053,
#    'daily_net_pnl': 169.65874989339042,
#    'total_commission': 41530.2315,
#    'daily_commission': 17.710120042643926,
#    'total_slippage': 107760.0,
#    'daily_slippage': 45.953091684434966,
#    'total_turnover': 1661209260.0,
#    'daily_turnover': 708404.8017057569,
#    'total_trade_count': 1796,
#    'daily_trade_count': 0.7658848614072494,
#    'total_return': 79.56995370000016,
#    'annual_return': 8.143619994882746,
#    'daily_return': 0.02496764174359153,
#    'return_std': 0.47433194757520847,
#    'sharpe_ratio': 0.815456442783001,
#    'return_drawdown_ratio': 8.886205095851178}),
#  ("{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 73, 'rsi_len': 20}",
#   0.815456442783001,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 334,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 897849.7685000007,
#    'max_drawdown': -74073.0824999999,
#    'max_ddpercent': -8.954323340696925,
#    'max_drawdown_duration': 499,
#    'total_net_pnl': 397849.76850000053,
#    'daily_net_pnl': 169.65874989339042,
#    'total_commission': 41530.2315,
#    'daily_commission': 17.710120042643926,
#    'total_slippage': 107760.0,
#    'daily_slippage': 45.953091684434966,
#    'total_turnover': 1661209260.0,
#    'daily_turnover': 708404.8017057569,
#    'total_trade_count': 1796,
#    'daily_trade_count': 0.7658848614072494,
#    'total_return': 79.56995370000016,
#    'annual_return': 8.143619994882746,
#    'daily_return': 0.02496764174359153,
#    'return_std': 0.47433194757520847,
#    'sharpe_ratio': 0.815456442783001,
#    'return_drawdown_ratio': 8.886205095851178}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 73, 'rsi_len': 20}",
#   0.815456442783001,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 334,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 897849.7685000007,
#    'max_drawdown': -74073.0824999999,
#    'max_ddpercent': -8.954323340696925,
#    'max_drawdown_duration': 499,
#    'total_net_pnl': 397849.76850000053,
#    'daily_net_pnl': 169.65874989339042,
#    'total_commission': 41530.2315,
#    'daily_commission': 17.710120042643926,
#    'total_slippage': 107760.0,
#    'daily_slippage': 45.953091684434966,
#    'total_turnover': 1661209260.0,
#    'daily_turnover': 708404.8017057569,
#    'total_trade_count': 1796,
#    'daily_trade_count': 0.7658848614072494,
#    'total_return': 79.56995370000016,
#    'annual_return': 8.143619994882746,
#    'daily_return': 0.02496764174359153,
#    'return_std': 0.47433194757520847,
#    'sharpe_ratio': 0.815456442783001,
#    'return_drawdown_ratio': 8.886205095851178}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 73, 'rsi_len': 20}",
#   0.815456442783001,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 334,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 897849.7685000007,
#    'max_drawdown': -74073.0824999999,
#    'max_ddpercent': -8.954323340696925,
#    'max_drawdown_duration': 499,
#    'total_net_pnl': 397849.76850000053,
#    'daily_net_pnl': 169.65874989339042,
#    'total_commission': 41530.2315,
#    'daily_commission': 17.710120042643926,
#    'total_slippage': 107760.0,
#    'daily_slippage': 45.953091684434966,
#    'total_turnover': 1661209260.0,
#    'daily_turnover': 708404.8017057569,
#    'total_trade_count': 1796,
#    'daily_trade_count': 0.7658848614072494,
#    'total_return': 79.56995370000016,
#    'annual_return': 8.143619994882746,
#    'daily_return': 0.02496764174359153,
#    'return_std': 0.47433194757520847,
#    'sharpe_ratio': 0.815456442783001,
#    'return_drawdown_ratio': 8.886205095851178}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 73, 'rsi_len': 20}",
#   0.815456442783001,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 334,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 897849.7685000007,
#    'max_drawdown': -74073.0824999999,
#    'max_ddpercent': -8.954323340696925,
#    'max_drawdown_duration': 499,
# ...
#    'total_slippage': 769560.0,
#    'daily_slippage': 328.1705756929638,
#    'total_turnover': 12260525280.0,
#    'daily_turnover': 5228368.989339019,
#    'total_trade_count': 12826,
#    'daily_trade_count': 5.469509594882729,
#    'total_return': 119.4173735999986,
#    'annual_return': 12.221820752238662,
#    'daily_return': 0.03318671155258908,
#    'return_std': 1.1193435330709967,
#    'sharpe_ratio': 0.45931057753442855,
#    'return_drawdown_ratio': 3.1301402616704213}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 70, 'rsi_len': 5}",
#   0.45931057753442855,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1118,
#    'loss_days': 1227,
#    'capital': 500000,
#    'end_balance': 1097086.867999993,
#    'max_drawdown': -380517.5940000005,
#    'max_ddpercent': -38.15080591189568,
#    'max_drawdown_duration': 698,
#    'total_net_pnl': 597086.8679999933,
#    'daily_net_pnl': 254.62126567163892,
#    'total_commission': 306513.132,
#    'daily_commission': 130.70922473347548,
#    'total_slippage': 769560.0,
#    'daily_slippage': 328.1705756929638,
#    'total_turnover': 12260525280.0,
#    'daily_turnover': 5228368.989339019,
#    'total_trade_count': 12826,
#    'daily_trade_count': 5.469509594882729,
#    'total_return': 119.4173735999986,
#    'annual_return': 12.221820752238662,
#    'daily_return': 0.03318671155258908,
#    'return_std': 1.1193435330709967,
#    'sharpe_ratio': 0.45931057753442855,
#    'return_drawdown_ratio': 3.1301402616704213}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 70, 'rsi_len': 5}",
#   0.45931057753442855,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1118,
#    'loss_days': 1227,
#    'capital': 500000,
#    'end_balance': 1097086.867999993,
#    'max_drawdown': -380517.5940000005,
#    'max_ddpercent': -38.15080591189568,
#    'max_drawdown_duration': 698,
#    'total_net_pnl': 597086.8679999933,
#    'daily_net_pnl': 254.62126567163892,
#    'total_commission': 306513.132,
#    'daily_commission': 130.70922473347548,
#    'total_slippage': 769560.0,
#    'daily_slippage': 328.1705756929638,
#    'total_turnover': 12260525280.0,
#    'daily_turnover': 5228368.989339019,
#    'total_trade_count': 12826,
#    'daily_trade_count': 5.469509594882729,
#    'total_return': 119.4173735999986,
#    'annual_return': 12.221820752238662,
#    'daily_return': 0.03318671155258908,
#    'return_std': 1.1193435330709967,
#    'sharpe_ratio': 0.45931057753442855,
#    'return_drawdown_ratio': 3.1301402616704213}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 70, 'rsi_len': 5}",
#   0.45931057753442855,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 1118,
#    'loss_days': 1227,
#    'capital': 500000,
#    'end_balance': 1097086.867999993,
#    'max_drawdown': -380517.5940000005,
#    'max_ddpercent': -38.15080591189568,
#    'max_drawdown_duration': 698,
#    'total_net_pnl': 597086.8679999933,
#    'daily_net_pnl': 254.62126567163892,
#    'total_commission': 306513.132,
#    'daily_commission': 130.70922473347548,
#    'total_slippage': 769560.0,
#    'daily_slippage': 328.1705756929638,
#    'total_turnover': 12260525280.0,
#    'daily_turnover': 5228368.989339019,
#    'total_trade_count': 12826,
#    'daily_trade_count': 5.469509594882729,
#    'total_return': 119.4173735999986,
#    'annual_return': 12.221820752238662,
#    'daily_return': 0.03318671155258908,
#    'return_std': 1.1193435330709967,
#    'sharpe_ratio': 0.45931057753442855,
#    'return_drawdown_ratio': 3.1301402616704213}),
#  ("{'rsi_fliter_slow': 55, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 85, 'rsi_len': 5}",
#   0.3974110847087726,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 951,
#    'loss_days': 1223,
#    'capital': 500000,
#    'end_balance': 908267.7064999995,
#    'max_drawdown': -460190.1209999979,
#    'max_ddpercent': -48.6313205390842,
#    'max_drawdown_duration': 717,
#    'total_net_pnl': 408267.7065,
#    'daily_net_pnl': 174.1013673773987,
#    'total_commission': 162272.2935,
#    'daily_commission': 69.1992722814499,
#    'total_slippage': 412920.0,
#    'daily_slippage': 176.0852878464819,
#    'total_turnover': 6490891740.0,
#    'daily_turnover': 2767970.8912579957,
#    'total_trade_count': 6882,
#    'daily_trade_count': 2.934754797441365,
#    'total_return': 81.65354129999992,
#    'annual_return': 8.356865634115131,
#    'daily_return': 0.025479107808425536,
#    'return_std': 0.9932300734949998,
#    'sharpe_ratio': 0.3974110847087726,
#    'return_drawdown_ratio': 1.679031957077462}),
#  ("{'rsi_fliter_slow': 55, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572}),
#  ("{'rsi_fliter_slow': 58, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572}),
#  ("{'rsi_fliter_slow': 61, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572}),
#  ("{'rsi_fliter_slow': 64, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572}),
#  ("{'rsi_fliter_slow': 67, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572}),
#  ("{'rsi_fliter_slow': 70, 'rsi_fliter_fast': 85, 'rsi_len': 20}",
#   0.2630346857470827,
#   {'start_date': datetime.date(2010, 4, 26),
#    'end_date': datetime.date(2019, 12, 13),
#    'total_days': 2345,
#    'profit_days': 16,
#    'loss_days': 19,
#    'capital': 500000,
#    'end_balance': 537996.4954999997,
#    'max_drawdown': -26042.238000000012,
#    'max_ddpercent': -4.960309118488807,
#    'max_drawdown_duration': 1511,
#    'total_net_pnl': 37996.495499999786,
#    'daily_net_pnl': 16.203196375266433,
#    'total_commission': 1663.5045,
#    'daily_commission': 0.7093835820895522,
#    'total_slippage': 4320.0,
#    'daily_slippage': 1.8422174840085288,
#    'total_turnover': 66540180.0,
#    'daily_turnover': 28375.34328358209,
#    'total_trade_count': 72,
#    'daily_trade_count': 0.03070362473347548,
#    'total_return': 7.5992990999999455,
#    'annual_return': 0.7777534260127876,
#    'daily_return': 0.0031234092869021563,
#    'return_std': 0.18395919332392915,
#    'sharpe_ratio': 0.2630346857470827,
#    'return_drawdown_ratio': 1.5320212749795572})]

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2010, 1, 1),
    end=datetime(2020, 1, 1),
    rate=0.25/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine.add_strategy(TSMyoRSIStrategy, {'rsi_fliter_slow':55, 'rsi_fliter_fast':79, 'rsi_len':5,'setup_bar':30, 'trailing_stop':0.6, 'fixed_size':1})
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2020-02-25 00:39:27.901995	开始加载历史数据
# 2020-02-25 00:39:27.901995	加载进度： [1%]
# 2020-02-25 00:39:27.901995	加载进度： [2%]
# 2020-02-25 00:39:27.902996	加载进度： [2%]
# 2020-02-25 00:39:27.902996	加载进度： [3%]
# 2020-02-25 00:39:27.902996	加载进度： [4%]
# 2020-02-25 00:39:27.902996	加载进度： [5%]
# 2020-02-25 00:39:27.902996	加载进度： [6%]
# 2020-02-25 00:39:27.902996	加载进度： [7%]
# 2020-02-25 00:39:27.902996	加载进度： [7%]
# 2020-02-25 00:39:27.902996	加载进度： [8%]
# 2020-02-25 00:39:27.902996	加载进度： [9%]
# 2020-02-25 00:39:27.902996	加载进度： [10%]
# 2020-02-25 00:39:27.902996	加载进度：# [11%]
# 2020-02-25 00:39:27.902996	加载进度：# [12%]
# 2020-02-25 00:39:27.902996	加载进度：# [12%]
# 2020-02-25 00:39:27.902996	加载进度：# [13%]
# 2020-02-25 00:39:27.902996	加载进度：# [14%]
# 2020-02-25 00:39:27.902996	加载进度：# [15%]
# 2020-02-25 00:39:27.902996	加载进度：# [16%]
# 2020-02-25 00:39:27.902996	加载进度：# [16%]
# 2020-02-25 00:39:27.902996	加载进度：# [17%]
# 2020-02-25 00:39:27.902996	加载进度：# [18%]
# 2020-02-25 00:39:27.902996	加载进度：# [19%]
# 2020-02-25 00:39:27.902996	加载进度：# [20%]
	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 40, 'fit_bar': 5}, 目标：0.3633621987464526
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 50, 'fit_bar': 5}, 目标：0.35152558772244485
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：0.28495183449827083
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 60, 'fit_bar': 5}, 目标：0.28399999000655024
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 40, 'fit_bar': 10}, 目标：0.2830090874769267
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：0.2736002409356326
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 20, 'fit_bar': 10}, 目标：0.2693305582925126
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 40, 'fit_bar': 10}, 目标：0.25414803657258794
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 10, 'fit_bar': 15}, 目标：0.24767798374452682
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 30, 'fit_bar': 15}, 目标：0.21476282604982302
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：0.20479357468125667
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 50, 'fit_bar': 10}, 目标：0.18555527982486336
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 60, 'fit_bar': 5}, 目标：0.16260947531242756
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 20, 'fit_bar': 15}, 目标：0.16136883360085724
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 10, 'fit_bar': 5}, 目标：0.15484121714611762
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 30, 'fit_bar': 10}, 目标：0.13835275685788107
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：0.13808800951436273
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 40, 'fit_bar': 10}, 目标：0.123900228050318
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 10, 'fit_bar': 15}, 目标：0.11792979986624054
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 60, 'fit_bar': 15}, 目标：0.09845890301326299
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 30, 'fit_bar': 10}, 目标：0.09193110190125059
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 50, 'fit_bar': 10}, 目标：0.09043998759256494
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 60, 'fit_bar': 5}, 目标：0.0898991293532696
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 30, 'fit_bar': 10}, 目标：0.07018040338572572
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 30, 'fit_bar': 10}, 目标：0.06817221303414955
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 40, 'fit_bar': 10}, 目标：0.06766696694997137
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 60, 'fit_bar': 5}, 目标：0.056764761728980664
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 50, 'fit_bar': 15}, 目标：0.05248485819918965
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 50, 'fit_bar': 15}, 目标：0.049163650526304066
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 10, 'fit_bar': 5}, 目标：0.04251644853535712
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 40, 'fit_bar': 15}, 目标：0.02654150993472818
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 40, 'fit_bar': 15}, 目标：0.022286694915641312
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 10, 'fit_bar': 10}, 目标：0.016301540683795926
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 10, 'fit_bar': 5}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 10, 'fit_bar': 10}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 10, 'fit_bar': 15}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 20, 'fit_bar': 5}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 20, 'fit_bar': 10}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 20, 'fit_bar': 15}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 30, 'fit_bar': 5}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 30, 'fit_bar': 10}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 30, 'fit_bar': 15}, 目标：0
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 30, 'fit_bar': 15}, 目标：-0.006516730008884848
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 50, 'fit_bar': 10}, 目标：-0.029742812939321572
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 50, 'fit_bar': 10}, 目标：-0.04240386257358842
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 30, 'fit_bar': 5}, 目标：-0.06437055883546447
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 10, 'fit_bar': 5}, 目标：-0.10857130630420705
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 20, 'fit_bar': 15}, 目标：-0.11181749513090988
# 2020-02-24 22:45:01.158711	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 20, 'fit_bar': 5}, 目标：-0.13130998856911638
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 40, 'fit_bar': 15}, 目标：-0.1462084543276706
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 30, 'fit_bar': 15}, 目标：-0.1511244898846992
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 50, 'fit_bar': 15}, 目标：-0.15212006058281816
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 40, 'fit_bar': 5}, 目标：-0.18872959595138197
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 30, 'fit_bar': 15}, 目标：-0.2165313719455
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 5, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：-0.2402080710361725
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 50, 'fit_bar': 15}, 目标：-0.31494420213307994
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 30, 'LLT_len_slow': 20, 'fit_bar': 15}, 目标：-0.4186993813273378
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 15, 'LLT_len_slow': 10, 'fit_bar': 15}, 目标：-0.4373850017280615
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 40, 'fit_bar': 15}, 目标：-0.45170526947761724
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 50, 'fit_bar': 15}, 目标：-0.4564471127176972
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 10}, 目标：-0.46315646908494223
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 5}, 目标：-0.5147802334344155
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 25, 'LLT_len_slow': 10, 'fit_bar': 10}, 目标：-0.7004067042826468
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 10, 'LLT_len_slow': 60, 'fit_bar': 10}, 目标：-0.7445824258875645
# 2020-02-24 22:45:01.159713	参数：{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 15}, 目标：-0.9385774376307544
# [("{'LLT_len_fast': 5, 'LLT_len_slow': 10, 'fit_bar': 10}",
#   1.3606533335158117,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 477,
#    'loss_days': 665,
#    'capital': 500000,
#    'end_balance': 2033957.218000004,
#    'max_drawdown': -478625.1870000011,
#    'max_ddpercent': -20.635849619485153,
#    'max_drawdown_duration': 1197,
#    'total_net_pnl': 1533957.218000005,
#    'daily_net_pnl': 1338.531603839446,
#    'total_commission': 124522.782,
#    'daily_commission': 108.65862303664922,
#    'total_slippage': 164640.0,
#    'daily_slippage': 143.66492146596858,
#    'total_turnover': 4980911280.0,
#    'daily_turnover': 4346344.921465969,
#    'total_trade_count': 4116,
#    'daily_trade_count': 3.5916230366492146,
#    'total_return': 306.79144360000083,
#    'annual_return': 64.24951698429336,
#    'daily_return': 0.12581850443545228,
#    'return_std': 1.4325264498168904,
#    'sharpe_ratio': 1.3606533335158117,
#    'return_drawdown_ratio': 14.866916034817228}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 60, 'fit_bar': 15}",
#   1.2761269647874622,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 276,
#    'loss_days': 346,
#    'capital': 500000,
#    'end_balance': 1624785.3209999993,
#    'max_drawdown': -124797.66500000097,
#    'max_ddpercent': -10.479289144589918,
#    'max_drawdown_duration': 323,
#    'total_net_pnl': 1124785.320999999,
#    'daily_net_pnl': 981.4880636998247,
#    'total_commission': 21174.679000000004,
#    'daily_commission': 18.477032286212918,
#    'total_slippage': 27880.0,
#    'daily_slippage': 24.328097731239094,
#    'total_turnover': 846987160.0,
#    'daily_turnover': 739081.2914485165,
#    'total_trade_count': 697,
#    'daily_trade_count': 0.6082024432809773,
#    'total_return': 224.95706419999988,
#    'annual_return': 47.1114270575916,
#    'daily_return': 0.1028379474223809,
#    'return_std': 1.2484326989873455,
#    'sharpe_ratio': 1.2761269647874622,
#    'return_drawdown_ratio': 21.466824809976462}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 40, 'fit_bar': 5}",
#   1.0864882866797685,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 420,
#    'loss_days': 584,
#    'capital': 500000,
#    'end_balance': 1740229.661000001,
#    'max_drawdown': -379699.41300000064,
#    'max_ddpercent': -34.64959848107314,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 1240229.6609999998,
#    'daily_net_pnl': 1082.224835078534,
#    'total_commission': 56050.33900000001,
#    'daily_commission': 48.90954537521816,
#    'total_slippage': 73720.0,
#    'daily_slippage': 64.3280977312391,
#    'total_turnover': 2242013560.0,
#    'daily_turnover': 1956381.815008726,
#    'total_trade_count': 1843,
#    'daily_trade_count': 1.6082024432809774,
#    'total_return': 248.0459322000002,
#    'annual_return': 51.94679208376967,
#    'daily_return': 0.11306944019075199,
#    'return_std': 1.6122256049792074,
#    'sharpe_ratio': 1.0864882866797685,
#    'return_drawdown_ratio': 7.158695715781291}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 20, 'fit_bar': 5}",
#   0.9947475930558234,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 466,
#    'loss_days': 676,
#    'capital': 500000,
#    'end_balance': 1520359.7339999953,
#    'max_drawdown': -781311.7650000043,
#    'max_ddpercent': -36.61613361080628,
#    'max_drawdown_duration': 1215,
#    'total_net_pnl': 1020359.7339999953,
#    'daily_net_pnl': 890.3662600348999,
#    'total_commission': 138440.266,
#    'daily_commission': 120.80302443280978,
#    'total_slippage': 182960.0,
#    'daily_slippage': 159.65095986038395,
#    'total_turnover': 5537610640.0,
#    'daily_turnover': 4832120.977312391,
#    'total_trade_count': 4574,
#    'daily_trade_count': 3.9912739965095985,
#    'total_return': 204.07194679999904,
#    'annual_return': 42.73758048167519,
#    'daily_return': 0.09827245855941573,
#    'return_std': 1.5304690277149198,
#    'sharpe_ratio': 0.9947475930558234,
#    'return_drawdown_ratio': 5.573279499389106}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 10, 'fit_bar': 5}",
#   0.9811119474019366,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 525,
#    'loss_days': 621,
#    'capital': 500000,
#    'end_balance': 2000390.033999998,
#    'max_drawdown': -344884.80900000175,
#    'max_ddpercent': -20.920328060976544,
#    'max_drawdown_duration': 394,
#    'total_net_pnl': 1500390.0339999967,
#    'daily_net_pnl': 1309.2408673647442,
#    'total_commission': 236009.96600000001,
#    'daily_commission': 205.9423787085515,
#    'total_slippage': 313560.0,
#    'daily_slippage': 273.6125654450262,
#    'total_turnover': 9440398640.0,
#    'daily_turnover': 8237695.148342059,
#    'total_trade_count': 7839,
#    'daily_trade_count': 6.840314136125654,
#    'total_return': 300.07800679999957,
#    'annual_return': 62.84356163350777,
#    'daily_return': 0.12273480217822512,
#    'return_std': 1.9380045104744361,
#    'sharpe_ratio': 0.9811119474019366,
#    'return_drawdown_ratio': 14.343848046998177}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 30, 'fit_bar': 5}",
#   0.9510506246341496,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 436,
#    'loss_days': 589,
#    'capital': 500000,
#    'end_balance': 1700637.1209999996,
#    'max_drawdown': -321890.9170000013,
#    'max_ddpercent': -25.793250962083867,
#    'max_drawdown_duration': 333,
#    'total_net_pnl': 1200637.1209999989,
#    'daily_net_pnl': 1047.6763708551473,
#    'total_commission': 61402.879,
#    'daily_commission': 53.58017364746946,
#    'total_slippage': 81080.0,
#    'daily_slippage': 70.75043630017451,
#    'total_turnover': 2456115160.0,
#    'daily_turnover': 2143206.9458987783,
#    'total_trade_count': 2027,
#    'daily_trade_count': 1.768760907504363,
#    'total_return': 240.1274241999999,
#    'annual_return': 50.288465801047096,
#    'daily_return': 0.10681938381060696,
#    'return_std': 1.7400112416087834,
#    'sharpe_ratio': 0.9510506246341496,
#    'return_drawdown_ratio': 9.309699833998735}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 20, 'fit_bar': 5}",
#   0.8690125481371879,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 502,
#    'loss_days': 643,
#    'capital': 500000,
#    'end_balance': 1862844.9370000032,
#    'max_drawdown': -286695.2330000007,
#    'max_ddpercent': -24.539175373517498,
#    'max_drawdown_duration': 19,
#    'total_net_pnl': 1362844.9370000025,
#    'daily_net_pnl': 1189.2189677137892,
#    'total_commission': 191035.06300000002,
#    'daily_commission': 166.6972626527051,
#    'total_slippage': 253160.0,
#    'daily_slippage': 220.90750436300175,
#    'total_turnover': 7641402520.0,
#    'daily_turnover': 6667890.506108202,
#    'total_trade_count': 6329,
#    'daily_trade_count': 5.522687609075043,
#    'total_return': 272.5689874000006,
#    'annual_return': 57.08251045026191,
#    'daily_return': 0.11027299966494249,
#    'return_std': 1.9658426896327665,
#    'sharpe_ratio': 0.8690125481371879,
#    'return_drawdown_ratio': 11.107503950363185}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 40, 'fit_bar': 10}",
#   0.8285062767635438,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 420,
#    'loss_days': 582,
#    'capital': 500000,
#    'end_balance': 1457328.217000001,
#    'max_drawdown': -222996.38199999998,
#    'max_ddpercent': -19.58285148470551,
#    'max_drawdown_duration': 401,
#    'total_net_pnl': 957328.2170000004,
#    'daily_net_pnl': 835.3649363001749,
#    'total_commission': 63351.783,
#    'daily_commission': 55.280787958115184,
#    'total_slippage': 83840.0,
#    'daily_slippage': 73.1588132635253,
#    'total_turnover': 2534071320.0,
#    'daily_turnover': 2211231.5183246075,
#    'total_trade_count': 2096,
#    'daily_trade_count': 1.8289703315881327,
#    'total_return': 191.4656434000002,
#    'annual_return': 40.09751694240842,
#    'daily_return': 0.09334659262214097,
#    'return_std': 1.7454535169632321,
#    'sharpe_ratio': 0.8285062767635438,
#    'return_drawdown_ratio': 9.777209593277957}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 60, 'fit_bar': 15}",
#   0.7981737341515321,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 317,
#    'loss_days': 413,
#    'capital': 500000,
#    'end_balance': 1307947.301000001,
#    'max_drawdown': -279961.7970000008,
#    'max_ddpercent': -37.42434872065565,
#    'max_drawdown_duration': 116,
#    'total_net_pnl': 807947.3010000007,
#    'daily_net_pnl': 705.0150968586394,
#    'total_commission': 29932.699,
#    'daily_commission': 26.119283595113437,
#    'total_slippage': 39840.0,
#    'daily_slippage': 34.76439790575916,
#    'total_turnover': 1197307960.0,
#    'daily_turnover': 1044771.3438045376,
#    'total_trade_count': 996,
#    'daily_trade_count': 0.8691099476439791,
#    'total_return': 161.5894602000002,
#    'annual_return': 33.8407246492147,
#    'daily_return': 0.08390978560453306,
#    'return_std': 1.6286238863805769,
#    'sharpe_ratio': 0.7981737341515321,
#    'return_drawdown_ratio': 4.317762786097972}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 40, 'fit_bar': 15}",
#   0.7753624712982984,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 297,
#    'loss_days': 327,
#    'capital': 500000,
#    'end_balance': 1179735.3440000021,
#    'max_drawdown': -185762.66999999993,
#    'max_ddpercent': -21.77581413304366,
#    'max_drawdown_duration': 243,
#    'total_net_pnl': 679735.3440000019,
#    'daily_net_pnl': 593.137298429321,
#    'total_commission': 15064.656,
#    'daily_commission': 13.145424083769635,
#    'total_slippage': 19560.0,
#    'daily_slippage': 17.06806282722513,
#    'total_turnover': 602586240.0,
#    'daily_turnover': 525816.9633507853,
#    'total_trade_count': 489,
#    'daily_trade_count': 0.42670157068062825,
#    'total_return': 135.94706880000044,
#    'annual_return': 28.47059032460742,
#    'daily_return': 0.07490726955813047,
#    'return_std': 1.4966657182813063,
#    'sharpe_ratio': 0.7753624712982984,
#    'return_drawdown_ratio': 6.243030362465662}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 20, 'fit_bar': 10}",
#   0.7661381223654327,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 493,
#    'loss_days': 633,
#    'capital': 500000,
#    'end_balance': 1357500.6120000011,
#    'max_drawdown': -477700.74200000125,
#    'max_ddpercent': -30.59951159886014,
#    'max_drawdown_duration': 1093,
#    'total_net_pnl': 857500.6120000018,
#    'daily_net_pnl': 748.2553333333349,
#    'total_commission': 100179.388,
#    'daily_commission': 87.41656893542758,
#    'total_slippage': 131760.0,
#    'daily_slippage': 114.9738219895288,
#    'total_turnover': 4007175520.0,
#    'daily_turnover': 3496662.757417103,
#    'total_trade_count': 3294,
#    'daily_trade_count': 2.8743455497382198,
#    'total_return': 171.5001224000002,
#    'annual_return': 35.91625600000005,
#    'daily_return': 0.08912526888124202,
#    'return_std': 1.8021851257711683,
#    'sharpe_ratio': 0.7661381223654327,
#    'return_drawdown_ratio': 5.604668618514445}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 40, 'fit_bar': 5}",
#   0.7490210048084119,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 389,
#    'loss_days': 526,
#    'capital': 500000,
#    'end_balance': 1423186.6059999974,
#    'max_drawdown': -340308.6640000006,
#    'max_ddpercent': -41.82738954281297,
#    'max_drawdown_duration': 73,
#    'total_net_pnl': 923186.6059999976,
#    'daily_net_pnl': 805.5729546247798,
#    'total_commission': 41853.394,
#    'daily_commission': 36.52128621291448,
#    'total_slippage': 54960.0,
#    'daily_slippage': 47.95811518324607,
#    'total_turnover': 1674135760.0,
#    'daily_turnover': 1460851.4485165793,
#    'total_trade_count': 1374,
#    'daily_trade_count': 1.198952879581152,
#    'total_return': 184.63732119999946,
#    'annual_return': 38.66750182198941,
#    'daily_return': 0.08932506084995195,
#    'return_std': 1.8475021172967927,
#    'sharpe_ratio': 0.7490210048084119,
#    'return_drawdown_ratio': 4.4142683351302985}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 50, 'fit_bar': 10}",
#   0.7260659442370518,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 287,
#    'loss_days': 385,
#    'capital': 500000,
#    'end_balance': 1246958.541000002,
#    'max_drawdown': -168091.25299999886,
#    'max_ddpercent': -17.66331543283933,
#    'max_drawdown_duration': 155,
#    'total_net_pnl': 746958.5410000028,
#    'daily_net_pnl': 651.7962835951158,
#    'total_commission': 24441.459000000003,
#    'daily_commission': 21.327625654450262,
#    'total_slippage': 32240.0,
#    'daily_slippage': 28.1326352530541,
#    'total_turnover': 977658360.0,
#    'daily_turnover': 853105.0261780105,
#    'total_trade_count': 806,
#    'daily_trade_count': 0.7033158813263525,
#    'total_return': 149.39170820000044,
#    'annual_return': 31.286221612565537,
#    'daily_return': 0.07974298426809519,
#    'return_std': 1.7014611551392587,
#    'sharpe_ratio': 0.7260659442370518,
#    'return_drawdown_ratio': 8.457738795869204}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 20, 'fit_bar': 15}",
#   0.6997088287759843,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 477,
#    'loss_days': 585,
#    'capital': 500000,
#    'end_balance': 1428533.3870000008,
#    'max_drawdown': -280814.78500000027,
#    'max_ddpercent': -30.230610412734954,
#    'max_drawdown_duration': 48,
#    'total_net_pnl': 928533.3870000014,
#    'daily_net_pnl': 810.2385575916243,
#    'total_commission': 61906.613,
#    'daily_commission': 54.01973211169284,
#    'total_slippage': 82120.0,
#    'daily_slippage': 71.65794066317626,
#    'total_turnover': 2476264520.0,
#    'daily_turnover': 2160789.284467714,
#    'total_trade_count': 2053,
#    'daily_trade_count': 1.7914485165794067,
#    'total_return': 185.70667740000016,
#    'annual_return': 38.891450764397945,
#    'daily_return': 0.09160519153962636,
#    'return_std': 2.0281886788808836,
#    'sharpe_ratio': 0.6997088287759843,
#    'return_drawdown_ratio': 6.143001244915959}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 30, 'fit_bar': 5}",
#   0.6630509555577743,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 477,
#    'loss_days': 636,
#    'capital': 500000,
#    'end_balance': 1434964.816000001,
#    'max_drawdown': -367476.40299999935,
#    'max_ddpercent': -35.651027977253044,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': 934964.8160000014,
#    'daily_net_pnl': 815.8506247818511,
#    'total_commission': 108395.18400000001,
#    'daily_commission': 94.58567539267017,
#    'total_slippage': 141840.0,
#    'daily_slippage': 123.7696335078534,
#    'total_turnover': 4335807360.0,
#    'daily_turnover': 3783427.0157068064,
#    'total_trade_count': 3546,
#    'daily_trade_count': 3.094240837696335,
#    'total_return': 186.99296320000022,
#    'annual_return': 39.16082998952884,
#    'daily_return': 0.09430394908099113,
#    'return_std': 2.203375901721003,
#    'sharpe_ratio': 0.6630509555577743,
#    'return_drawdown_ratio': 5.245093165877576}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 60, 'fit_bar': 5}",
#   0.6569989256666762,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 306,
#    'loss_days': 456,
#    'capital': 500000,
#    'end_balance': 1201645.495,
#    'max_drawdown': -206891.054,
#    'max_ddpercent': -25.925706181642926,
#    'max_drawdown_duration': 120,
#    'total_net_pnl': 701645.4949999996,
#    'daily_net_pnl': 612.2561038394413,
#    'total_commission': 37114.505000000005,
#    'daily_commission': 32.38613001745201,
#    'total_slippage': 48440.0,
#    'daily_slippage': 42.268760907504365,
#    'total_turnover': 1484580200.0,
#    'daily_turnover': 1295445.2006980802,
#    'total_trade_count': 1211,
#    'daily_trade_count': 1.056719022687609,
#    'total_return': 140.32909900000004,
#    'annual_return': 29.388292984293205,
#    'daily_return': 0.07423944594170126,
#    'return_std': 1.7505546906160403,
#    'sharpe_ratio': 0.6569989256666762,
#    'return_drawdown_ratio': 5.41273969614614}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 40, 'fit_bar': 5}",
#   0.62732377047137,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 399,
#    'loss_days': 544,
#    'capital': 500000,
#    'end_balance': 1303365.127000001,
#    'max_drawdown': -249673.57600000023,
#    'max_ddpercent': -28.867129158771476,
#    'max_drawdown_duration': 12,
#    'total_net_pnl': 803365.1270000003,
#    'daily_net_pnl': 701.0166902268763,
#    'total_commission': 49554.873,
#    'daily_commission': 43.24159947643979,
#    'total_slippage': 65080.0,
#    'daily_slippage': 56.788830715532285,
#    'total_turnover': 1982194920.0,
#    'daily_turnover': 1729663.9790575916,
#    'total_trade_count': 1627,
#    'daily_trade_count': 1.4197207678883073,
#    'total_return': 160.6730254000002,
#    'annual_return': 33.64880113089009,
#    'daily_return': 0.0816506309206446,
#    'return_std': 2.016384831235514,
#    'sharpe_ratio': 0.62732377047137,
#    'return_drawdown_ratio': 5.565950965067775}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 50, 'fit_bar': 5}",
#   0.6206022568969839,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 356,
#    'loss_days': 507,
#    'capital': 500000,
#    'end_balance': 1149628.5479999988,
#    'max_drawdown': -270594.1470000007,
#    'max_ddpercent': -27.86054531112651,
#    'max_drawdown_duration': 428,
#    'total_net_pnl': 649628.5479999983,
#    'daily_net_pnl': 566.8660977312376,
#    'total_commission': 37811.452000000005,
#    'daily_commission': 32.99428621291449,
#    'total_slippage': 50200.0,
#    'daily_slippage': 43.80453752181501,
#    'total_turnover': 1512458080.0,
#    'daily_turnover': 1319771.4485165793,
#    'total_trade_count': 1255,
#    'daily_trade_count': 1.0951134380453753,
#    'total_return': 129.92570959999975,
#    'annual_return': 27.209572691099424,
#    'daily_return': 0.07037792981006376,
#    'return_std': 1.756826031911623,
#    'sharpe_ratio': 0.6206022568969839,
#    'return_drawdown_ratio': 4.66343024334531}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 50, 'fit_bar': 5}",
#   0.5946511154444488,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 394,
#    'loss_days': 611,
#    'capital': 500000,
#    'end_balance': 1299520.7530000042,
#    'max_drawdown': -527461.1070000005,
#    'max_ddpercent': -60.25023788233737,
#    'max_drawdown_duration': 114,
#    'total_net_pnl': 799520.753000004,
#    'daily_net_pnl': 697.6620881326387,
#    'total_commission': 72519.247,
#    'daily_commission': 63.2803202443281,
#    'total_slippage': 96040.0,
#    'daily_slippage': 83.804537521815,
#    'total_turnover': 2900769880.0,
#    'daily_turnover': 2531212.809773124,
#    'total_trade_count': 2401,
#    'daily_trade_count': 2.095113438045375,
#    'total_return': 159.90415060000083,
#    'annual_return': 33.48778023036667,
#    'daily_return': 0.08634338757545847,
#    'return_std': 2.2494299157915068,
#    'sharpe_ratio': 0.5946511154444488,
#    'return_drawdown_ratio': 2.6540003196713924}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 60, 'fit_bar': 15}",
#   0.5821492636534706,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 216,
#    'loss_days': 288,
#    'capital': 500000,
#    'end_balance': 852946.5339999995,
#    'max_drawdown': -312887.3779999999,
#    'max_ddpercent': -31.848485020199767,
#    'max_drawdown_duration': 519,
#    'total_net_pnl': 352946.5339999999,
#    'daily_net_pnl': 307.9812687609074,
#    'total_commission': 14413.466000000002,
#    'daily_commission': 12.577195462478187,
#    'total_slippage': 19040.0,
#    'daily_slippage': 16.61431064572426,
#    'total_turnover': 576538640.0,
#    'daily_turnover': 503087.8184991274,
#    'total_trade_count': 476,
#    'daily_trade_count': 0.41535776614310643,
#    'total_return': 70.5893067999999,
#    'annual_return': 14.78310090052354,
#    'daily_return': 0.04906876264763464,
#    'return_std': 1.3057991303509953,
#    'sharpe_ratio': 0.5821492636534706,
#    'return_drawdown_ratio': 2.2164101920461503}),
#  ("{'LLT_len_fast': 15, 'LLT_len_slow': 40, 'fit_bar': 15}",
#   0.5817399986851133,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 316,
#    'loss_days': 426,
#    'capital': 500000,
#    'end_balance': 1142696.6079999998,
#    'max_drawdown': -203413.7159999999,
#    'max_ddpercent': -25.58547010326212,
#    'max_drawdown_duration': 179,
#    'total_net_pnl': 642696.6079999992,
#    'daily_net_pnl': 560.8172844677131,
#    'total_commission': 26423.392,
#    'daily_commission': 23.057061082024433,
#    'total_slippage': 35120.0,
#    'daily_slippage': 30.645724258289704,
#    'total_turnover': 1056935680.0,
#    'daily_turnover': 922282.4432809773,
#    'total_trade_count': 878,
#    'daily_trade_count': 0.7661431064572426,
#    'total_return': 128.53932159999997,
#    'annual_return': 26.919229654450252,
#    'daily_return': 0.07212374304693857,
#    'return_std': 1.9206797285268684,
#    'sharpe_ratio': 0.5817399986851133,
#    'return_drawdown_ratio': 5.023918696088813}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 40, 'fit_bar': 5}",
#   0.5582952025770339,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 442,
#    'loss_days': 610,
#    'capital': 500000,
#    'end_balance': 1362886.2840000042,
#    'max_drawdown': -348083.9179999987,
#    'max_ddpercent': -43.17491648939116,
#    'max_drawdown_duration': 83,
#    'total_net_pnl': 862886.2840000029,
#    'daily_net_pnl': 752.9548726003516,
#    'total_commission': 87993.716,
#    'daily_commission': 76.78334729493892,
#    'total_slippage': 115960.0,
#    'daily_slippage': 101.18673647469458,
#    'total_turnover': 3519748640.0,
#    'daily_turnover': 3071333.8917975565,
#    'total_trade_count': 2899,
#    'daily_trade_count': 2.5296684118673647,
#    'total_return': 172.57725680000084,
#    'annual_return': 36.141833884816926,
#    'daily_return': 0.08619130668034776,
#    'return_std': 2.391691662905039,
#    'sharpe_ratio': 0.5582952025770339,
#    'return_drawdown_ratio': 3.99716480846943}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 60, 'fit_bar': 5}",
#   0.5557957572861182,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 371,
#    'loss_days': 633,
#    'capital': 500000,
#    'end_balance': 1243131.2369999983,
#    'max_drawdown': -274735.4230000003,
#    'max_ddpercent': -32.81124910365756,
#    'max_drawdown_duration': 14,
#    'total_net_pnl': 743131.2369999981,
#    'daily_net_pnl': 648.456576788829,
#    'total_commission': 82748.763,
#    'daily_commission': 72.20659947643979,
#    'total_slippage': 109080.0,
#    'daily_slippage': 95.18324607329843,
#    'total_turnover': 3309950520.0,
#    'daily_turnover': 2888263.9790575914,
#    'total_trade_count': 2727,
#    'daily_trade_count': 2.3795811518324608,
#    'total_return': 148.62624739999967,
#    'annual_return': 31.125915685863802,
#    'daily_return': 0.0818542096122795,
#    'return_std': 2.2815574713509794,
#    'sharpe_ratio': 0.5557957572861182,
#    'return_drawdown_ratio': 4.529734510577712}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 20, 'fit_bar': 10}",
#   0.5479838392707749,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 483,
#    'loss_days': 602,
#    'capital': 500000,
#    'end_balance': 1170628.6820000003,
#    'max_drawdown': -416466.7619999985,
#    'max_ddpercent': -32.86337525929673,
#    'max_drawdown_duration': 301,
#    'total_net_pnl': 670628.6820000001,
#    'daily_net_pnl': 585.1908219895289,
#    'total_commission': 69051.318,
#    'daily_commission': 60.25420418848167,
#    'total_slippage': 91240.0,
#    'daily_slippage': 79.61605584642234,
#    'total_turnover': 2762052720.0,
#    'daily_turnover': 2410168.167539267,
#    'total_trade_count': 2281,
#    'daily_trade_count': 1.9904013961605584,
#    'total_return': 134.12573640000005,
#    'annual_return': 28.089159455497395,
#    'daily_return': 0.07195751541912913,
#    'return_std': 2.0342954582282236,
#    'sharpe_ratio': 0.5479838392707749,
#    'return_drawdown_ratio': 4.081313478659109}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 50, 'fit_bar': 10}",
#   0.5347609248523316,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 388,
#    'loss_days': 540,
#    'capital': 500000,
#    'end_balance': 1083886.2269999993,
#    'max_drawdown': -299720.3720000009,
#    'max_ddpercent': -32.00767238290085,
#    'max_drawdown_duration': 164,
#    'total_net_pnl': 583886.2269999997,
#    'daily_net_pnl': 509.49932547992995,
#    'total_commission': 56073.773,
#    'daily_commission': 48.92999389179756,
#    'total_slippage': 74680.0,
#    'daily_slippage': 65.16579406631763,
#    'total_turnover': 2242950920.0,
#    'daily_turnover': 1957199.7556719023,
#    'total_trade_count': 1867,
#    'daily_trade_count': 1.6291448516579408,
#    'total_return': 116.77724539999983,
#    'annual_return': 24.455967623036614,
#    'daily_return': 0.07208578834925858,
#    'return_std': 2.088313074497772,
#    'sharpe_ratio': 0.5347609248523316,
#    'return_drawdown_ratio': 3.6484141677976125}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 60, 'fit_bar': 15}",
#   0.5236710658787123,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 155,
#    'loss_days': 211,
#    'capital': 500000,
#    'end_balance': 818340.6939999986,
#    'max_drawdown': -224993.79400000104,
#    'max_ddpercent': -21.641455677662613,
#    'max_drawdown_duration': 935,
#    'total_net_pnl': 318340.6939999996,
#    'daily_net_pnl': 277.7842006980799,
#    'total_commission': 10059.306,
#    'daily_commission': 8.777753926701571,
#    'total_slippage': 13280.0,
#    'daily_slippage': 11.588132635253054,
#    'total_turnover': 402372240.0,
#    'daily_turnover': 351110.1570680628,
#    'total_trade_count': 332,
#    'daily_trade_count': 0.28970331588132636,
#    'total_return': 63.66813879999973,
#    'annual_return': 13.333641633507797,
#    'daily_return': 0.0429904579234337,
#    'return_std': 1.2718008569284054,
#    'sharpe_ratio': 0.5236710658787123,
#    'return_drawdown_ratio': 2.9419526924760087}),
#  ("{'LLT_len_fast': 15, 'LLT_len_slow': 20, 'fit_bar': 5}",
#   0.5144457958230709,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 462,
#    'loss_days': 677,
#    'capital': 500000,
#    'end_balance': 1005358.1950000022,
#    'max_drawdown': -852847.6029999983,
#    'max_ddpercent': -53.73638397735486,
#    'max_drawdown_duration': 910,
#    'total_net_pnl': 505358.1950000023,
#    'daily_net_pnl': 440.9757373472969,
#    'total_commission': 114921.805,
#    'daily_commission': 100.28080715532286,
#    'total_slippage': 151720.0,
#    'daily_slippage': 132.39092495637,
#    'total_turnover': 4596872200.0,
#    'daily_turnover': 4011232.2862129146,
#    'total_trade_count': 3793,
#    'daily_trade_count': 3.3097731239092494,
#    'total_return': 101.07163900000043,
#    'annual_return': 21.166835392670247,
#    'daily_return': 0.06451329401422216,
#    'return_std': 1.942742386892764,
#    'sharpe_ratio': 0.5144457958230709,
#    'return_drawdown_ratio': 1.8808790528702712}),
#  ("{'LLT_len_fast': 15, 'LLT_len_slow': 20, 'fit_bar': 10}",
#   0.5136109969248336,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 456,
#    'loss_days': 591,
#    'capital': 500000,
#    'end_balance': 1070650.4690000026,
#    'max_drawdown': -344469.36800000025,
#    'max_ddpercent': -34.30399906820263,
#    'max_drawdown_duration': 60,
#    'total_net_pnl': 570650.4690000021,
#    'daily_net_pnl': 497.9497984293212,
#    'total_commission': 55469.531,
#    'daily_commission': 48.40273211169285,
#    'total_slippage': 73560.0,
#    'daily_slippage': 64.18848167539267,
#    'total_turnover': 2218781240.0,
#    'daily_turnover': 1936109.2844677137,
#    'total_trade_count': 1839,
#    'daily_trade_count': 1.6047120418848169,
#    'total_return': 114.1300938000005,
#    'annual_return': 23.901590324607433,
#    'daily_return': 0.06644097375930125,
#    'return_std': 2.00404420011464,
#    'sharpe_ratio': 0.5136109969248336,
#    'return_drawdown_ratio': 3.327020082209336}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 50, 'fit_bar': 5}",
#   0.5086508581237482,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 419,
#    'loss_days': 644,
#    'capital': 500000,
#    'end_balance': 1172986.2619999957,
#    'max_drawdown': -358896.5419999999,
#    'max_ddpercent': -46.214045855043096,
#    'max_drawdown_duration': 108,
#    'total_net_pnl': 672986.2619999968,
#    'daily_net_pnl': 587.2480471204161,
#    'total_commission': 102773.738,
#    'daily_commission': 89.68039965095986,
#    'total_slippage': 136680.0,
#    'daily_slippage': 119.26701570680628,
#    'total_turnover': 4110949520.0,
#    'daily_turnover': 3587215.9860383943,
#    'total_trade_count': 3417,
#    'daily_trade_count': 2.981675392670157,
#    'total_return': 134.59725239999915,
#    'annual_return': 28.187906261779926,
#    'daily_return': 0.07582162871167338,
#    'return_std': 2.309292518375663,
#    'sharpe_ratio': 0.5086508581237482,
#    'return_drawdown_ratio': 2.9124749826531637}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 20, 'fit_bar': 5}",
#   0.5071170341797167,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 460,
#    'loss_days': 546,
#    'capital': 500000,
#    'end_balance': 755879.932000001,
#    'max_drawdown': -321085.5270000006,
#    'max_ddpercent': -34.33354278094898,
#    'max_drawdown_duration': 854,
#    'total_net_pnl': 255879.93200000084,
#    'daily_net_pnl': 223.28091797556792,
#    'total_commission': 116360.068,
#    'daily_commission': 101.53583595113437,
#    'total_slippage': 154400.0,
#    'daily_slippage': 134.72949389179755,
#    'total_turnover': 4654402720.0,
#    'daily_turnover': 4061433.438045375,
#    'total_trade_count': 3860,
#    'daily_trade_count': 3.3682373472949387,
#    'total_return': 51.175986400000184,
#    'annual_return': 10.717484062827264,
#    'daily_return': 0.03507060536815876,
#    'return_std': 1.0713729681906559,
#    'sharpe_ratio': 0.5071170341797167,
#    'return_drawdown_ratio': 1.490553617682494}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 50, 'fit_bar': 5}",
#   0.5025391774257678,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 332,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 1311416.668999999,
#    'max_drawdown': -236204.23899999907,
#    'max_ddpercent': -41.27600941308176,
#    'max_drawdown_duration': 85,
#    'total_net_pnl': 811416.668999999,
#    'daily_net_pnl': 708.0424685863865,
#    'total_commission': 33183.331,
#    'daily_commission': 28.955786212914482,
#    'total_slippage': 43800.0,
#    'daily_slippage': 38.21989528795812,
#    'total_turnover': 1327333240.0,
#    'daily_turnover': 1158231.4485165793,
#    'total_trade_count': 1095,
#    'daily_trade_count': 0.9554973821989529,
#    'total_return': 162.2833337999998,
#    'annual_return': 33.986038492146555,
#    'daily_return': 0.08540701357799615,
#    'return_std': 2.6328688874072967,
#    'sharpe_ratio': 0.5025391774257678,
#    'return_drawdown_ratio': 3.9316623895469593}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 50, 'fit_bar': 5}",
#   0.49244516520350173,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 373,
#    'loss_days': 548,
#    'capital': 500000,
#    'end_balance': 925910.7399999982,
#    'max_drawdown': -287958.3709999997,
#    'max_ddpercent': -28.806357383360897,
#    'max_drawdown_duration': 41,
#    'total_net_pnl': 425910.7399999994,
#    'daily_net_pnl': 371.64986038394363,
#    'total_commission': 49369.26,
#    'daily_commission': 43.0796335078534,
#    'total_slippage': 64520.0,
#    'daily_slippage': 56.30017452006981,
#    'total_turnover': 1974770400.0,
#    'daily_turnover': 1723185.3403141361,
#    'total_trade_count': 1613,
#    'daily_trade_count': 1.4075043630017452,
#    'total_return': 85.18214799999966,
#    'annual_return': 17.839193298429247,
#    'daily_return': 0.0537669928873754,
#    'return_std': 1.6914668494503626,
#    'sharpe_ratio': 0.49244516520350173,
#    'return_drawdown_ratio': 2.9570607233111152}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 50, 'fit_bar': 15}",
#   0.4754229384124142,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 245,
#    'loss_days': 329,
#    'capital': 500000,
#    'end_balance': 894614.7530000012,
#    'max_drawdown': -238283.07599999872,
#    'max_ddpercent': -27.960069649666607,
#    'max_drawdown_duration': 447,
#    'total_net_pnl': 394614.75300000206,
#    'daily_net_pnl': 344.3409712041903,
#    'total_commission': 16865.247000000003,
#    'daily_commission': 14.71662041884817,
#    'total_slippage': 22440.0,
#    'daily_slippage': 19.581151832460733,
#    'total_turnover': 674609880.0,
#    'daily_turnover': 588664.8167539267,
#    'total_trade_count': 561,
#    'daily_trade_count': 0.4895287958115183,
#    'total_return': 78.92295060000023,
#    'annual_return': 16.528366617801098,
#    'daily_return': 0.05076658670242738,
#    'return_std': 1.6542587995342892,
#    'sharpe_ratio': 0.4754229384124142,
#    'return_drawdown_ratio': 2.822702217443915}),
#  ("{'LLT_len_fast': 15, 'LLT_len_slow': 30, 'fit_bar': 10}",
#   0.471228106653681,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 430,
#    'loss_days': 529,
#    'capital': 500000,
#    'end_balance': 1127687.389,
#    'max_drawdown': -415534.3069999999,
#    'max_ddpercent': -46.2334426996469,
#    'max_drawdown_duration': 142,
#    'total_net_pnl': 627687.3890000009,
#    'daily_net_pnl': 547.7202347294947,
#    'total_commission': 41712.611000000004,
#    'daily_commission': 36.39843891797557,
#    'total_slippage': 55080.0,
#    'daily_slippage': 48.06282722513089,
#    'total_turnover': 1668504440.0,
#    'daily_turnover': 1455937.5567190228,
#    'total_trade_count': 1377,
#    'daily_trade_count': 1.2015706806282722,
#    'total_return': 125.53747779999998,
#    'annual_return': 26.2905712670157,
#    'daily_return': 0.07037197136719937,
#    'return_std': 2.313524760485077,
#    'sharpe_ratio': 0.471228106653681,
#    'return_drawdown_ratio': 2.7152959085384905}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 20, 'fit_bar': 15}",
#   0.4663448505124783,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 439,
#    'loss_days': 563,
#    'capital': 500000,
#    'end_balance': 1108440.071000003,
#    'max_drawdown': -362240.9569999981,
#    'max_ddpercent': -34.30862321963729,
#    'max_drawdown_duration': 521,
#    'total_net_pnl': 608440.0710000019,
#    'daily_net_pnl': 530.9250183246089,
#    'total_commission': 46159.929000000004,
#    'daily_commission': 40.279170157068066,
#    'total_slippage': 61080.0,
#    'daily_slippage': 53.29842931937173,
#    'total_turnover': 1846397160.0,
#    'daily_turnover': 1611166.8062827226,
#    'total_trade_count': 1527,
#    'daily_trade_count': 1.3324607329842932,
#    'total_return': 121.68801420000062,
#    'annual_return': 25.48440087958128,
#    'daily_return': 0.0698108157604406,
#    'return_std': 2.3191089300393686,
#    'sharpe_ratio': 0.4663448505124783,
#    'return_drawdown_ratio': 3.5468638138282924}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 10, 'fit_bar': 15}",
#   0.44629363344201867,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 372,
#    'loss_days': 409,
#    'capital': 500000,
#    'end_balance': 769343.749000001,
# ...
#    'daily_turnover': 1142342.4781849913,
#    'total_trade_count': 1073,
#    'daily_trade_count': 0.9363001745200699,
#    'total_return': -33.24962240000029,
#    'annual_return': -6.963271706806344,
#    'daily_return': -0.03527139893498242,
#    'return_std': 3.7372815765215774,
#    'sharpe_ratio': -0.1462084543276706,
#    'return_drawdown_ratio': -0.3661748882097323}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 30, 'fit_bar': 15}",
#   -0.1511244898846992,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 373,
#    'loss_days': 519,
#    'capital': 500000,
#    'end_balance': 339842.69099999825,
#    'max_drawdown': -424154.56800000044,
#    'max_ddpercent': -70.25168962355043,
#    'max_drawdown_duration': 492,
#    'total_net_pnl': -160157.3090000014,
#    'daily_net_pnl': -139.7533237347307,
#    'total_commission': 37877.309,
#    'daily_commission': 33.05175305410122,
#    'total_slippage': 50120.0,
#    'daily_slippage': 43.7347294938918,
#    'total_turnover': 1515092360.0,
#    'daily_turnover': 1322070.122164049,
#    'total_trade_count': 1253,
#    'daily_trade_count': 1.093368237347295,
#    'total_return': -32.03146180000035,
#    'annual_return': -6.70815953926709,
#    'daily_return': -0.03403441890057901,
#    'return_std': 3.4889047486706577,
#    'sharpe_ratio': -0.1511244898846992,
#    'return_drawdown_ratio': -0.45595290265107674}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 50, 'fit_bar': 15}",
#   -0.15212006058281816,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 193,
#    'loss_days': 270,
#    'capital': 500000,
#    'end_balance': 382178.88399999845,
#    'max_drawdown': -338642.34400000016,
#    'max_ddpercent': -49.424672927478,
#    'max_drawdown_duration': 427,
#    'total_net_pnl': -117821.1160000016,
#    'daily_net_pnl': -102.81074694590016,
#    'total_commission': 13341.116000000002,
#    'daily_commission': 11.641462478184993,
#    'total_slippage': 17760.0,
#    'daily_slippage': 15.497382198952879,
#    'total_turnover': 533644640.0,
#    'daily_turnover': 465658.49912739964,
#    'total_trade_count': 444,
#    'daily_trade_count': 0.387434554973822,
#    'total_return': -23.564223200000313,
#    'annual_return': -4.934915853403207,
#    'daily_return': -0.020984298770790562,
#    'return_std': 2.137044630661742,
#    'sharpe_ratio': -0.15212006058281816,
#    'return_drawdown_ratio': -0.4767704428631558}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 40, 'fit_bar': 5}",
#   -0.18872959595138197,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 414,
#    'loss_days': 691,
#    'capital': 500000,
#    'end_balance': 75359.00200000184,
#    'max_drawdown': -887904.4709999999,
#    'max_ddpercent': -101.00717111583405,
#    'max_drawdown_duration': 981,
#    'total_net_pnl': -424640.9979999983,
#    'daily_net_pnl': -370.54188307155175,
#    'total_commission': 136720.99800000002,
#    'daily_commission': 119.30279057591625,
#    'total_slippage': 180760.0,
#    'daily_slippage': 157.73123909249563,
#    'total_turnover': 5468839920.0,
#    'daily_turnover': 4772111.623036649,
#    'total_trade_count': 4519,
#    'daily_trade_count': 3.943280977312391,
#    'total_return': -84.92819959999963,
#    'annual_return': -17.78601038743448,
#    'daily_return': -0.25487283244249903,
#    'return_std': 20.92132355764277,
#    'sharpe_ratio': -0.18872959595138197,
#    'return_drawdown_ratio': -0.8408135646389382}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 30, 'fit_bar': 15}",
#   -0.2165313719455,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 321,
#    'loss_days': 421,
#    'capital': 500000,
#    'end_balance': 175193.40699999785,
#    'max_drawdown': -606399.0770000017,
#    'max_ddpercent': -105.36736913047487,
#    'max_drawdown_duration': 1318,
#    'total_net_pnl': -324806.5930000016,
#    'daily_net_pnl': -283.42634642234,
#    'total_commission': 23166.593000000004,
#    'daily_commission': 20.21517713787086,
#    'total_slippage': 30760.0,
#    'daily_slippage': 26.841186736474693,
#    'total_turnover': 926663720.0,
#    'daily_turnover': 808607.0855148342,
#    'total_trade_count': 769,
#    'daily_trade_count': 0.6710296684118674,
#    'total_return': -64.96131860000042,
#    'annual_return': -13.604464628272341,
#    'daily_return': -0.3042928572301596,
#    'return_std': 21.770908443122188,
#    'sharpe_ratio': -0.2165313719455,
#    'return_drawdown_ratio': -0.6165221656010009}),
#  ("{'LLT_len_fast': 5, 'LLT_len_slow': 60, 'fit_bar': 10}",
#   -0.2402080710361725,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 314,
#    'loss_days': 497,
#    'capital': 500000,
#    'end_balance': 189046.6710000027,
#    'max_drawdown': -469228.31699999765,
#    'max_ddpercent': -83.84698865175329,
#    'max_drawdown_duration': 1454,
#    'total_net_pnl': -310953.3289999971,
#    'daily_net_pnl': -271.33798342059083,
#    'total_commission': 44113.329,
#    'daily_commission': 38.493306282722514,
#    'total_slippage': 58760.0,
#    'daily_slippage': 51.273996509598604,
#    'total_turnover': 1764533160.0,
#    'daily_turnover': 1539732.2513089005,
#    'total_trade_count': 1469,
#    'daily_trade_count': 1.2818499127399652,
#    'total_return': -62.19066579999946,
#    'annual_return': -13.024223204188369,
#    'daily_return': -0.08681609226986707,
#    'return_std': 5.599100448100568,
#    'sharpe_ratio': -0.2402080710361725,
#    'return_drawdown_ratio': -0.7417161522436979}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 50, 'fit_bar': 15}",
#   -0.31494420213307994,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 285,
#    'loss_days': 423,
#    'capital': 500000,
#    'end_balance': 293247.7920000006,
#    'max_drawdown': -530004.973000001,
#    'max_ddpercent': -101.69158449422603,
#    'max_drawdown_duration': 262,
#    'total_net_pnl': -206752.20799999952,
#    'daily_net_pnl': -180.4120488656191,
#    'total_commission': 28912.208000000002,
#    'daily_commission': 25.22880279232112,
#    'total_slippage': 37560.0,
#    'daily_slippage': 32.774869109947645,
#    'total_turnover': 1156488320.0,
#    'daily_turnover': 1009152.1116928447,
#    'total_trade_count': 939,
#    'daily_trade_count': 0.819371727748691,
#    'total_return': -41.350441599999876,
#    'annual_return': -8.659778345549713,
#    'daily_return': -0.20252814926139054,
#    'return_std': 9.96224910844533,
#    'sharpe_ratio': -0.31494420213307994,
#    'return_drawdown_ratio': -0.4066259937403937}),
#  ("{'LLT_len_fast': 30, 'LLT_len_slow': 20, 'fit_bar': 15}",
#   -0.4186993813273378,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 253,
#    'loss_days': 265,
#    'capital': 500000,
#    'end_balance': 329438.77599999995,
#    'max_drawdown': -207251.58799999935,
#    'max_ddpercent': -39.703665452815216,
#    'max_drawdown_duration': 1407,
#    'total_net_pnl': -170561.224,
#    'daily_net_pnl': -148.83178359511342,
#    'total_commission': 37681.224,
#    'daily_commission': 32.88064921465969,
#    'total_slippage': 49560.0,
#    'daily_slippage': 43.246073298429316,
#    'total_turnover': 1507248960.0,
#    'daily_turnover': 1315225.9685863873,
#    'total_trade_count': 1239,
#    'daily_trade_count': 1.081151832460733,
#    'total_return': -34.11224480000001,
#    'annual_return': -7.143925612565448,
#    'daily_return': -0.03640641976836289,
#    'return_std': 1.3470424246714756,
#    'sharpe_ratio': -0.4186993813273378,
#    'return_drawdown_ratio': -0.8591711725089921}),
#  ("{'LLT_len_fast': 15, 'LLT_len_slow': 10, 'fit_bar': 15}",
#   -0.4373850017280615,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 422,
#    'loss_days': 506,
#    'capital': 500000,
#    'end_balance': 268736.444999999,
#    'max_drawdown': -445431.3079999995,
#    'max_ddpercent': -62.554195296230795,
#    'max_drawdown_duration': 1465,
#    'total_net_pnl': -231263.55500000104,
#    'daily_net_pnl': -201.80065881326442,
#    'total_commission': 72663.55500000001,
#    'daily_commission': 63.40624345549739,
#    'total_slippage': 97040.0,
#    'daily_slippage': 84.67713787085515,
#    'total_turnover': 2906542200.0,
#    'daily_turnover': 2536249.7382198954,
#    'total_trade_count': 2426,
#    'daily_trade_count': 2.1169284467713787,
#    'total_return': -46.252711000000204,
#    'annual_return': -9.686431623036693,
#    'daily_return': -0.05269876166844824,
#    'return_std': 1.8665608148543809,
#    'sharpe_ratio': -0.4373850017280615,
#    'return_drawdown_ratio': -0.7394022220406881}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 40, 'fit_bar': 15}",
#   -0.45170526947761724,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 252,
#    'loss_days': 373,
#    'capital': 500000,
#    'end_balance': 56976.90800000023,
#    'max_drawdown': -897323.9120000002,
#    'max_ddpercent': -97.69140278729648,
#    'max_drawdown_duration': 1519,
#    'total_net_pnl': -443023.09200000006,
#    'daily_net_pnl': -386.58210471204194,
#    'total_commission': 20463.092,
#    'daily_commission': 17.85610122164049,
#    'total_slippage': 26800.0,
#    'daily_slippage': 23.38568935427574,
#    'total_turnover': 818523680.0,
#    'daily_turnover': 714244.0488656196,
#    'total_trade_count': 670,
#    'daily_trade_count': 0.5846422338568935,
#    'total_return': -88.60461839999996,
#    'annual_return': -18.555941026178,
#    'daily_return': -0.1866943471903389,
#    'return_std': 6.40297243674353,
#    'sharpe_ratio': -0.45170526947761724,
#    'return_drawdown_ratio': -0.9069848100443273}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 50, 'fit_bar': 15}",
#   -0.4564471127176972,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 200,
#    'loss_days': 296,
#    'capital': 500000,
#    'end_balance': 186220.43399999815,
#    'max_drawdown': -386348.8300000006,
#    'max_ddpercent': -72.2559012649587,
#    'max_drawdown_duration': 1343,
#    'total_net_pnl': -313779.5660000016,
#    'daily_net_pnl': -273.80415881326496,
#    'total_commission': 15539.566,
#    'daily_commission': 13.559830715532287,
#    'total_slippage': 20480.0,
#    'daily_slippage': 17.87085514834206,
#    'total_turnover': 621582640.0,
#    'daily_turnover': 542393.2286212915,
#    'total_trade_count': 512,
#    'daily_trade_count': 0.4467713787085515,
#    'total_return': -62.75591320000037,
#    'annual_return': -13.142599623036727,
#    'daily_return': -0.0861847292659507,
#    'return_std': 2.9251320632264814,
#    'sharpe_ratio': -0.4564471127176972,
#    'return_drawdown_ratio': -0.8685230147483407}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 10}",
#   -0.46315646908494223,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 465,
#    'loss_days': 555,
#    'capital': 500000,
#    'end_balance': 216745.50199999765,
#    'max_drawdown': -368285.00000000006,
#    'max_ddpercent': -65.28753762759779,
#    'max_drawdown_duration': 1106,
#    'total_net_pnl': -283254.49800000235,
#    'daily_net_pnl': -247.16797382199158,
#    'total_commission': 98134.498,
#    'daily_commission': 85.63219720767889,
#    'total_slippage': 130800.0,
#    'daily_slippage': 114.13612565445027,
#    'total_turnover': 3925379920.0,
#    'daily_turnover': 3425287.888307155,
#    'total_trade_count': 3270,
#    'daily_trade_count': 2.8534031413612566,
#    'total_return': -56.65089960000047,
#    'annual_return': -11.864062743455596,
#    'daily_return': -0.07176514220502495,
#    'return_std': 2.400443212181876,
#    'sharpe_ratio': -0.46315646908494223,
#    'return_drawdown_ratio': -0.8677138341951113}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 5}",
#   -0.5147802334344155,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 509,
#    'loss_days': 627,
#    'capital': 500000,
#    'end_balance': 278137.55100000685,
#    'max_drawdown': -438627.67199999123,
#    'max_ddpercent': -62.885389408237536,
#    'max_drawdown_duration': 1494,
#    'total_net_pnl': -221862.44899999318,
#    'daily_net_pnl': -193.59725043629422,
#    'total_commission': 206462.44900000002,
#    'daily_commission': 180.15920506108205,
#    'total_slippage': 274720.0,
#    'daily_slippage': 239.72076788830717,
#    'total_turnover': 8258497960.0,
#    'daily_turnover': 7206368.202443281,
#    'total_trade_count': 6868,
#    'daily_trade_count': 5.993019197207679,
#    'total_return': -44.372489799998625,
#    'annual_return': -9.29266802094212,
#    'daily_return': -0.04979716673760697,
#    'return_std': 1.4986091923254636,
#    'sharpe_ratio': -0.5147802334344155,
#    'return_drawdown_ratio': -0.7056088897206725}),
#  ("{'LLT_len_fast': 25, 'LLT_len_slow': 10, 'fit_bar': 10}",
#   -0.7004067042826468,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 438,
#    'loss_days': 508,
#    'capital': 500000,
#    'end_balance': 182696.91499999445,
#    'max_drawdown': -477750.34700000356,
#    'max_ddpercent': -72.33739535133465,
#    'max_drawdown_duration': 1604,
#    'total_net_pnl': -317303.08500000543,
#    'daily_net_pnl': -276.8787827225178,
#    'total_commission': 84143.085,
#    'daily_commission': 73.42328534031414,
#    'total_slippage': 112320.0,
#    'daily_slippage': 98.01047120418848,
#    'total_turnover': 3365723400.0,
#    'daily_turnover': 2936931.4136125655,
#    'total_trade_count': 2808,
#    'daily_trade_count': 2.450261780104712,
#    'total_return': -63.46061700000112,
#    'annual_return': -13.290181570680865,
#    'daily_return': -0.08731190036357647,
#    'return_std': 1.9312067344083594,
#    'sharpe_ratio': -0.7004067042826468,
#    'return_drawdown_ratio': -0.8772864531792995}),
#  ("{'LLT_len_fast': 10, 'LLT_len_slow': 60, 'fit_bar': 10}",
#   -0.7445824258875645,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 266,
#    'loss_days': 438,
#    'capital': 500000,
#    'end_balance': 40258.74599999987,
#    'max_drawdown': -621910.1559999998,
#    'max_ddpercent': -109.55452440342579,
#    'max_drawdown_duration': 1479,
#    'total_net_pnl': -459741.25400000025,
#    'daily_net_pnl': -401.1703787085517,
#    'total_commission': 31821.254000000004,
#    'daily_commission': 27.767237347294945,
#    'total_slippage': 42040.0,
#    'daily_slippage': 36.68411867364747,
#    'total_turnover': 1272850160.0,
#    'daily_turnover': 1110689.4938917975,
#    'total_trade_count': 1051,
#    'daily_trade_count': 0.9171029668411868,
#    'total_return': -91.94825080000003,
#    'annual_return': -19.256178178010476,
#    'daily_return': -1.0376870963464828,
#    'return_std': 21.59032876949013,
#    'sharpe_ratio': -0.7445824258875645,
#    'return_drawdown_ratio': -0.8392921360454995}),
#  ("{'LLT_len_fast': 20, 'LLT_len_slow': 10, 'fit_bar': 15}",
#   -0.9385774376307544,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2019, 12, 31),
#    'total_days': 1146,
#    'profit_days': 396,
#    'loss_days': 462,
#    'capital': 500000,
#    'end_balance': 89369.20100000198,
#    'max_drawdown': -475670.1789999985,
#    'max_ddpercent': -84.60919015189774,
#    'max_drawdown_duration': 1675,
#    'total_net_pnl': -410630.7989999989,
#    'daily_net_pnl': -358.31657853403044,
#    'total_commission': 63950.799000000006,
#    'daily_commission': 55.803489528795815,
#    'total_slippage': 85200.0,
#    'daily_slippage': 74.3455497382199,
#    'total_turnover': 2558031960.0,
#    'daily_turnover': 2232139.5811518324,
#    'total_trade_count': 2130,
#    'daily_trade_count': 1.8586387434554974,
#    'total_return': -82.1261597999996,
#    'annual_return': -17.199195769633427,
#    'daily_return': -0.1509349293425151,
#    'return_std': 2.491295632165107,
#    'sharpe_ratio': -0.9385774376307544,
#    'return_drawdown_ratio': -0.9706529474228464})]

# %%
# 样本外。2019
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 12, 15),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:07:19.381702	开始加载历史数据
# 2019-12-20 12:07:19.641336	加载进度： [9%]
# 2019-12-20 12:07:19.858341	加载进度：# [17%]
# 2019-12-20 12:07:20.105831	加载进度：## [26%]
# 2019-12-20 12:07:20.381099	加载进度：### [34%]
# 2019-12-20 12:07:20.640501	加载进度：#### [43%]
# 2019-12-20 12:07:20.888839	加载进度：##### [52%]
# 2019-12-20 12:07:21.177471	加载进度：###### [60%]
# 2019-12-20 12:07:21.467733	加载进度：###### [69%]
# 2019-12-20 12:07:21.735977	加载进度：####### [78%]
# 2019-12-20 12:07:22.266116	加载进度：######## [86%]
# 2019-12-20 12:07:22.548527	加载进度：######### [95%]
# 2019-12-20 12:07:22.708051	加载进度：########## [100%]
# 2019-12-20 12:07:22.708051	历史数据加载完成，数据量：55680
# 2019-12-20 12:07:22.739304	策略初始化完成
# 2019-12-20 12:07:22.739304	开始回放历史数据
# 2019-12-20 12:07:24.842473	历史数据回放结束
# 2019-12-20 12:07:24.842473	开始计算逐日盯市盈亏
# 2019-12-20 12:07:24.842473	逐日盯市盈亏计算完成
# 2019-12-20 12:07:24.842473	开始计算策略统计指标
# 2019-12-20 12:07:24.842473	------------------------------
# 2019-12-20 12:07:24.842473	首个交易日：	2019-01-09
# 2019-12-20 12:07:24.842473	最后交易日：	2019-12-13
# 2019-12-20 12:07:24.842473	总交易日：	227
# 2019-12-20 12:07:24.842473	盈利交易日：	57
# 2019-12-20 12:07:24.842473	亏损交易日：	48
# 2019-12-20 12:07:24.842473	起始资金：	500,000.00
# 2019-12-20 12:07:24.842473	结束资金：	675,029.17
# 2019-12-20 12:07:24.842473	总收益率：	35.01%
# 2019-12-20 12:07:24.842473	年化收益：	37.01%
# 2019-12-20 12:07:24.842473	最大回撤: 	-23,488.78
# 2019-12-20 12:07:24.842473	百分比最大回撤: -4.06%
# 2019-12-20 12:07:24.842473	最长回撤天数: 	21
# 2019-12-20 12:07:24.842473	总盈亏：	175,029.17

#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 775079.8927999984,
#    'max_drawdown': -25140.243600000395,
#    'max_ddpercent': -4.449706259806321,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 275079.89279999817,
#    'daily_net_pnl': 304.966621729488,
#    'total_commission': 31040.1072,
#    'daily_commission': 34.41253569844789,
#    'total_slippage': 83040.0,
#    'daily_slippage': 92.06208425720621,
#    'total_turnover': 1034670240.0,
#    'daily_turnover': 1147084.5232815964,
#    'total_trade_count': 1384,
#    'daily_trade_count': 1.5343680709534369,
#    'total_return': 55.01597855999969,
#    'annual_return': 14.638397843015438,
#    'daily_return': 0.04777556887546098,
#    'return_std': 0.516097066602112,
#    'sharpe_ratio': 1.434102184137379,
#    'return_drawdown_ratio': 12.36395738230018}),
#  ("{'atr_window': 28, 'atr_ma_len': 34}",
#   1.4139702801845824,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 772479.1357999984,
#    'max_drawdown': -24486.095400000224,
#    'max_ddpercent': -4.258557014533781,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 272479.1357999983,
#    'daily_net_pnl': 302.08329911308016,
#    'total_commission': 30940.864199999996,
#    'daily_commission': 34.30251019955654,
#    'total_slippage': 82800.0,
#    'daily_slippage': 91.7960088691796,
#    'total_turnover': 1031362140.0,
#    'daily_turnover': 1143417.0066518846,
#    'total_trade_count': 1380,
#    'daily_trade_count': 1.5299334811529934,
#    'total_return': 54.49582715999968,
#    'annual_return': 14.499998357427852,
#    'daily_return': 0.04740294007390324,
#    'return_std': 0.5193625355223991,
#    'sharpe_ratio': 1.4139702801845824,
#    'return_drawdown_ratio': 12.7967823312014}),
#  ("{'atr_window': 60, 'atr_ma_len': 40}",
#   1.3971258848660566,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 208,
#    'loss_days': 209,
#    'capital': 500000,
#    'end_balance': 770848.5157999983,
#    'max_drawdown': -22961.68800000043,
#    'max_ddpercent': -4.1210069496588995,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 270848.5157999984,
#    'daily_net_pnl': 300.2755164079805,
#    'total_commission': 31131.4842,
#    'daily_commission': 34.513840576496676,
#    'total_slippage': 83160.0,
#    'daily_slippage': 92.1951219512195,
#    'total_turnover': 1037716140.0,
#    'daily_turnover': 1150461.3525498891,
#    'total_trade_count': 1386,
#    'daily_trade_count': 1.5365853658536586,
#    'total_return': 54.16970315999967,
#    'annual_return': 14.41322478758306,
#    'daily_return': 0.047168669227279775,
#    'return_std': 0.5230265142429448,
#    'sharpe_ratio': 1.3971258848660566,
#    'return_drawdown_ratio': 13.144773552125011}),
#  ("{'atr_window': 56, 'atr_ma_len': 38}",
#   1.3905074505785386,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 205,
#    'loss_days': 212,
#    'capital': 500000,
#    'end_balance': 779981.0023999984,
#    'max_drawdown': -21409.770000000135,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 42,
#    'total_net_pnl': 279981.00239999837,
#    'daily_net_pnl': 310.4002243902421,
#    'total_commission': 31298.9976,
#    'daily_commission': 34.69955388026607,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043299920.0,
#    'daily_turnover': 1156651.796008869,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 55.99620047999967,
#    'annual_return': 14.89921077073162,
#    'daily_return': 0.048474399470308245,
#    'return_std': 0.5400633899165304,
#    'sharpe_ratio': 1.3905074505785386,
#    'return_drawdown_ratio': 14.99845037915169}),
#  ("{'atr_window': 60, 'atr_ma_len': 38}",
#   1.3702499365892344,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 205,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 775379.6167999981,
#    'max_drawdown': -21409.770000000135,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 42,
#    'total_net_pnl': 275379.616799998,
#    'daily_net_pnl': 305.2989099778248,
#    'total_commission': 31340.383199999997,
#    'daily_commission': 34.74543592017738,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044679440.0,
#    'daily_turnover': 1158181.197339246,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 55.07592335999962,
#    'annual_return': 14.654347678935599,
#    'daily_return': 0.047818432071876894,
#    'return_std': 0.5406312705757067,
#    'sharpe_ratio': 1.3702499365892344,
#    'return_drawdown_ratio': 14.75195632060714}),
#  ("{'atr_window': 48, 'atr_ma_len': 40}",
#   1.364750902491683,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 773580.5491999986,
#    'max_drawdown': -21972.221400000504,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 53,
#    'total_net_pnl': 273580.54919999855,
#    'daily_net_pnl': 303.3043782705084,
#    'total_commission': 31339.4508,
#    'daily_commission': 34.7444022172949,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044648360.0,
#    'daily_turnover': 1158146.7405764966,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 54.716109839999724,
#    'annual_return': 14.558610156984406,
#    'daily_return': 0.04756090025821571,
#    'return_std': 0.5398862878035694,
#    'sharpe_ratio': 1.364750902491683,
#    'return_drawdown_ratio': 14.65558111694678}),
#  ("{'atr_window': 24, 'atr_ma_len': 38}",
#   1.3628886023841191,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 764034.1375999982,
#    'max_drawdown': -28846.98780000047,
#    'max_ddpercent': -5.13194054833354,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 264034.13759999804,
#    'daily_net_pnl': 292.720773392459,
#    'total_commission': 31165.862399999998,
#    'daily_commission': 34.551953880266076,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1038862080.0,
#    'daily_turnover': 1151731.796008869,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 52.80682751999963,
#    'annual_return': 14.050597122838038,
#    'daily_return': 0.04618425616667195,
#    'return_std': 0.5249757160712812,
#    'sharpe_ratio': 1.3628886023841191,
#    'return_drawdown_ratio': 10.28983617847}),
#  ("{'atr_window': 52, 'atr_ma_len': 38}",
#   1.3581196744008468,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 760650.295999998,
#    'max_drawdown': -22362.922800000524,
#    'max_ddpercent': -4.011816576618695,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 260650.29599999805,
#    'daily_net_pnl': 288.96928603104,
#    'total_commission': 31309.703999999998,
#    'daily_commission': 34.71142350332594,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043656800.0,
#    'daily_turnover': 1157047.4501108648,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 52.1300591999996,
#    'annual_return': 13.870525729489916,
#    'daily_return': 0.045692155186531705,
#    'return_std': 0.5212057800954328,
#    'sharpe_ratio': 1.3581196744008468,
#    'return_drawdown_ratio': 12.994128271920326}),
#  ("{'atr_window': 60, 'atr_ma_len': 36}",
#   1.3581051774668824,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 773453.2483999981,
#    'max_drawdown': -21732.21420000051,
#    'max_ddpercent': -3.7487631089390607,
#    'max_drawdown_duration': 53,
#    'total_net_pnl': 273453.24839999794,
#    'daily_net_pnl': 303.1632465631906,
#    'total_commission': 31346.7516,
#    'daily_commission': 34.752496230598666,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044891720.0,
#    'daily_turnover': 1158416.5410199556,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 54.690649679999616,
#    'annual_return': 14.551835835033158,
#    'daily_return': 0.0475426547993439,
#    'return_std': 0.5423200303699222,
#    'sharpe_ratio': 1.3581051774668824,
#    'return_drawdown_ratio': 14.58898524411633}),
#  ("{'atr_window': 20, 'atr_ma_len': 18}",
#   1.354321748458312,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 202,
#    'capital': 500000,
#    'end_balance': 769860.0313999974,
#    'max_drawdown': -59451.89400000067,
#    'max_ddpercent': -10.6653337685738,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 269860.0313999973,
#    'daily_net_pnl': 299.1796356984449,
#    'total_commission': 31759.9686,
#    'daily_commission': 35.21060820399113,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1058665620.0,
#    'daily_turnover': 1173686.9401330377,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 53.972006279999476,
#    'annual_return': 14.36062251352536,
#    'daily_return': 0.04739677022255856,
#    'return_std': 0.542166296731044,
#    'sharpe_ratio': 1.354321748458312,
#    'return_drawdown_ratio': 5.060507945755248}),
#  ("{'atr_window': 44, 'atr_ma_len': 40}",
#   1.3522590525743277,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 759842.0305999981,
#    'max_drawdown': -24943.702200000524,
#    'max_ddpercent': -4.474797809890931,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 259842.03059999808,
#    'daily_net_pnl': 288.07320465631716,
#    'total_commission': 31337.969399999994,
#    'daily_commission': 34.7427598669623,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044598980.0,
#    'daily_turnover': 1158091.9955654102,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 51.96840611999962,
#    'annual_return': 13.827513823503224,
#    'daily_return': 0.0455742879084862,
#    'return_std': 0.5221143323057983,
#    'sharpe_ratio': 1.3522590525743277,
#    'return_drawdown_ratio': 11.61357637324541}),
#  ("{'atr_window': 56, 'atr_ma_len': 40}",
#   1.351987204186694,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 761788.0903999986,
#    'max_drawdown': -22961.68800000043,
#    'max_ddpercent': -4.119232596266269,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 261788.0903999986,
#    'daily_net_pnl': 290.230698891351,
#    'total_commission': 31251.909599999995,
#    'daily_commission': 34.64734988913525,
#    'total_slippage': 83520.0,
#    'daily_slippage': 92.59423503325942,
#    'total_turnover': 1041730320.0,
#    'daily_turnover': 1154911.6629711753,
#    'total_trade_count': 1392,
#    'daily_trade_count': 1.5432372505543237,
#    'total_return': 52.357618079999725,
#    'annual_return': 13.931073546784848,
#    'daily_return': 0.0458578647622265,
#    'return_std': 0.5254687203155207,
#    'sharpe_ratio': 1.351987204186694,
#    'return_drawdown_ratio': 12.71052722962462}),
#  ("{'atr_window': 20, 'atr_ma_len': 16}",
#   1.3466168596572936,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 201,
#    'loss_days': 206,
#    'capital': 500000,
#    'end_balance': 763637.8339999972,
#    'max_drawdown': -48891.138000000676,
#    'max_ddpercent': -8.690333205112577,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 263637.83399999724,
#    'daily_net_pnl': 292.28141241684835,
#    'total_commission': 32162.165999999994,
#    'daily_commission': 35.656503325942346,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1072072200.0,
#    'daily_turnover': 1188550.110864745,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 52.72756679999944,
#    'annual_return': 14.029507796008719,
#    'daily_return': 0.0464970935690945,
#    'return_std': 0.5349182070569974,
#    'sharpe_ratio': 1.3466168596572936,
#    'return_drawdown_ratio': 6.067381486475051}),
#  ("{'atr_window': 52, 'atr_ma_len': 40}",
#   1.3435953045566529,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 758690.5081999983,
#    'max_drawdown': -21701.72580000048,
#    'max_ddpercent': -3.893200548260779,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 258690.50819999815,
#    'daily_net_pnl': 286.7965722838117,
#    'total_commission': 31289.491799999996,
#    'daily_commission': 34.689015299334805,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1042983060.0,
#    'daily_turnover': 1156300.509977827,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 51.738101639999655,
#    'annual_return': 13.766235469622968,
#    'daily_return': 0.045406147604002633,
#    'return_std': 0.5235423282273698,
#    'sharpe_ratio': 1.3435953045566529,
#    'return_drawdown_ratio': 13.289349212465504}),
#  ("{'atr_window': 48, 'atr_ma_len': 38}",
#   1.3359506613953045,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 756404.4895999985,
#    'max_drawdown': -24943.702200000524,
#    'max_ddpercent': -4.474797809890931,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 256404.48959999846,
#    'daily_net_pnl': 284.262183592016,
#    'total_commission': 31355.5104,
#    'daily_commission': 34.762206651884696,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1045183680.0,
#    'daily_turnover': 1158740.22172949,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 51.2808979199997,
#    'annual_return': 13.644584812416772,
#    'daily_return': 0.04507159556354149,
#    'return_std': 0.5226586401694665,
#    'sharpe_ratio': 1.3359506613953045,
#    'return_drawdown_ratio': 11.459936314139215}),
#  ("{'atr_window': 24, 'atr_ma_len': 20}",
#   1.334895017219982,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 208,
#    'capital': 500000,
#    'end_balance': 759524.0749999976,
#    'max_drawdown': -39460.58820000052,
#    'max_ddpercent': -7.134325428349536,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 259524.07499999757,
#    'daily_net_pnl': 287.7207039911281,
#    'total_commission': 31655.925,
#    'daily_commission': 35.095260532150775,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1055197500.0,
#    'daily_turnover': 1169842.0177383593,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 51.90481499999953,
#    'annual_return': 13.810593791574155,
#    'daily_return': 0.04589824462363056,
#    'return_std': 0.5326655197730237,
#    'sharpe_ratio': 1.334895017219982,
#    'return_drawdown_ratio': 7.2753640861049504}),
#  ("{'atr_window': 20, 'atr_ma_len': 22}",
#   1.3340572213212853,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 207,
#    'capital': 500000,
#    'end_balance': 760508.0149999975,
#    'max_drawdown': -42341.29020000063,
#    'max_ddpercent': -7.655145478621818,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 260508.01499999734,
#    'daily_net_pnl': 288.81154656318995,
#    'total_commission': 31631.984999999997,
#    'daily_commission': 35.068719512195116,
#    'total_slippage': 84480.0,
#    'daily_slippage': 93.65853658536585,
#    'total_turnover': 1054399500.0,
#    'daily_turnover': 1168957.3170731708,
#    'total_trade_count': 1408,
#    'daily_trade_count': 1.5609756097560976,
#    'total_return': 52.101602999999486,
#    'annual_return': 13.862954235033122,
#    'daily_return': 0.046041773530894975,
#    'return_std': 0.5346667871964228,
#    'sharpe_ratio': 1.3340572213212853,
#    'return_drawdown_ratio': 6.806089204379107}),
#  ("{'atr_window': 32, 'atr_ma_len': 26}",
#   1.329201615880061,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 767009.2645999973,
#    'max_drawdown': -29881.455000000657,
#    'max_ddpercent': -5.403664886979857,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 267009.2645999973,
#    'daily_net_pnl': 296.0191403547642,
#    'total_commission': 31130.735399999998,
#    'daily_commission': 34.513010421286026,
#    'total_slippage': 83280.0,
#    'daily_slippage': 92.32815964523282,
#    'total_turnover': 1037691180.0,
#    'daily_turnover': 1150433.6807095343,
#    'total_trade_count': 1388,
#    'daily_trade_count': 1.5388026607538803,
#    'total_return': 53.401852919999456,
#    'annual_return': 14.20891873702868,
#    'daily_return': 0.04661512195521271,
#    'return_std': 0.5433023518992091,
#    'sharpe_ratio': 1.329201615880061,
#    'return_drawdown_ratio': 9.882524922792927}),
#  ("{'atr_window': 40, 'atr_ma_len': 18}",
#   1.3208531347050896,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 210,
#    'capital': 500000,
#    'end_balance': 757560.4807999978,
#    'max_drawdown': -50130.12600000069,
#    'max_ddpercent': -8.92397763310703,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 257560.48079999775,
#    'daily_net_pnl': 285.54377028824587,
#    'total_commission': 31879.5192,
#    'daily_commission': 35.343147671840356,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062650640.0,
#    'daily_turnover': 1178104.9223946785,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 51.512096159999565,
#    'annual_return': 13.706100973835806,
#    'daily_return': 0.04524089762407134,
#    'return_std': 0.5306183964339812,
#    'sharpe_ratio': 1.3208531347050896,
#    'return_drawdown_ratio': 5.772324660350451}),
#  ("{'atr_window': 24, 'atr_ma_len': 34}",
#   1.3196718183647909,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 754403.545399998,
#    'max_drawdown': -28486.861800000304,
#    'max_ddpercent': -5.04204212538724,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 254403.54539999788,
#    'daily_net_pnl': 282.04384190687125,
#    'total_commission': 31256.454599999997,
#    'daily_commission': 34.652388691796006,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1041881820.0,
#    'daily_turnover': 1155079.623059867,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.8807090799996,
#    'annual_return': 13.538104411529826,
#    'daily_return': 0.044777932446744564,
#    'return_std': 0.5256585288264558,
#    'sharpe_ratio': 1.3196718183647909,
#    'return_drawdown_ratio': 10.091289960432817}),
#  ("{'atr_window': 32, 'atr_ma_len': 32}",
#   1.3148201601012595,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 754223.5249999983,
#    'max_drawdown': -26520.42540000053,
#    'max_ddpercent': -4.723088253090257,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 254223.52499999816,
#    'daily_net_pnl': 281.84426274944366,
#    'total_commission': 31196.475,
#    'daily_commission': 34.58589246119734,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1039882500.0,
#    'daily_turnover': 1152863.0820399113,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.84470499999965,
#    'annual_return': 13.5285246119733,
#    'daily_return': 0.04475147406451193,
#    'return_std': 0.5272864503590808,
#    'sharpe_ratio': 1.3148201601012595,
#    'return_drawdown_ratio': 10.765139729653072}),
#  ("{'atr_window': 52, 'atr_ma_len': 36}",
#   1.3143068008788616,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 752489.5975999981,
#    'max_drawdown': -27463.62660000054,
#    'max_ddpercent': -4.95405809512727,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252489.59759999806,
#    'daily_net_pnl': 279.9219485587562,
#    'total_commission': 31310.4024,
#    'daily_commission': 34.7121977827051,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043680080.0,
#    'daily_turnover': 1157073.2594235034,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.49791951999963,
#    'annual_return': 13.4362535308203,
#    'daily_return': 0.04449630736947833,
#    'return_std': 0.5244847163370944,
#    'sharpe_ratio': 1.3143068008788616,
#    'return_drawdown_ratio': 10.193243306869684}),
#  ("{'atr_window': 56, 'atr_ma_len': 36}",
#   1.3082223353474187,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 751049.5507999983,
#    'max_drawdown': -27463.62660000054,
#    'max_ddpercent': -4.947632015161298,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 251049.55079999828,
#    'daily_net_pnl': 278.3254443458961,
#    'total_commission': 31310.4492,
#    'daily_commission': 34.712249667405764,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043681640.0,
#    'daily_turnover': 1157074.9889135256,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.20991015999967,
#    'annual_return': 13.359621328603017,
#    'daily_return': 0.04428394113974205,
#    'return_std': 0.5244092289346308,
#    'sharpe_ratio': 1.3082223353474187,
#    'return_drawdown_ratio': 10.148270931657551}),
#  ("{'atr_window': 28, 'atr_ma_len': 36}",
#   1.3070478117495554,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 752372.2639999983,
#    'max_drawdown': -27780.38760000025,
#    'max_ddpercent': -4.980464908122983,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252372.26399999828,
#    'daily_net_pnl': 279.7918669623041,
#    'total_commission': 31187.735999999997,
#    'daily_commission': 34.57620399113082,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1039591200.0,
#    'daily_turnover': 1152540.133037694,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.47445279999967,
#    'annual_return': 13.430009614190599,
#    'daily_return': 0.04447901919173455,
#    'return_std': 0.5271926521330228,
#    'sharpe_ratio': 1.3070478117495554,
#    'return_drawdown_ratio': 10.134486183745098}),
#  ("{'atr_window': 32, 'atr_ma_len': 34}",
#   1.3068775759458102,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 750691.0357999986,
#    'max_drawdown': -27780.387600000366,
#    'max_ddpercent': -4.9474780423338665,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 250691.03579999847,
#    'daily_net_pnl': 277.9279776053198,
#    'total_commission': 31128.964200000002,
#    'daily_commission': 34.5110467849224,
#    'total_slippage': 83280.0,
#    'daily_slippage': 92.32815964523282,
#    'total_turnover': 1037632140.0,
#    'daily_turnover': 1150368.2261640797,
#    'total_trade_count': 1388,
#    'daily_trade_count': 1.5388026607538803,
#    'total_return': 50.1382071599997,
#    'annual_return': 13.340542925055352,
#    'daily_return': 0.04423100699763072,
#    'return_std': 0.5243213492704712,
#    'sharpe_ratio': 1.3068775759458102,
#    'return_drawdown_ratio': 10.134093922395273}),
#  ("{'atr_window': 60, 'atr_ma_len': 34}",
#   1.3061289973050922,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 753989.1709999982,
#    'max_drawdown': -29683.909200000577,
#    'max_ddpercent': -5.354566343662814,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 253989.1709999982,
#    'daily_net_pnl': 281.5844467849204,
#    'total_commission': 31310.828999999998,
#    'daily_commission': 34.71267073170731,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043694300.0,
#    'daily_turnover': 1157089.024390244,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.797834199999635,
#    'annual_return': 13.516053445676178,
#    'daily_return': 0.044717020572998305,
#    'return_std': 0.530386436036785,
#    'sharpe_ratio': 1.3061289973050922,
#    'return_drawdown_ratio': 9.486825064763538}),
#  ("{'atr_window': 36, 'atr_ma_len': 34}",
#   1.303326538207579,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 222,
#    'capital': 500000,
#    'end_balance': 750145.899199998,
#    'max_drawdown': -26760.418200000422,
#    'max_ddpercent': -4.758202336164025,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 250145.89919999812,
#    'daily_net_pnl': 277.32361330376733,
#    'total_commission': 31374.1008,
#    'daily_commission': 34.78281685144124,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1045803360.0,
#    'daily_turnover': 1159427.2283813746,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
#    'total_return': 50.02917983999959,
#    'annual_return': 13.311533438580822,
#    'daily_return': 0.04415047002335509,
#    'return_std': 0.5247926137155049,
#    'sharpe_ratio': 1.303326538207579,
#    'return_drawdown_ratio': 10.514302735669746}),
#  ("{'atr_window': 60, 'atr_ma_len': 30}",
#   1.2993163995149517,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 202,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 752644.5751999983,
#    'max_drawdown': -29320.27020000061,
#    'max_ddpercent': -5.237959869233035,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': 252644.57519999827,
#    'daily_net_pnl': 280.0937640798207,
#    'total_commission': 31275.424799999997,
#    'daily_commission': 34.6734199556541,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1042514160.0,
#    'daily_turnover': 1155780.6651884702,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.52891503999965,
#    'annual_return': 13.444500675831394,
#    'daily_return': 0.04451913796156451,
#    'return_std': 0.530807984804984,
#    'sharpe_ratio': 1.2993163995149517,
#    'return_drawdown_ratio': 9.646678535434889}),
#  ("{'atr_window': 24, 'atr_ma_len': 18}",
#   1.2980663922630302,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 210,
#    'capital': 500000,
#    'end_balance': 752580.1909999975,
#    'max_drawdown': -48952.39260000066,
#    'max_ddpercent': -8.802651560363723,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252580.19099999728,
#    'daily_net_pnl': 280.0223847006622,
#    'total_commission': 31879.808999999994,
#    'daily_commission': 35.34346895787139,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062660300.0,
#    'daily_turnover': 1178115.6319290465,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 50.5160381999995,
#    'annual_return': 13.441074465631797,
#    'daily_return': 0.04488001147938836,
#    'return_std': 0.5356260298342194,
#    'sharpe_ratio': 1.2980663922630302,
#    'return_drawdown_ratio': 5.738729728603752}),
#  ("{'atr_window': 28, 'atr_ma_len': 30}",
#   1.297645854762482,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 752944.3633999976,
#    'max_drawdown': -28500.049200000474,
#    'max_ddpercent': -5.125488492110252,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252944.36339999767,
#    'daily_net_pnl': 280.42612350332337,
#    'total_commission': 31155.636599999998,
#    'daily_commission': 34.54061707317073,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1038521220.0,
#    'daily_turnover': 1151353.9024390243,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.58887267999952,
#    'annual_return': 13.460453928159517,
#    'daily_return': 0.04456328805052636,
#    'return_std': 0.5320184142337466,
#    'sharpe_ratio': 1.297645854762482,
#    'return_drawdown_ratio': 9.870058777396885}),
#  ("{'atr_window': 28, 'atr_ma_len': 16}",
#   1.2970646524473046,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 751715.6203999978,
#    'max_drawdown': -47392.497000000556,
#    'max_ddpercent': -8.588832048367117,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 251715.62039999777,
#    'daily_net_pnl': 279.0638807095319,
#    'total_commission': 32204.3796,
#    'daily_commission': 35.70330332594235,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1073479320.0,
#    'daily_turnover': 1190110.110864745,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 50.34312407999957,
#    'annual_return': 13.395066274057536,
#    'daily_return': 0.04475257589266368,
#    'return_std': 0.5345176304207755,
#    'sharpe_ratio': 1.2970646524473046,
#    'return_drawdown_ratio': 5.861463327783975}),
#  ("{'atr_window': 32, 'atr_ma_len': 40}",
#   1.2953462369796027,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 753917.527399998,
#    'max_drawdown': -30955.38480000035,
#    'max_ddpercent': -5.533020540821168,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 253917.52739999813,
#    'daily_net_pnl': 281.50501929046357,
#    'total_commission': 31382.472599999997,
#    'daily_commission': 34.79209822616408,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1046082420.0,
#    'daily_turnover': 1159736.6075388025,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
#    'total_return': 50.78350547999961,
#    'annual_return': 13.512240925942248,
#    'daily_return': 0.0447064857707322,
#    'return_std': 0.5346755019298556,
#    'sharpe_ratio': 1.2953462369796027,
#    'return_drawdown_ratio': 9.178260789984835}),
#  ("{'atr_window': 20, 'atr_ma_len': 24}",
#   1.295183846834247,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 212,
#    'capital': 500000,
#    'end_balance': 754436.6233999974,
#    'max_drawdown': -35124.94319999986,
#    'max_ddpercent': -5.564454374446332,
#    'max_drawdown_duration': 92,
#    'total_net_pnl': 254436.62339999725,
#    'daily_net_pnl': 282.0805137472253,
#    'total_commission': 31703.3766,
#    'daily_commission': 35.147867627494456,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1056779220.0,
#    'daily_turnover': 1171595.5875831486,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 50.88732467999948,
#    'annual_return': 13.539864659866824,
#    'daily_return': 0.04478279337782512,
#    'return_std': 0.5356552689346846,
#    'sharpe_ratio': 1.295183846834247,
#    'return_drawdown_ratio': 9.145069984523472}),
#  ("{'atr_window': 28, 'atr_ma_len': 38}",
#   1.2949583120937822,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 749841.5017999981,
#    'max_drawdown': -29220.344400000293,
#    'max_ddpercent': -5.23018844078835,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 249841.501799998,
#    'daily_net_pnl': 276.9861439024368,
#    'total_commission': 31378.498199999995,
#    'daily_commission': 34.78769201773835,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1045949940.0,
#    'daily_turnover': 1159589.733924612,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
# ...
#    'capital': 500000,
#    'end_balance': 729131.9185999976,
#    'max_drawdown': -31966.872600000526,
#    'max_ddpercent': -5.773263414750239,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 229131.91859999768,
#    'daily_net_pnl': 254.02651729489764,
#    'total_commission': 31568.081399999995,
#    'daily_commission': 34.997872949002215,
#    'total_slippage': 84360.0,
#    'daily_slippage': 93.52549889135256,
#    'total_turnover': 1052269380.0,
#    'daily_turnover': 1166595.7649667405,
#    'total_trade_count': 1406,
#    'daily_trade_count': 1.558758314855876,
#    'total_return': 45.82638371999952,
#    'annual_return': 12.193272830155083,
#    'daily_return': 0.041000464930078265,
#    'return_std': 0.5424677917676795,
#    'sharpe_ratio': 1.1709017218774198,
#    'return_drawdown_ratio': 7.93769146284174}),
#  ("{'atr_window': 24, 'atr_ma_len': 30}",
#   1.1695049524094758,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 732481.1425999972,
#    'max_drawdown': -31561.393800000602,
#    'max_ddpercent': -5.728595712876029,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 232481.1425999973,
#    'daily_net_pnl': 257.73962594234735,
#    'total_commission': 31458.857399999997,
#    'daily_commission': 34.876782039911305,
#    'total_slippage': 84120.0,
#    'daily_slippage': 93.25942350332595,
#    'total_turnover': 1048628580.0,
#    'daily_turnover': 1162559.401330377,
#    'total_trade_count': 1402,
#    'daily_trade_count': 1.5543237250554325,
#    'total_return': 46.49622851999944,
#    'annual_return': 12.371502045232669,
#    'daily_return': 0.041508549490204584,
#    'return_std': 0.5498460543312058,
#    'sharpe_ratio': 1.1695049524094758,
#    'return_drawdown_ratio': 8.116514212286088}),
#  ("{'atr_window': 24, 'atr_ma_len': 24}",
#   1.167735092241468,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 727039.1359999974,
#    'max_drawdown': -38903.42880000069,
#    'max_ddpercent': -6.466969517876126,
#    'max_drawdown_duration': 149,
#    'total_net_pnl': 227039.13599999715,
#    'daily_net_pnl': 251.70635920177068,
#    'total_commission': 31680.863999999994,
#    'daily_commission': 35.12290909090908,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1056028800.0,
#    'daily_turnover': 1170763.6363636365,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 45.407827199999474,
#    'annual_return': 12.081905241685003,
#    'daily_return': 0.040681799113556134,
#    'return_std': 0.5397112119260619,
#    'sharpe_ratio': 1.167735092241468,
#    'return_drawdown_ratio': 7.021500112917225}),
#  ("{'atr_window': 20, 'atr_ma_len': 36}",
#   1.1606845725472168,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 727953.8869999978,
#    'max_drawdown': -30046.80420000048,
#    'max_ddpercent': -5.466786434566879,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 227953.88699999778,
#    'daily_net_pnl': 252.72049556540773,
#    'total_commission': 31666.112999999998,
#    'daily_commission': 35.1065554323725,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1055537100.0,
#    'daily_turnover': 1170218.5144124168,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 45.59077739999955,
#    'annual_return': 12.130583787139571,
#    'daily_return': 0.0408211999878176,
#    'return_std': 0.5448502770328274,
#    'sharpe_ratio': 1.1606845725472168,
#    'return_drawdown_ratio': 8.339593643484191}),
#  ("{'atr_window': 44, 'atr_ma_len': 18}",
#   1.1575784042656174,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 725010.2209999979,
#    'max_drawdown': -49470.15660000057,
#    'max_ddpercent': -8.941164385770962,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 225010.22099999795,
#    'daily_net_pnl': 249.45700776052988,
#    'total_commission': 32089.779,
#    'daily_commission': 35.576251662971174,
#    'total_slippage': 85560.0,
#    'daily_slippage': 94.85587583148559,
#    'total_turnover': 1069659300.0,
#    'daily_turnover': 1185875.0554323725,
#    'total_trade_count': 1426,
#    'daily_trade_count': 1.580931263858093,
#    'total_return': 45.00204419999958,
#    'annual_return': 11.973936372505433,
#    'daily_return': 0.04037198142116664,
#    'return_std': 0.5403003757547479,
#    'sharpe_ratio': 1.1575784042656174,
#    'return_drawdown_ratio': 5.033130167209114}),
#  ("{'atr_window': 60, 'atr_ma_len': 20}",
#   1.1557338266791317,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 731587.4731999976,
#    'max_drawdown': -35929.38120000053,
#    'max_ddpercent': -6.488890420836905,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 231587.47319999756,
#    'daily_net_pnl': 256.7488616407955,
#    'total_commission': 31812.526799999996,
#    'daily_commission': 35.26887671840354,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1060417560.0,
#    'daily_turnover': 1175629.2239467849,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 46.31749463999952,
#    'annual_return': 12.32394535875819,
#    'daily_return': 0.04137320550237356,
#    'return_std': 0.5545835284594364,
#    'sharpe_ratio': 1.1557338266791317,
#    'return_drawdown_ratio': 7.137968379195671}),
#  ("{'atr_window': 36, 'atr_ma_len': 16}",
#   1.148728091198126,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 728270.2495999984,
#    'max_drawdown': -48437.62980000046,
#    'max_ddpercent': -8.844588488217079,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 228270.2495999984,
#    'daily_net_pnl': 253.07123015520887,
#    'total_commission': 32249.750399999997,
#    'daily_commission': 35.75360354767184,
#    'total_slippage': 86040.0,
#    'daily_slippage': 95.3880266075388,
#    'total_turnover': 1074991680.0,
#    'daily_turnover': 1191786.7849223947,
#    'total_trade_count': 1434,
#    'daily_trade_count': 1.58980044345898,
#    'total_return': 45.654049919999665,
#    'annual_return': 12.147419047450022,
#    'daily_return': 0.04086937040149301,
#    'return_std': 0.5511709590730796,
#    'sharpe_ratio': 1.148728091198126,
#    'return_drawdown_ratio': 5.1618059993204675}),
#  ("{'atr_window': 48, 'atr_ma_len': 18}",
#   1.1476165478458453,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 725280.6223999986,
#    'max_drawdown': -50497.53120000049,
#    'max_ddpercent': -9.126850581564506,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 225280.62239999865,
#    'daily_net_pnl': 249.75678758314706,
#    'total_commission': 31999.377599999996,
#    'daily_commission': 35.47602838137472,
#    'total_slippage': 85320.0,
#    'daily_slippage': 94.58980044345898,
#    'total_turnover': 1066645920.0,
#    'daily_turnover': 1182534.2793791573,
#    'total_trade_count': 1422,
#    'daily_trade_count': 1.5764966740576496,
#    'total_return': 45.05612447999972,
#    'annual_return': 11.988325803991057,
#    'daily_return': 0.04041332207052059,
#    'return_std': 0.5455485062073804,
#    'sharpe_ratio': 1.1476165478458453,
#    'return_drawdown_ratio': 4.9366563062848225}),
#  ("{'atr_window': 48, 'atr_ma_len': 20}",
#   1.1454120143826803,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 729784.5133999983,
#    'max_drawdown': -33116.47200000059,
#    'max_ddpercent': -6.0636755985153865,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 229784.5133999983,
#    'daily_net_pnl': 254.75001485587396,
#    'total_commission': 31755.486599999997,
#    'daily_commission': 35.20563924611973,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1058516220.0,
#    'daily_turnover': 1173521.308203991,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 45.95690267999966,
#    'annual_return': 12.228000713081949,
#    'daily_return': 0.04109964780215551,
#    'return_std': 0.5558812007346637,
#    'sharpe_ratio': 1.1454120143826803,
#    'return_drawdown_ratio': 7.579050352108483}),
#  ("{'atr_window': 28, 'atr_ma_len': 22}",
#   1.1349783709023278,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 192,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 723268.9567999976,
#    'max_drawdown': -37048.64640000055,
#    'max_ddpercent': -6.770962144324557,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 223268.95679999748,
#    'daily_net_pnl': 247.52655964523004,
#    'total_commission': 31851.0432,
#    'daily_commission': 35.311577827050996,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1061701440.0,
#    'daily_turnover': 1177052.5942350333,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 44.653791359999516,
#    'annual_return': 11.881274862971045,
#    'daily_return': 0.040105396210930816,
#    'return_std': 0.5474202349582996,
#    'sharpe_ratio': 1.1349783709023278,
#    'return_drawdown_ratio': 6.594896029278273}),
#  ("{'atr_window': 56, 'atr_ma_len': 20}",
#   1.1147327177232487,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 722063.614999998,
#    'max_drawdown': -35929.38120000053,
#    'max_ddpercent': -6.488890420836905,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 222063.614999998,
#    'daily_net_pnl': 246.19026053214859,
#    'total_commission': 31916.385,
#    'daily_commission': 35.38401884700665,
#    'total_slippage': 85200.0,
#    'daily_slippage': 94.45676274944567,
#    'total_turnover': 1063879500.0,
#    'daily_turnover': 1179467.2949002218,
#    'total_trade_count': 1420,
#    'daily_trade_count': 1.5742793791574279,
#    'total_return': 44.41272299999961,
#    'annual_return': 11.817132505543134,
#    'daily_return': 0.0399204838317394,
#    'return_std': 0.5547926120573562,
#    'sharpe_ratio': 1.1147327177232487,
#    'return_drawdown_ratio': 6.844424873840214}),
#  ("{'atr_window': 52, 'atr_ma_len': 18}",
#   1.1118591208893946,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 718695.5065999983,
#    'max_drawdown': -50497.53120000049,
#    'max_ddpercent': -9.126850581564506,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 218695.5065999983,
#    'daily_net_pnl': 242.45621574279193,
#    'total_commission': 32164.4934,
#    'daily_commission': 35.65908359201774,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1072149780.0,
#    'daily_turnover': 1188636.1197339245,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 43.739101319999676,
#    'annual_return': 11.637898355654016,
#    'daily_return': 0.039402138809928385,
#    'return_std': 0.5490041842485772,
#    'sharpe_ratio': 1.1118591208893946,
#    'return_drawdown_ratio': 4.792354266032261}),
#  ("{'atr_window': 28, 'atr_ma_len': 24}",
#   1.1073061113728793,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 191,
#    'loss_days': 220,
#    'capital': 500000,
#    'end_balance': 719732.7997999975,
#    'max_drawdown': -37048.64640000049,
#    'max_ddpercent': -6.777719445265888,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 219732.79979999742,
#    'daily_net_pnl': 243.60620820398827,
#    'total_commission': 31847.2002,
#    'daily_commission': 35.30731729490022,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1061573340.0,
#    'daily_turnover': 1176910.576496674,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 43.9465599599995,
#    'annual_return': 11.69309799379144,
#    'daily_return': 0.03956203453158815,
#    'return_std': 0.553498619069128,
#    'sharpe_ratio': 1.1073061113728793,
#    'return_drawdown_ratio': 6.48397448653549}),
#  ("{'atr_window': 52, 'atr_ma_len': 20}",
#   1.1059072817752214,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 192,
#    'loss_days': 221,
#    'capital': 500000,
#    'end_balance': 721376.763799998,
#    'max_drawdown': -35929.38120000047,
#    'max_ddpercent': -6.537068477898904,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 221376.76379999807,
#    'daily_net_pnl': 245.42878470066304,
#    'total_commission': 31883.236199999996,
#    'daily_commission': 35.34726851441241,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062774540.0,
#    'daily_turnover': 1178242.2838137473,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 44.275352759999585,
#    'annual_return': 11.780581665631818,
#    'daily_return': 0.039814975367359,
#    'return_std': 0.557742006291562,
#    'sharpe_ratio': 1.1059072817752214,
#    'return_drawdown_ratio': 6.772967563318265}),
#  ("{'atr_window': 56, 'atr_ma_len': 18}",
#   1.1023273719191053,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 716980.9057999982,
#    'max_drawdown': -50497.53120000055,
#    'max_ddpercent': -9.145695115194288,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 216980.90579999826,
#    'daily_net_pnl': 240.5553279379138,
#    'total_commission': 32079.094199999996,
#    'daily_commission': 35.56440598669623,
#    'total_slippage': 85560.0,
#    'daily_slippage': 94.85587583148559,
#    'total_turnover': 1069303140.0,
#    'daily_turnover': 1185480.199556541,
#    'total_trade_count': 1426,
#    'daily_trade_count': 1.580931263858093,
#    'total_return': 43.396181159999635,
#    'annual_return': 11.546655741019858,
#    'daily_return': 0.03913733140733933,
#    'return_std': 0.55002982459461,
#    'sharpe_ratio': 1.1023273719191053,
#    'return_drawdown_ratio': 4.744984455900238}),
#  ("{'atr_window': 60, 'atr_ma_len': 18}",
#   1.0759144264198126,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 220,
#    'capital': 500000,
#    'end_balance': 712583.6449999979,
#    'max_drawdown': -50616.282000000414,
#    'max_ddpercent': -9.16720227773621,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 212583.64499999792,
#    'daily_net_pnl': 235.680315964521,
#    'total_commission': 32036.354999999996,
#    'daily_commission': 35.51702328159645,
#    'total_slippage': 85440.0,
#    'daily_slippage': 94.72283813747228,
#    'total_turnover': 1067878500.0,
#    'daily_turnover': 1183900.7760532151,
#    'total_trade_count': 1424,
#    'daily_trade_count': 1.5787139689578713,
#    'total_return': 42.516728999999586,
#    'annual_return': 11.312655166297008,
#    'daily_return': 0.03845530171576409,
#    'return_std': 0.5537122264049725,
#    'sharpe_ratio': 1.0759144264198126,
#    'return_drawdown_ratio': 4.6379176232706465})]

# %%
# 样本外。2019
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IH9999.CFFEX",
    interval="1m",
    start=datetime(2014, 1, 1),
    end=datetime(2019, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 24, 'atr_ma_len': 16, 'trailing_short':0.55,'trailing_long':0.55})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-16 19:56:03.517048	开始加载历史数据
# 2019-12-16 19:56:03.517048	加载进度： [2%]
# 2019-12-16 19:56:03.517048	加载进度： [3%]
# 2019-12-16 19:56:03.517048	加载进度： [5%]
# 2019-12-16 19:56:03.518049	加载进度： [7%]
# 2019-12-16 19:56:03.518049	加载进度： [8%]
# 2019-12-16 19:56:03.518049	加载进度： [10%]
# 2019-12-16 19:56:03.518049	加载进度：# [12%]
# 2019-12-16 19:56:03.518049	加载进度：# [13%]
# 2019-12-16 19:56:03.518049	加载进度：# [15%]
# 2019-12-16 19:56:03.518049	加载进度：# [16%]
# 2019-12-16 19:56:03.518049	加载进度：# [18%]
# 2019-12-16 19:56:03.518049	加载进度：# [20%]
# 2019-12-16 19:56:03.518049	加载进度：## [21%]
# 2019-12-16 19:56:03.518049	加载进度：## [23%]
# 2019-12-16 19:56:03.518049	加载进度：## [25%]
# 2019-12-16 19:56:03.518049	加载进度：## [26%]
# 2019-12-16 19:56:03.518049	加载进度：## [28%]
# 2019-12-16 19:56:03.518049	加载进度：## [30%]
# 2019-12-16 19:56:03.518049	加载进度：### [31%]
# 2019-12-16 19:56:03.518049	加载进度：### [33%]
# 2019-12-16 19:56:03.518049	加载进度：### [35%]
# 2019-12-16 19:56:03.518049	加载进度：### [36%]
# 2019-12-16 19:56:03.518049	加载进度：### [38%]
# 2019-12-16 19:56:03.518049	加载进度：### [39%]
# 2019-12-16 19:56:03.518049	加载进度：#### [41%]
# 2019-12-16 19:56:03.519050	加载进度：#### [43%]
# 2019-12-16 19:56:03.519050	加载进度：#### [44%]
# 2019-12-16 19:56:03.519050	加载进度：#### [46%]
# 2019-12-16 19:56:03.519050	加载进度：#### [48%]
# 2019-12-16 19:56:03.519050	加载进度：#### [49%]
# 2019-12-16 19:56:03.519050	加载进度：##### [51%]
# 2019-12-16 19:56:03.519050	加载进度：##### [53%]
# 2019-12-16 19:56:03.519050	加载进度：##### [54%]
# 2019-12-16 19:56:03.519050	加载进度：##### [56%]
# 2019-12-16 19:56:03.519050	加载进度：##### [58%]
# 2019-12-16 19:56:03.519050	加载进度：##### [59%]
# 2019-12-16 19:56:03.520051	加载进度：###### [61%]
# 2019-12-16 19:56:03.520051	加载进度：###### [62%]
# 2019-12-16 19:56:03.520051	加载进度：###### [64%]
# 2019-12-16 19:56:03.520051	加载进度：###### [66%]
# 2019-12-16 19:56:03.520051	加载进度：###### [67%]
# 2019-12-16 19:56:03.520051	加载进度：###### [69%]
# 2019-12-16 19:56:03.520051	加载进度：####### [71%]
# 2019-12-16 19:56:03.520051	加载进度：####### [72%]
