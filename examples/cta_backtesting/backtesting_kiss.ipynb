# %%
#%%
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from vnpy.app.cta_strategy.strategies.tsmyo_kiss_strategy import (
    TSMyoKISSStrategy,
)
from datetime import datetime

# %%
# 基于5分钟的KISS，在国债上验证一下
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="TF9999.CFFEX",
    interval="1m",
    start=datetime(2016, 1, 1),
    end=datetime(2020, 1, 1),
    rate=0.03/10000,
    slippage=0.005,
    size=10000,
    pricetick=0.005,
    capital=500_000,
)
#engine.add_strategy(TSMyoRBKStrategy, {'limited_size':8,'fixed_size': 1,'atr_stop': 4, 'atr_window': 44, 'atr_ma_len': 22, 'trailing_stop':0.55})
engine.add_strategy(TSMyoKISSStrategy, {'ma_len':30,'atr_window':30,'atr_stop':6,'fixed_size':1,'target_atr':24})

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2020-03-13 22:15:14.429706	开始加载历史数据
# 2020-03-13 22:15:15.126588	加载进度： [2%]
# 2020-03-13 22:15:15.376859	加载进度： [4%]
# 2020-03-13 22:15:15.716931	加载进度： [6%]
# 2020-03-13 22:15:16.041850	加载进度： [8%]
# 2020-03-13 22:15:16.339046	加载进度：# [10%]
# 2020-03-13 22:15:16.635322	加载进度：# [12%]
# 2020-03-13 22:15:16.975596	加载进度：# [14%]
# 2020-03-13 22:15:17.565979	加载进度：# [16%]
# 2020-03-13 22:15:17.852193	加载进度：# [18%]
# 2020-03-13 22:15:18.119318	加载进度：## [21%]
# 2020-03-13 22:15:18.463636	加载进度：## [23%]
# 2020-03-13 22:15:18.762799	加载进度：## [25%]
# 2020-03-13 22:15:19.086960	加载进度：## [27%]
# 2020-03-13 22:15:19.367554	加载进度：## [29%]
# 2020-03-13 22:15:19.675825	加载进度：### [31%]
# 2020-03-13 22:15:19.953232	加载进度：### [33%]
# 2020-03-13 22:15:20.584162	加载进度：### [35%]
# 2020-03-13 22:15:20.894701	加载进度：### [37%]
# 2020-03-13 22:15:21.198208	加载进度：### [39%]
# 2020-03-13 22:15:21.547231	加载进度：#### [41%]
# 2020-03-13 22:15:21.889037	加载进度：#### [43%]
# 2020-03-13 22:15:22.134869	加载进度：#### [45%]
# 2020-03-13 22:15:22.470802	加载进度：#### [47%]
# 2020-03-13 22:15:22.816483	加载进度：#### [49%]
# 2020-03-13 22:15:23.478905	加载进度：##### [51%]
# 2020-03-13 22:15:23.772405	加载进度：##### [53%]
# 2020-03-13 22:15:24.065487	加载进度：##### [55%]
# 2020-03-13 22:15:24.381440	加载进度：##### [57%]
# 2020-03-13 22:15:24.667278	加载进度：##### [60%]
# 2020-03-13 22:15:24.976144	加载进度：###### [62%]
# 2020-03-13 22:15:25.319314	加载进度：###### [64%]
# 2020-03-13 22:15:25.642338	加载进度：###### [66%]
# 2020-03-13 22:15:25.950786	加载进度：###### [68%]
# 2020-03-13 22:15:26.196034	加载进度：###### [70%]
# 2020-03-13 22:15:26.901273	加载进度：####### [72%]
# 2020-03-13 22:15:27.232152	加载进度：####### [74%]
# 2020-03-13 22:15:27.527374	加载进度：####### [76%]
# 2020-03-13 22:15:27.784153	加载进度：####### [78%]
# 2020-03-13 22:15:28.138940	加载进度：######## [80%]
# 2020-03-13 22:15:28.426618	加载进度：######## [82%]
# 2020-03-13 22:15:28.735977	加载进度：######## [84%]
# 2020-03-13 22:15:29.060089	加载进度：######## [86%]
# 2020-03-13 22:15:29.403942	加载进度：######## [88%]
# 2020-03-13 22:15:29.706521	加载进度：######### [90%]
# 2020-03-13 22:15:30.062808	加载进度：######### [92%]
# 2020-03-13 22:15:30.720654	加载进度：######### [94%]
# 2020-03-13 22:15:31.028501	加载进度：######### [97%]
# 2020-03-13 22:15:31.372018	加载进度：######### [99%]
# 2020-03-13 22:15:31.614611	加载进度：########## [100%]
# 2020-03-13 22:15:31.615612	历史数据加载完成，数据量：263250
# 2020-03-13 22:15:31.630625	策略初始化完成
# 2020-03-13 22:15:31.630625	开始回放历史数据
# 2020-03-13 22:15:35.421205	历史数据回放结束
# 2020-03-13 22:15:35.421205	开始计算逐日盯市盈亏
# 2020-03-13 22:15:35.430213	逐日盯市盈亏计算完成
# 2020-03-13 22:15:35.430213	开始计算策略统计指标
# 2020-03-13 22:15:35.437219	------------------------------
# 2020-03-13 22:15:35.437219	首个交易日：	2016-01-18
# 2020-03-13 22:15:35.437219	最后交易日：	2019-12-31
# 2020-03-13 22:15:35.437219	总交易日：	965
# 2020-03-13 22:15:35.437219	盈利交易日：	453
# 2020-03-13 22:15:35.438221	亏损交易日：	497
# 2020-03-13 22:15:35.438221	起始资金：	500,000.00
# 2020-03-13 22:15:35.438221	结束资金：	516,818.02
# 2020-03-13 22:15:35.438221	总收益率：	3.36%
# 2020-03-13 22:15:35.438221	年化收益：	0.84%
# 2020-03-13 22:15:35.438221	最大回撤: 	-38,122.76
# 2020-03-13 22:15:35.439222	百分比最大回撤: -6.89%
# 2020-03-13 22:15:35.439222	最长回撤天数: 	629
# 2020-03-13 22:15:35.439222	总盈亏：	16,818.02
# 2020-03-13 22:15:35.439222	总手续费：	1,131.98
# 2020-03-13 22:15:35.439222	总滑点：	19,050.00
# 2020-03-13 22:15:35.439222	总成交金额：	377,326,500.00
# 2020-03-13 22:15:35.440222	总成交笔数：	381
# 2020-03-13 22:15:35.440222	日均盈亏：	17.43
# 2020-03-13 22:15:35.440222	日均手续费：	1.17
# 2020-03-13 22:15:35.440222	日均滑点：	19.74
# 2020-03-13 22:15:35.440222	日均成交金额：	391,011.92
# 2020-03-13 22:15:35.440222	日均成交笔数：	0.39481865284974094
# 2020-03-13 22:15:35.440222	日均收益率：	0.00%
# 2020-03-13 22:15:35.441223	收益标准差：	0.30%
# 2020-03-13 22:15:35.441223	Sharpe Ratio：	-0.69
# 2020-03-13 22:15:35.441223	收益回撤比：	0.49
# 2020-03-13 22:15:35.442224	策略统计指标计算完成

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_window",5, 30, 5) # 
setting.add_parameter("target_atr", 4, 24, 4) # 
setting.add_parameter("ma_len", 5, 40, 5) # 
setting.add_parameter("atr_stop", 2, 6, 2) # 

engine.run_optimization(setting)
# Out:
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：0.5088297551312696
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：0.5082343822260899
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：0.4981326622773948
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：0.4799714438941977
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：0.4135183028158595
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：0.3959471074065668
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：0.3959471074065668
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：0.3929541438410019
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：0.37229230179364164
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：0.2959749048694656
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 6}, 目标：0.22141814204366717
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 6}, 目标：0.22021917312866782
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 6}, 目标：0.21965604847339112
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 6}, 目标：0.18983321009755952
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：0.18798642783779554
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：0.186816505799842
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：0.186816505799842
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：0.17530726196660265
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：0.14851623249337634
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 6}, 目标：0.1388380220846334
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：0.08055436908336616
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 6}, 目标：0.0776053643082186
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 6}, 目标：0.07651692924871199
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 6}, 目标：0.07651692924871199
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 6}, 目标：0.07651692924871199
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：0.07445317916550814
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：0.07445317916550814
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 6}, 目标：0.07445216379951149
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 6}, 目标：0.07445216379951149
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 6}, 目标：0.07397597033087511
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：0.073491572930339
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：0.07248491750783954
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 6}, 目标：0.06280021022930575
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：0.05712366924812853
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：0.05712366924812853
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：0.0567208290450562
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：0.05547521458583302
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：0.05383009212601094
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：0.04954279737450907
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：0.04954279737450907
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：0.04850621840885022
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：0.04742139802192417
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：0.04311411671260159
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：0.04311411671260159
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：0.04311411671260159
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：0.04042302561119284
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 6}, 目标：0.03552725232928393
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 4}, 目标：0.027958130064078667
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 4}, 目标：0.027958130064078667
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 4}, 目标：0.027958130064078667
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 4}, 目标：0.027958130064078667
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 10, 'atr_stop': 4}, 目标：0.0193207487554615
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 4}, 目标：0.01399159575104807
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 4}, 目标：0.012884416800551794
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 4}, 目标：0.012884416800551794
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 4}, 目标：0.012884416800551794
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 4, 'ma_len': 5, 'atr_stop': 6}, 目标：0.002867067574460124
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：0.0006034335043728996
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.0007097756389095397
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.0010207612468247842
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.0015379572223479484
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.0016197386209390173
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.011215321118837811
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.012176616152877174
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.025293435626057917
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.025293435626057917
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.026378956179537637
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.026378956179537637
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.026378956179537637
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.028761572562096226
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.02923019519891671
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.031806434094240374
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.03748424979450346
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.03748424979450346
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.03748424979450346
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.0400641247756377
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.04017940896575897
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.041243435157825345
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.041662574349906834
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.04188754858481999
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.04219867696535488
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.04321185909384749
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.049002557576814605
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.049002557576814605
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.05018735561388124
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.05040078141137573
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.051100278982991944
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.05206569695982052
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.05206569695982052
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.05291306980289546
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.05343545755187238
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.05549720020393734
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.057741108833926295
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.057741108833926295
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.05925763553772296
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.060317463903738225
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.060317463903738225
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.060317463903738225
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.060317463903738225
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.06162936265726226
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.06682125163896407
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.06827478893905431
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.06903804657940417
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.06930459206231003
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.06930459206231003
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.0699748853900687
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.07049774645773374
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.07086064002657218
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.07116308647146671
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.07172194492906588
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.07618027815127201
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.07618027815127201
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.07777791454296658
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.07977689807560924
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.07985705504016145
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.07998781103447944
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.08256692992195025
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.0827030766334242
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.08408278632056088
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.08510343972287976
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.08542293440426686
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.08554068401946628
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.090711605980577
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.09267403820521182
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.09294217887914717
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.09345858698969281
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.0991466908878228
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.09952898209861431
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.1001906681980502
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.1001906681980502
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.10252174607474597
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.10298929920957224
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.10617558507662156
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.1062819498410838
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.10674694502251318
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.1075996619389799
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.1075996619389799
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.1075996619389799
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.10897334060402793
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.11000539600649879
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.11062553704832648
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.11161594644600766
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.11161594644600766
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.11161594644600766
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.11274817927690425
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.11331578922159055
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.11363921926269364
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.11529268221217061
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.11529268221217061
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.11529268221217061
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.11542849028604901
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.11652665174859901
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.11652665174859901
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.11652665174859901
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.11680574222876328
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.11768383766611976
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.11871921204636453
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.11946098110843259
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.11955666043157356
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.12012567082247383
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.120235234431971
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.12107443990735865
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.1225043122885666
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.1225043122885666
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.1225043122885666
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.12284805021314972
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.12284805021314972
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.12381115156590597
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.12905226466035163
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.13308670210258502
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.13388595623392036
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.13410774634827285
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.13410774634827285
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.1354491778124506
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.13630591571750503
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.14304233728667884
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.14614502032937382
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.1464797829740713
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.1496419265794121
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.1496419265794121
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.15184014593771578
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.15184014593771578
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.15196074609300603
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.15268454089587585
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.153567685498007
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.15554295980903343
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.1599889580990393
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.16024695387532611
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.1603101871573635
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.1607583353358016
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.16219242004028658
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.16537485221157766
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.16610670981171938
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.16610670981171938
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.16610670981171938
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.16654861715804412
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.16990655628343482
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.16990655628343482
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.16990655628343482
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.17065450864864584
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.17109538473035463
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.17109538473035463
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.1719079297004508
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.17219074273927976
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.17334310186118224
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.1734998640258542
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.1734998640258542
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.1734998640258542
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.17387708981754493
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.17387708981754493
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.17411977550864016
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.17427483886433215
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.17608301932284393
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 15, 'atr_stop': 6}, 目标：-0.17879513189259164
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.18003147254138868
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.18003746193351483
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.1815374499516965
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.18309804798930612
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.18333218459976006
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.18549407103572188
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 2}, 目标：-0.18947750958204032
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.18969456340005852
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.18984330701222393
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.18984330701222393
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.19066191066205324
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.19298995069968863
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.19300662030835722
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.19300662030835722
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.19300662030835722
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 4, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.1931111310768123
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.1955465643238405
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.19716266773264937
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.1976744929467164
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.19813424305836144
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.1985726563386505
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.2018459373592535
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.20594659261218934
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.20964990237848213
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.20979226202403178
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.20979226202403178
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.2113936722635871
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.21312052822562752
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 4, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.21363160357113045
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.2139682675855205
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.2139682675855205
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.21439974883465687
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.21495161755499537
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.21605263838109548
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.21969359423519869
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.22494551934099719
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.22494551934099719
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.22494551934099719
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.22909271235145143
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.23108688898750407
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.2350159940055885
# 2020-03-13 22:06:47.744718	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.23579144858767187
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.23602062177919467
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.23607679018173022
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.23608104438230043
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.2377486149645747
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.23959760590845483
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 4, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.24040745692584936
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.2408100535253779
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.24120983427213816
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.24323129541423685
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.24532320053149745
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.24540979930257412
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.24573273204248017
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.24795184445493565
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.24883361899946083
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.24924719183711472
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.2495642900812283
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.24983587557026452
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.25024024237821585
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.25073403132906635
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.25698331810852987
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.2577780921220212
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.2577780921220212
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.25860241005622786
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.2604389723071679
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.26058206552823676
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.2637073264145058
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.26416629727419505
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.26823461472085225
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.269221204583171
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.269221204583171
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.269221204583171
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.269221204583171
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.2692846562491357
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.2702284740629677
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.27139227251026454
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.27139227251026454
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.27139227251026454
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.27171184687547045
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.27265646642577396
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.27265646642577396
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.2730803244021562
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.2730803244021562
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.27359794463737896
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.27494300365124286
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.2755039716477982
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.27588095202413576
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.27603257126855435
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 4, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.27642395322480656
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.2765259756486282
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.27832829339027637
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.27832829339027637
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.27832829339027637
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.2797298694663952
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 2}, 目标：-0.2798119875551215
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.2817838262281611
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.2822350742631208
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.28231425277929256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.28332168521292145
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 4, 'ma_len': 20, 'atr_stop': 6}, 目标：-0.28391242530021144
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.28782857769794895
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.2902671444514198
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.2902671444514198
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.2902671444514198
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.2902671444514198
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 8, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.2906999784143183
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.29801129176722385
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.29801129176722385
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.30029935065071944
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.30029935065071944
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.30111423331821463
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 4, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.30274378589535883
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.3033931590219261
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.30446974677688526
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.30556953616894295
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 4}, 目标：-0.30574667379030085
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 4, 'ma_len': 10, 'atr_stop': 4}, 目标：-0.3059353424070786
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 4}, 目标：-0.306789794206227
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.30747100368925234
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 4}, 目标：-0.3076604580517339
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.3083666287871593
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.3083666287871593
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.3083666287871593
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.31373148104491594
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 4, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.31382281152907154
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.3164699632776314
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.31661416779720386
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 16, 'ma_len': 10, 'atr_stop': 6}, 目标：-0.31765484833239604
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 4}, 目标：-0.31780989723722675
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 20, 'ma_len': 10, 'atr_stop': 6}, 目标：-0.31854547725973603
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 24, 'ma_len': 10, 'atr_stop': 6}, 目标：-0.31854547725973603
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.3202369770019575
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.3204649217194407
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.3209037462927005
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.3220370286061961
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.32285457413696533
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.3237581460724257
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.3237581460724257
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.3237581460724257
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 10, 'atr_stop': 6}, 目标：-0.3275391555573544
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.3306709476844256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.3306709476844256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.3306709476844256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.3324777604032522
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.3324777604032522
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.3324777604032522
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 6}, 目标：-0.3325903848091256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.33318429410512346
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 25, 'atr_stop': 4}, 目标：-0.33774290079383584
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.3404358033642043
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.3405642383295688
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.34253904871086827
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 12, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.34300434834701476
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 16, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.34300434834701476
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 20, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.34300434834701476
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 24, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.34300434834701476
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.34433541935339085
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 30, 'atr_stop': 4}, 目标：-0.34512065516979523
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.3469033653074502
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.34710934674058413
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 24, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.34715982801125156
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 5, 'target_atr': 8, 'ma_len': 35, 'atr_stop': 6}, 目标：-0.3483617070263211
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 10, 'target_atr': 12, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.34866183171365484
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.34869270124357454
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.34874877864135545
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.3505331873453451
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 16, 'ma_len': 40, 'atr_stop': 4}, 目标：-0.3523578257157256
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 25, 'target_atr': 4, 'ma_len': 30, 'atr_stop': 6}, 目标：-0.352818481573097
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.3562652734008044
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.3562652734008044
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.3562652734008044
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 6}, 目标：-0.3562652734008044
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 8, 'ma_len': 15, 'atr_stop': 4}, 目标：-0.35663117277126566
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 12, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.3583004462400451
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.35849816057725964
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 30, 'target_atr': 8, 'ma_len': 5, 'atr_stop': 4}, 目标：-0.3585313914577593
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 16, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.35913935610292674
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 20, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.35913935610292674
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 15, 'target_atr': 24, 'ma_len': 20, 'atr_stop': 4}, 目标：-0.35913935610292674
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 12, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.36198948508238726
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 16, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.36198948508238726
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.36198948508238726
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 24, 'ma_len': 5, 'atr_stop': 2}, 目标：-0.36198948508238726
# 2020-03-13 22:06:47.760344	参数：{'atr_window': 20, 'target_atr': 20, 'ma_len': 40, 'atr_stop': 6}, 目标：-0.36224622604308676
# ...
#    'annual_return': -9.516175309847457,
#    'daily_return': -0.04596595795250621,
#    'return_std': 0.5913002210367532,
#    'sharpe_ratio': -1.6409607400721036,
#    'return_drawdown_ratio': -0.948356670058765}),
#  ("{'atr_window': 30, 'target_atr': 4, 'ma_len': 35, 'atr_stop': 4}",
#   -1.649763908543705,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 303,
#    'loss_days': 414,
#    'capital': 500000,
#    'end_balance': 368008.992200004,
#    'max_drawdown': -143915.66154999624,
#    'max_ddpercent': -28.626319145764732,
#    'max_drawdown_duration': 1064,
#    'total_net_pnl': -131991.007799996,
#    'daily_net_pnl': -183.0665850207989,
#    'total_commission': 11391.007800000001,
#    'daily_commission': 15.798901248266299,
#    'total_slippage': 196850.0,
#    'daily_slippage': 273.02357836338416,
#    'total_turnover': 3797002600.0,
#    'daily_turnover': 5266300.4160887655,
#    'total_trade_count': 3937,
#    'daily_trade_count': 5.460471567267684,
#    'total_return': -26.3982015599992,
#    'annual_return': -8.787196080998346,
#    'daily_return': -0.04270037641233054,
#    'return_std': 0.5574799350811311,
#    'sharpe_ratio': -1.649763908543705,
#    'return_drawdown_ratio': -0.9221654179700857}),
#  ("{'atr_window': 30, 'target_atr': 4, 'ma_len': 25, 'atr_stop': 2}",
#   -1.6741254212702963,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 301,
#    'loss_days': 418,
#    'capital': 500000,
#    'end_balance': 367916.0389000006,
#    'max_drawdown': -141477.53849999967,
#    'max_ddpercent': -28.194686006528702,
#    'max_drawdown_duration': 1054,
#    'total_net_pnl': -132083.96109999946,
#    'daily_net_pnl': -183.19550776698955,
#    'total_commission': 10483.9611,
#    'daily_commission': 14.540861442441054,
#    'total_slippage': 181150.0,
#    'daily_slippage': 251.24826629681,
#    'total_turnover': 3494653700.0,
#    'daily_turnover': 4846953.814147018,
#    'total_trade_count': 3623,
#    'daily_trade_count': 5.0249653259362,
#    'total_return': -26.416792219999873,
#    'annual_return': -8.793384372815492,
#    'daily_return': -0.04304062056564879,
#    'return_std': 0.55251614045145,
#    'sharpe_ratio': -1.6741254212702963,
#    'return_drawdown_ratio': -0.9369422384729823}),
#  ("{'atr_window': 25, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 6}",
#   -1.7035664727974544,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 314,
#    'loss_days': 403,
#    'capital': 500000,
#    'end_balance': 338354.15885000303,
#    'max_drawdown': -169060.93514999683,
#    'max_ddpercent': -33.90393218933346,
#    'max_drawdown_duration': 1067,
#    'total_net_pnl': -161645.84114999685,
#    'daily_net_pnl': -224.19672836337983,
#    'total_commission': 11495.84115,
#    'daily_commission': 15.94430117891817,
#    'total_slippage': 198750.0,
#    'daily_slippage': 275.65880721220526,
#    'total_turnover': 3831947050.0,
#    'daily_turnover': 5314767.05963939,
#    'total_trade_count': 3975,
#    'daily_trade_count': 5.513176144244105,
#    'total_return': -32.3291682299994,
#    'annual_return': -10.76144296144224,
#    'daily_return': -0.0534111297895319,
#    'return_std': 0.6372751353061865,
#    'sharpe_ratio': -1.7035664727974544,
#    'return_drawdown_ratio': -0.9535521735195807}),
#  ("{'atr_window': 10, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 4}",
#   -1.7087142168372642,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 308,
#    'loss_days': 410,
#    'capital': 500000,
#    'end_balance': 352574.54875000275,
#    'max_drawdown': -154110.39524999756,
#    'max_ddpercent': -30.910673984255162,
#    'max_drawdown_duration': 1070,
#    'total_net_pnl': -147425.4512499973,
#    'daily_net_pnl': -204.47358009708364,
#    'total_commission': 12775.451250000002,
#    'daily_commission': 17.719072468793346,
#    'total_slippage': 220450.0,
#    'daily_slippage': 305.755894590846,
#    'total_turnover': 4258483750.0,
#    'daily_turnover': 5906357.489597781,
#    'total_trade_count': 4409,
#    'daily_trade_count': 6.115117891816921,
#    'total_return': -29.485090249999445,
#    'annual_return': -9.81473184466001,
#    'daily_return': -0.04762302138354632,
#    'return_std': 0.5828777889194765,
#    'sharpe_ratio': -1.7087142168372642,
#    'return_drawdown_ratio': -0.9538805354104585}),
#  ("{'atr_window': 25, 'target_atr': 4, 'ma_len': 25, 'atr_stop': 2}",
#   -1.7343370290707323,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 302,
#    'loss_days': 417,
#    'capital': 500000,
#    'end_balance': 361983.9644500005,
#    'max_drawdown': -145765.44419999974,
#    'max_ddpercent': -29.049211439462404,
#    'max_drawdown_duration': 1054,
#    'total_net_pnl': -138016.03554999965,
#    'daily_net_pnl': -191.42307288488163,
#    'total_commission': 10266.03555,
#    'daily_commission': 14.238606865464632,
#    'total_slippage': 177350.0,
#    'daily_slippage': 245.97780859916782,
#    'total_turnover': 3422011850.0,
#    'daily_turnover': 4746202.288488211,
#    'total_trade_count': 3547,
#    'daily_trade_count': 4.9195561719833565,
#    'total_return': -27.603207109999907,
#    'annual_return': -9.18830749847431,
#    'daily_return': -0.04529510645044264,
#    'return_std': 0.5534723905713477,
#    'sharpe_ratio': -1.7343370290707323,
#    'return_drawdown_ratio': -0.9502222519025716}),
#  ("{'atr_window': 30, 'target_atr': 4, 'ma_len': 30, 'atr_stop': 2}",
#   -1.7456838474773482,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 283,
#    'loss_days': 436,
#    'capital': 500000,
#    'end_balance': 369121.15555000206,
#    'max_drawdown': -139311.19144999795,
#    'max_ddpercent': -27.749301571255614,
#    'max_drawdown_duration': 1072,
#    'total_net_pnl': -130878.84444999787,
#    'daily_net_pnl': -181.52405610263227,
#    'total_commission': 11828.84445,
#    'daily_commission': 16.406164285714286,
#    'total_slippage': 204350.0,
#    'daily_slippage': 283.4257975034674,
#    'total_turnover': 3942948150.0,
#    'daily_turnover': 5468721.428571428,
#    'total_trade_count': 4087,
#    'daily_trade_count': 5.668515950069348,
#    'total_return': -26.175768889999585,
#    'annual_return': -8.713154692926354,
#    'daily_return': -0.042655313166688205,
#    'return_std': 0.5264482232350309,
#    'sharpe_ratio': -1.7456838474773482,
#    'return_drawdown_ratio': -0.9432946924009796}),
#  ("{'atr_window': 15, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 4}",
#   -1.7792908782077645,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 297,
#    'loss_days': 420,
#    'capital': 500000,
#    'end_balance': 345236.5015500012,
#    'max_drawdown': -161978.7263999993,
#    'max_ddpercent': -32.457219419111446,
#    'max_drawdown_duration': 1062,
#    'total_net_pnl': -154763.49844999885,
#    'daily_net_pnl': -214.65117676837565,
#    'total_commission': 13113.498450000001,
#    'daily_commission': 18.18793127600555,
#    'total_slippage': 226450.0,
#    'daily_slippage': 314.07766990291265,
#    'total_turnover': 4371166150.0,
#    'daily_turnover': 6062643.758668516,
#    'total_trade_count': 4529,
#    'daily_trade_count': 6.281553398058253,
#    'total_return': -30.95269968999976,
#    'annual_return': -10.303256484882029,
#    'daily_return': -0.05044578895049062,
#    'return_std': 0.5843348630891673,
#    'sharpe_ratio': -1.7792908782077645,
#    'return_drawdown_ratio': -0.953646068392852}),
#  ("{'atr_window': 20, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 2}",
#   -1.8050064438295332,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 291,
#    'loss_days': 427,
#    'capital': 500000,
#    'end_balance': 365559.4721500005,
#    'max_drawdown': -149695.2908999991,
#    'max_ddpercent': -29.89774655312137,
#    'max_drawdown_duration': 967,
#    'total_net_pnl': -134440.5278499995,
#    'daily_net_pnl': -186.46397760055407,
#    'total_commission': 15390.527850000002,
#    'daily_commission': 21.346085783633846,
#    'total_slippage': 265850.0,
#    'daily_slippage': 368.7239944521498,
#    'total_turnover': 5130175950.0,
#    'daily_turnover': 7115361.927877948,
#    'total_trade_count': 5317,
#    'daily_trade_count': 7.374479889042996,
#    'total_return': -26.888105569999897,
#    'annual_return': -8.950270924826595,
#    'daily_return': -0.043250497115396094,
#    'return_std': 0.5142545131031723,
#    'sharpe_ratio': -1.8050064438295332,
#    'return_drawdown_ratio': -0.8993355242418007}),
#  ("{'atr_window': 10, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 2}",
#   -1.8131191461931195,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 289,
#    'loss_days': 429,
#    'capital': 500000,
#    'end_balance': 363877.1754000016,
#    'max_drawdown': -151249.31409999816,
#    'max_ddpercent': -30.26930356777442,
#    'max_drawdown_duration': 967,
#    'total_net_pnl': -136122.82459999825,
#    'daily_net_pnl': -188.79726019417234,
#    'total_commission': 14722.8246,
#    'daily_commission': 20.42000638002774,
#    'total_slippage': 254150.0,
#    'daily_slippage': 352.49653259362,
#    'total_turnover': 4907608200.0,
#    'daily_turnover': 6806668.79334258,
#    'total_trade_count': 5083,
#    'daily_trade_count': 7.049930651872399,
#    'total_return': -27.224564919999683,
#    'annual_return': -9.062268489320283,
#    'daily_return': -0.04377575549305684,
#    'return_std': 0.5164415034071094,
#    'sharpe_ratio': -1.8131191461931195,
#    'return_drawdown_ratio': -0.8994116715980128}),
#  ("{'atr_window': 20, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 4}",
#   -1.823084024621404,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 297,
#    'loss_days': 420,
#    'capital': 500000,
#    'end_balance': 337653.73810000357,
#    'max_drawdown': -171143.2844999964,
#    'max_ddpercent': -34.2266761064183,
#    'max_drawdown_duration': 1070,
#    'total_net_pnl': -162346.26189999652,
#    'daily_net_pnl': -225.1681857142809,
#    'total_commission': 13446.2619,
#    'daily_commission': 18.649461719833564,
#    'total_slippage': 232250.0,
#    'daily_slippage': 322.12205270457696,
#    'total_turnover': 4482087300.0,
#    'daily_turnover': 6216487.239944521,
#    'total_trade_count': 4645,
#    'daily_trade_count': 6.44244105409154,
#    'total_return': -32.46925237999929,
#    'annual_return': -10.808072914285479,
#    'daily_return': -0.05402779579143791,
#    'return_std': 0.6007369316423771,
#    'sharpe_ratio': -1.823084024621404,
#    'return_drawdown_ratio': -0.9486533918469093}),
#  ("{'atr_window': 25, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 2}",
#   -1.8460565570915048,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 284,
#    'loss_days': 434,
#    'capital': 500000,
#    'end_balance': 360832.9736500025,
#    'max_drawdown': -153287.59359999717,
#    'max_ddpercent': -30.61215871912473,
#    'max_drawdown_duration': 967,
#    'total_net_pnl': -139167.02634999764,
#    'daily_net_pnl': -193.01945402218814,
#    'total_commission': 15617.02635,
#    'daily_commission': 21.66023072122053,
#    'total_slippage': 269850.0,
#    'daily_slippage': 374.2718446601942,
#    'total_turnover': 5205675450.0,
#    'daily_turnover': 7220076.907073509,
#    'total_trade_count': 5397,
#    'daily_trade_count': 7.485436893203883,
#    'total_return': -27.8334052699995,
#    'annual_return': -9.26493379306502,
#    'daily_return': -0.04505546328166997,
#    'return_std': 0.517966322243092,
#    'sharpe_ratio': -1.8460565570915048,
#    'return_drawdown_ratio': -0.9092271317870431}),
#  ("{'atr_window': 15, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 2}",
#   -1.8711684165074463,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 293,
#    'loss_days': 425,
#    'capital': 500000,
#    'end_balance': 359754.6984999993,
#    'max_drawdown': -154528.2423500003,
#    'max_ddpercent': -30.903491437201225,
#    'max_drawdown_duration': 967,
#    'total_net_pnl': -140245.30150000053,
#    'daily_net_pnl': -194.51498127600627,
#    'total_commission': 15045.3015,
#    'daily_commission': 20.867269764216367,
#    'total_slippage': 259850.0,
#    'daily_slippage': 360.4022191400832,
#    'total_turnover': 5015100500.0,
#    'daily_turnover': 6955756.588072122,
#    'total_trade_count': 5197,
#    'daily_trade_count': 7.208044382801664,
#    'total_return': -28.04906030000014,
#    'annual_return': -9.336719101248312,
#    'daily_return': -0.04524816025486527,
#    'return_std': 0.5126103913147223,
#    'sharpe_ratio': -1.8711684165074463,
#    'return_drawdown_ratio': -0.9076340243625366}),
#  ("{'atr_window': 25, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 4}",
#   -1.9318894160823334,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 292,
#    'loss_days': 425,
#    'capital': 500000,
#    'end_balance': 325472.23695000436,
#    'max_drawdown': -183374.80979999556,
#    'max_ddpercent': -36.66917290599951,
#    'max_drawdown_duration': 1070,
#    'total_net_pnl': -174527.76304999564,
#    'daily_net_pnl': -242.06347163660976,
#    'total_commission': 13677.76305,
#    'daily_commission': 18.970545145631068,
#    'total_slippage': 236350.0,
#    'daily_slippage': 327.8085991678225,
#    'total_turnover': 4559254350.0,
#    'daily_turnover': 6323515.04854369,
#    'total_trade_count': 4727,
#    'daily_trade_count': 6.55617198335645,
#    'total_return': -34.90555260999913,
#    'annual_return': -11.619046638557268,
#    'daily_return': -0.05913792925029438,
#    'return_std': 0.6078814555498567,
#    'sharpe_ratio': -1.9318894160823334,
#    'return_drawdown_ratio': -0.9519045520737166}),
#  ("{'atr_window': 30, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 2}",
#   -1.9742433410852345,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 287,
#    'loss_days': 431,
#    'capital': 500000,
#    'end_balance': 348289.72465000127,
#    'max_drawdown': -166179.20419999794,
#    'max_ddpercent': -33.19329486296421,
#    'max_drawdown_duration': 967,
#    'total_net_pnl': -151710.27534999888,
#    'daily_net_pnl': -210.41647066574046,
#    'total_commission': 15860.27535,
#    'daily_commission': 21.997607975034676,
#    'total_slippage': 274150.0,
#    'daily_slippage': 380.2357836338419,
#    'total_turnover': 5286758450.0,
#    'daily_turnover': 7332535.991678225,
#    'total_trade_count': 5483,
#    'daily_trade_count': 7.6047156726768375,
#    'total_return': -30.342055069999752,
#    'annual_return': -10.099990591955535,
#    'daily_return': -0.049962605985397514,
#    'return_std': 0.5228414511647921,
#    'sharpe_ratio': -1.9742433410852345,
#    'return_drawdown_ratio': -0.9141019352030112}),
#  ("{'atr_window': 30, 'target_atr': 4, 'ma_len': 40, 'atr_stop': 4}",
#   -2.011448542482085,
#   {'start_date': datetime.date(2016, 1, 18),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 721,
#    'profit_days': 291,
#    'loss_days': 426,
#    'capital': 500000,
#    'end_balance': 317990.3257000033,
#    'max_drawdown': -190906.72089999658,
#    'max_ddpercent': -38.171500811107855,
#    'max_drawdown_duration': 1070,
#    'total_net_pnl': -182009.67429999658,
#    'daily_net_pnl': -252.44060235783158,
#    'total_commission': 13909.674300000002,
#    'daily_commission': 19.292197364771155,
#    'total_slippage': 240450.0,
#    'daily_slippage': 333.49514563106794,
#    'total_turnover': 4636558100.0,
#    'daily_turnover': 6430732.454923717,
#    'total_trade_count': 4809,
#    'daily_trade_count': 6.669902912621359,
#    'total_return': -36.40193485999934,
#    'annual_return': -12.117148913175926,
#    'daily_return': -0.06237738753365381,
#    'return_std': 0.6087877448891471,
#    'sharpe_ratio': -2.011448542482085,
#    'return_drawdown_ratio': -0.9536416982956675})]

# %%
# 样本外。2019
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 12, 15),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:07:19.381702	开始加载历史数据
# 2019-12-20 12:07:19.641336	加载进度： [9%]
# 2019-12-20 12:07:19.858341	加载进度：# [17%]
# 2019-12-20 12:07:20.105831	加载进度：## [26%]
# 2019-12-20 12:07:20.381099	加载进度：### [34%]
# 2019-12-20 12:07:20.640501	加载进度：#### [43%]
# 2019-12-20 12:07:20.888839	加载进度：##### [52%]
# 2019-12-20 12:07:21.177471	加载进度：###### [60%]
# 2019-12-20 12:07:21.467733	加载进度：###### [69%]
# 2019-12-20 12:07:21.735977	加载进度：####### [78%]
# 2019-12-20 12:07:22.266116	加载进度：######## [86%]
# 2019-12-20 12:07:22.548527	加载进度：######### [95%]
# 2019-12-20 12:07:22.708051	加载进度：########## [100%]
# 2019-12-20 12:07:22.708051	历史数据加载完成，数据量：55680
# 2019-12-20 12:07:22.739304	策略初始化完成
# 2019-12-20 12:07:22.739304	开始回放历史数据
# 2019-12-20 12:07:24.842473	历史数据回放结束
# 2019-12-20 12:07:24.842473	开始计算逐日盯市盈亏
# 2019-12-20 12:07:24.842473	逐日盯市盈亏计算完成
# 2019-12-20 12:07:24.842473	开始计算策略统计指标
# 2019-12-20 12:07:24.842473	------------------------------
# 2019-12-20 12:07:24.842473	首个交易日：	2019-01-09
# 2019-12-20 12:07:24.842473	最后交易日：	2019-12-13
# 2019-12-20 12:07:24.842473	总交易日：	227
# 2019-12-20 12:07:24.842473	盈利交易日：	57
# 2019-12-20 12:07:24.842473	亏损交易日：	48
# 2019-12-20 12:07:24.842473	起始资金：	500,000.00
# 2019-12-20 12:07:24.842473	结束资金：	675,029.17
# 2019-12-20 12:07:24.842473	总收益率：	35.01%
# 2019-12-20 12:07:24.842473	年化收益：	37.01%
# 2019-12-20 12:07:24.842473	最大回撤: 	-23,488.78
# 2019-12-20 12:07:24.842473	百分比最大回撤: -4.06%
# 2019-12-20 12:07:24.842473	最长回撤天数: 	21
# 2019-12-20 12:07:24.842473	总盈亏：	175,029.17
# 2019-12-20 12:07:24.842473	总手续费：	10,370.83
# 2019-12-20 12:07:24.842473	总滑点：	13,920.00
# 2019-12-20 12:07:24.842473	总成交金额：	345,694,200.00
# 2019-12-20 12:07:24.842473	总成交笔数：	348
# 2019-12-20 12:07:24.842473	日均盈亏：	771.05
# 2019-12-20 12:07:24.842473	日均手续费：	45.69
# 2019-12-20 12:07:24.842473	日均滑点：	61.32
# 2019-12-20 12:07:24.842473	日均成交金额：	1,522,881.94
# 2019-12-20 12:07:24.842473	日均成交笔数：	1.5330396475770924
# 2019-12-20 12:07:24.842473	日均收益率：	0.13%
# 2019-12-20 12:07:24.842473	收益标准差：	0.71%
# 2019-12-20 12:07:24.842473	Sharpe Ratio：	2.75
# 2019-12-20 12:07:24.842473	收益回撤比：	8.62

# %%
# 样本内每年 2018-19
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2018, 1, 1),
    end=datetime(2019, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:10:23.916291	开始加载历史数据
# 2019-12-20 12:10:23.931920	加载进度： [8%]
# 2019-12-20 12:10:23.931920	加载进度：# [16%]
# 2019-12-20 12:10:23.931920	加载进度：## [25%]
# 2019-12-20 12:10:23.931920	加载进度：### [33%]
# 2019-12-20 12:10:23.931920	加载进度：#### [41%]
# 2019-12-20 12:10:23.931920	加载进度：#### [49%]
# 2019-12-20 12:10:23.931920	加载进度：##### [58%]
# 2019-12-20 12:10:23.931920	加载进度：###### [66%]
# 2019-12-20 12:10:23.931920	加载进度：####### [74%]
# 2019-12-20 12:10:23.931920	加载进度：######## [82%]
# 2019-12-20 12:10:23.931920	加载进度：######### [90%]
# 2019-12-20 12:10:23.931920	加载进度：######### [99%]
# 2019-12-20 12:10:23.931920	加载进度：########## [100%]
# 2019-12-20 12:10:23.931920	历史数据加载完成，数据量：58320
# 2019-12-20 12:10:23.954574	策略初始化完成
# 2019-12-20 12:10:23.954574	开始回放历史数据
# 2019-12-20 12:10:26.725533	历史数据回放结束
# 2019-12-20 12:10:26.725533	开始计算逐日盯市盈亏
# 2019-12-20 12:10:26.729537	逐日盯市盈亏计算完成
# 2019-12-20 12:10:26.730538	开始计算策略统计指标
# 2019-12-20 12:10:26.735542	------------------------------
# 2019-12-20 12:10:26.736543	首个交易日：	2018-01-09
# 2019-12-20 12:10:26.736543	最后交易日：	2018-12-28
# 2019-12-20 12:10:26.736543	总交易日：	238
# 2019-12-20 12:10:26.736543	盈利交易日：	49
# 2019-12-20 12:10:26.736543	亏损交易日：	56
# 2019-12-20 12:10:26.736543	起始资金：	500,000.00
# 2019-12-20 12:10:26.736543	结束资金：	607,077.03
# 2019-12-20 12:10:26.736543	总收益率：	21.42%
# 2019-12-20 12:10:26.736543	年化收益：	21.60%
# 2019-12-20 12:10:26.736543	最大回撤: 	-27,804.28
# 2019-12-20 12:10:26.736543	百分比最大回撤: -4.48%
# 2019-12-20 12:10:26.736543	最长回撤天数: 	86
# 2019-12-20 12:10:26.736543	总盈亏：	107,077.03
# 2019-12-20 12:10:26.736543	总手续费：	11,602.97
# 2019-12-20 12:10:26.736543	总滑点：	14,720.00
# 2019-12-20 12:10:26.736543	总成交金额：	386,765,720.00
# 2019-12-20 12:10:26.736543	总成交笔数：	368
# 2019-12-20 12:10:26.736543	日均盈亏：	449.90
# 2019-12-20 12:10:26.736543	日均手续费：	48.75
# 2019-12-20 12:10:26.736543	日均滑点：	61.85
# 2019-12-20 12:10:26.736543	日均成交金额：	1,625,066.05
# 2019-12-20 12:10:26.736543	日均成交笔数：	1.546218487394958
# 2019-12-20 12:10:26.736543	日均收益率：	0.08%
# 2019-12-20 12:10:26.736543	收益标准差：	0.75%
# 2019-12-20 12:10:26.736543	Sharpe Ratio：	1.68
# 2019-12-20 12:10:26.736543	收益回撤比：	4.78

# %%
# 样本内每年 2017-18
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2017, 1, 1),
    end=datetime(2018, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:10:09.769725	开始加载历史数据
# 2019-12-20 12:10:09.769725	加载进度： [8%]
# 2019-12-20 12:10:09.769725	加载进度：# [16%]
# 2019-12-20 12:10:09.769725	加载进度：## [25%]
# 2019-12-20 12:10:09.769725	加载进度：### [33%]
# 2019-12-20 12:10:09.769725	加载进度：#### [41%]
# 2019-12-20 12:10:09.769725	加载进度：#### [49%]
# 2019-12-20 12:10:09.769725	加载进度：##### [58%]
# 2019-12-20 12:10:09.769725	加载进度：###### [66%]
# 2019-12-20 12:10:09.769725	加载进度：####### [74%]
# 2019-12-20 12:10:09.769725	加载进度：######## [82%]
# 2019-12-20 12:10:09.769725	加载进度：######### [90%]
# 2019-12-20 12:10:09.769725	加载进度：######### [99%]
# 2019-12-20 12:10:09.769725	加载进度：########## [100%]
# 2019-12-20 12:10:09.769725	历史数据加载完成，数据量：58560
# 2019-12-20 12:10:09.804533	策略初始化完成
# 2019-12-20 12:10:09.804533	开始回放历史数据
# 2019-12-20 12:10:12.009985	历史数据回放结束
# 2019-12-20 12:10:12.010985	开始计算逐日盯市盈亏
# 2019-12-20 12:10:12.014989	逐日盯市盈亏计算完成
# 2019-12-20 12:10:12.014989	开始计算策略统计指标
# 2019-12-20 12:10:12.020522	------------------------------
# 2019-12-20 12:10:12.020522	首个交易日：	2017-01-10
# 2019-12-20 12:10:12.020522	最后交易日：	2017-12-29
# 2019-12-20 12:10:12.020522	总交易日：	239
# 2019-12-20 12:10:12.020522	盈利交易日：	50
# 2019-12-20 12:10:12.020522	亏损交易日：	62
# 2019-12-20 12:10:12.020522	起始资金：	500,000.00
# 2019-12-20 12:10:12.021522	结束资金：	605,354.79
# 2019-12-20 12:10:12.021522	总收益率：	21.07%
# 2019-12-20 12:10:12.021522	年化收益：	21.16%
# 2019-12-20 12:10:12.021522	最大回撤: 	-41,768.58
# 2019-12-20 12:10:12.021522	百分比最大回撤: -7.17%
# 2019-12-20 12:10:12.021522	最长回撤天数: 	59
# 2019-12-20 12:10:12.021522	总盈亏：	105,354.79
# 2019-12-20 12:10:12.021522	总手续费：	14,605.21
# 2019-12-20 12:10:12.021522	总滑点：	15,600.00
# 2019-12-20 12:10:12.021522	总成交金额：	486,840,200.00
# 2019-12-20 12:10:12.021522	总成交笔数：	390
# 2019-12-20 12:10:12.021522	日均盈亏：	440.82
# 2019-12-20 12:10:12.021522	日均手续费：	61.11
# 2019-12-20 12:10:12.021522	日均滑点：	65.27
# 2019-12-20 12:10:12.021522	日均成交金额：	2,036,988.28
# 2019-12-20 12:10:12.021522	日均成交笔数：	1.6317991631799162
# 2019-12-20 12:10:12.021522	日均收益率：	0.08%
# 2019-12-20 12:10:12.021522	收益标准差：	0.81%
# 2019-12-20 12:10:12.021522	Sharpe Ratio：	1.53
# 2019-12-20 12:10:12.021522	收益回撤比：	2.94

# %%
# 样本内每年 2016-17
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2016, 1, 1),
    end=datetime(2017, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:09:58.530770	开始加载历史数据
# 2019-12-20 12:09:58.530770	加载进度： [8%]
# 2019-12-20 12:09:58.530770	加载进度：# [16%]
# 2019-12-20 12:09:58.531771	加载进度：## [25%]
# 2019-12-20 12:09:58.531771	加载进度：### [33%]
# 2019-12-20 12:09:58.531771	加载进度：#### [41%]
# 2019-12-20 12:09:58.531771	加载进度：#### [49%]
# 2019-12-20 12:09:58.531771	加载进度：##### [57%]
# 2019-12-20 12:09:58.531771	加载进度：###### [66%]
# 2019-12-20 12:09:58.531771	加载进度：####### [74%]
# 2019-12-20 12:09:58.531771	加载进度：######## [82%]
# 2019-12-20 12:09:58.532773	加载进度：######### [90%]
# 2019-12-20 12:09:58.532773	加载进度：######### [98%]
# 2019-12-20 12:09:58.532773	加载进度：########## [100%]
# 2019-12-20 12:09:58.532773	历史数据加载完成，数据量：58560
# 2019-12-20 12:09:58.564276	策略初始化完成
# 2019-12-20 12:09:58.564276	开始回放历史数据
# 2019-12-20 12:10:00.743643	历史数据回放结束
# 2019-12-20 12:10:00.744644	开始计算逐日盯市盈亏
# 2019-12-20 12:10:00.748691	逐日盯市盈亏计算完成
# 2019-12-20 12:10:00.748691	开始计算策略统计指标
# 2019-12-20 12:10:00.755894	------------------------------
# 2019-12-20 12:10:00.755894	首个交易日：	2016-01-11
# 2019-12-20 12:10:00.755894	最后交易日：	2016-12-30
# 2019-12-20 12:10:00.755894	总交易日：	239
# 2019-12-20 12:10:00.755894	盈利交易日：	56
# 2019-12-20 12:10:00.755894	亏损交易日：	53
# 2019-12-20 12:10:00.755894	起始资金：	500,000.00
# 2019-12-20 12:10:00.755894	结束资金：	856,061.56
# 2019-12-20 12:10:00.755894	总收益率：	71.21%
# 2019-12-20 12:10:00.755894	年化收益：	71.51%
# 2019-12-20 12:10:00.755894	最大回撤: 	-31,863.75
# 2019-12-20 12:10:00.755894	百分比最大回撤: -3.90%
# 2019-12-20 12:10:00.755894	最长回撤天数: 	22
# 2019-12-20 12:10:00.755894	总盈亏：	356,061.56
# 2019-12-20 12:10:00.755894	总手续费：	14,578.44
# 2019-12-20 12:10:00.755894	总滑点：	16,080.00
# 2019-12-20 12:10:00.755894	总成交金额：	485,947,840.00
# 2019-12-20 12:10:00.755894	总成交笔数：	402
# 2019-12-20 12:10:00.755894	日均盈亏：	1,489.80
# 2019-12-20 12:10:00.755894	日均手续费：	61.00
# 2019-12-20 12:10:00.755894	日均滑点：	67.28
# 2019-12-20 12:10:00.755894	日均成交金额：	2,033,254.56
# 2019-12-20 12:10:00.755894	日均成交笔数：	1.6820083682008369
# 2019-12-20 12:10:00.755894	日均收益率：	0.23%
# 2019-12-20 12:10:00.755894	收益标准差：	1.19%
# 2019-12-20 12:10:00.755894	Sharpe Ratio：	3.05
# 2019-12-20 12:10:00.755894	收益回撤比：	18.26

# %%
# 样本内每年 2015-16
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IC9999.CFFEX",
    interval="1m",
    start=datetime(2015, 1, 1),
    end=datetime(2016, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=200,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 35, 'atr_ma_len': 20, 'trailing_stop':0.6})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-20 12:09:46.444700	开始加载历史数据
# 2019-12-20 12:09:46.444700	加载进度： [8%]
# 2019-12-20 12:09:46.444700	加载进度：# [16%]
# 2019-12-20 12:09:46.444700	加载进度：## [25%]
# 2019-12-20 12:09:46.444700	加载进度：### [33%]
# 2019-12-20 12:09:46.444700	加载进度：#### [41%]
# 2019-12-20 12:09:46.444700	加载进度：#### [49%]
# 2019-12-20 12:09:46.444700	加载进度：##### [58%]
# 2019-12-20 12:09:46.444700	加载进度：###### [66%]
# 2019-12-20 12:09:46.444700	加载进度：####### [74%]
# 2019-12-20 12:09:46.444700	加载进度：######## [82%]
# 2019-12-20 12:09:46.444700	加载进度：######### [90%]
# 2019-12-20 12:09:46.445701	加载进度：######### [99%]
# 2019-12-20 12:09:46.445701	加载进度：########## [100%]
# 2019-12-20 12:09:46.445701	历史数据加载完成，数据量：47520
# 2019-12-20 12:09:46.481240	策略初始化完成
# 2019-12-20 12:09:46.482241	开始回放历史数据
# 2019-12-20 12:09:48.210081	历史数据回放结束
# 2019-12-20 12:09:48.210081	开始计算逐日盯市盈亏
# 2019-12-20 12:09:48.225709	逐日盯市盈亏计算完成
# 2019-12-20 12:09:48.225709	开始计算策略统计指标
# 2019-12-20 12:09:48.225709	------------------------------
# 2019-12-20 12:09:48.225709	首个交易日：	2015-04-24
# 2019-12-20 12:09:48.225709	最后交易日：	2015-12-31
# 2019-12-20 12:09:48.225709	总交易日：	171
# 2019-12-20 12:09:48.225709	盈利交易日：	40
# 2019-12-20 12:09:48.225709	亏损交易日：	40
# 2019-12-20 12:09:48.225709	起始资金：	500,000.00
# 2019-12-20 12:09:48.225709	结束资金：	978,229.84
# 2019-12-20 12:09:48.225709	总收益率：	95.65%
# 2019-12-20 12:09:48.225709	年化收益：	134.24%
# 2019-12-20 12:09:48.225709	最大回撤: 	-55,523.83
# 2019-12-20 12:09:48.225709	百分比最大回撤: -9.01%
# 2019-12-20 12:09:48.225709	最长回撤天数: 	21
# 2019-12-20 12:09:48.225709	总盈亏：	478,229.84
# 2019-12-20 12:09:48.225709	总手续费：	15,610.16
# 2019-12-20 12:09:48.225709	总滑点：	13,280.00
# 2019-12-20 12:09:48.225709	总成交金额：	520,338,720.00
# 2019-12-20 12:09:48.225709	总成交笔数：	332
# 2019-12-20 12:09:48.225709	日均盈亏：	2,796.67
# 2019-12-20 12:09:48.225709	日均手续费：	91.29
# 2019-12-20 12:09:48.225709	日均滑点：	77.66
# 2019-12-20 12:09:48.225709	日均成交金额：	3,042,916.49
# 2019-12-20 12:09:48.225709	日均成交笔数：	1.9415204678362572
# 2019-12-20 12:09:48.225709	日均收益率：	0.39%
# 2019-12-20 12:09:48.225709	收益标准差：	1.98%
# 2019-12-20 12:09:48.225709	Sharpe Ratio：	3.07
# 2019-12-20 12:09:48.225709	收益回撤比：	10.62

# %%
# 样本外。2019
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IH9999.CFFEX",
    interval="1m",
    start=datetime(2014, 1, 1),
    end=datetime(2019, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 44, 'atr_ma_len': 22, 'trailing_short':0.55,'trailing_long':0.55})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-16 14:56:11.167765	开始加载历史数据
# 2019-12-16 14:56:11.167765	加载进度： [2%]
# 2019-12-16 14:56:11.167765	加载进度： [3%]
# 2019-12-16 14:56:11.167765	加载进度： [5%]
# 2019-12-16 14:56:11.167765	加载进度： [7%]
# 2019-12-16 14:56:11.167765	加载进度： [8%]
# 2019-12-16 14:56:11.167765	加载进度： [10%]
# 2019-12-16 14:56:11.167765	加载进度：# [12%]
# 2019-12-16 14:56:11.167765	加载进度：# [13%]
# 2019-12-16 14:56:11.167765	加载进度：# [15%]
# 2019-12-16 14:56:11.167765	加载进度：# [16%]
# 2019-12-16 14:56:11.167765	加载进度：# [18%]
# 2019-12-16 14:56:11.167765	加载进度：# [20%]
# 2019-12-16 14:56:11.167765	加载进度：## [21%]
# 2019-12-16 14:56:11.167765	加载进度：## [23%]
# 2019-12-16 14:56:11.167765	加载进度：## [25%]
# 2019-12-16 14:56:11.167765	加载进度：## [26%]
# 2019-12-16 14:56:11.167765	加载进度：## [28%]
# 2019-12-16 14:56:11.167765	加载进度：## [30%]
# 2019-12-16 14:56:11.167765	加载进度：### [31%]
# 2019-12-16 14:56:11.167765	加载进度：### [33%]
# 2019-12-16 14:56:11.167765	加载进度：### [35%]
# 2019-12-16 14:56:11.167765	加载进度：### [36%]
# 2019-12-16 14:56:11.167765	加载进度：### [38%]
# 2019-12-16 14:56:11.167765	加载进度：### [39%]
# 2019-12-16 14:56:11.167765	加载进度：#### [41%]
# 2019-12-16 14:56:11.167765	加载进度：#### [43%]
# 2019-12-16 14:56:11.167765	加载进度：#### [44%]
# 2019-12-16 14:56:11.167765	加载进度：#### [46%]
# 2019-12-16 14:56:11.167765	加载进度：#### [48%]
# 2019-12-16 14:56:11.167765	加载进度：#### [49%]
# 2019-12-16 14:56:11.167765	加载进度：##### [51%]
# 2019-12-16 14:56:11.167765	加载进度：##### [53%]
# 2019-12-16 14:56:11.167765	加载进度：##### [54%]
# 2019-12-16 14:56:11.167765	加载进度：##### [56%]
# 2019-12-16 14:56:11.167765	加载进度：##### [58%]
# 2019-12-16 14:56:11.167765	加载进度：##### [59%]
# 2019-12-16 14:56:11.167765	加载进度：###### [61%]
# 2019-12-16 14:56:11.178201	加载进度：###### [62%]
# 2019-12-16 14:56:11.178201	加载进度：###### [64%]
# 2019-12-16 14:56:11.178201	加载进度：###### [66%]
# 2019-12-16 14:56:11.178201	加载进度：###### [67%]
# 2019-12-16 14:56:11.178201	加载进度：###### [69%]
# 2019-12-16 14:56:11.179209	加载进度：####### [71%]
# 2019-12-16 14:56:11.179228	加载进度：####### [72%]
# 2019-12-16 14:56:11.179228	加载进度：####### [74%]
# 2019-12-16 14:56:11.179228	加载进度：####### [76%]
# 2019-12-16 14:56:11.180244	加载进度：####### [77%]
# 2019-12-16 14:56:11.180244	加载进度：####### [79%]
# 2019-12-16 14:56:11.180244	加载进度：######## [81%]
# 2019-12-16 14:56:11.181269	加载进度：######## [82%]
# 2019-12-16 14:56:11.181269	加载进度：######## [84%]
# 2019-12-16 14:56:11.181269	加载进度：######## [85%]
# 2019-12-16 14:56:11.181269	加载进度：######## [87%]
# 2019-12-16 14:56:11.181269	加载进度：######## [89%]
# 2019-12-16 14:56:11.182284	加载进度：######### [90%]
# 2019-12-16 14:56:11.182284	加载进度：######### [92%]
# 2019-12-16 14:56:11.182284	加载进度：######### [94%]
# 2019-12-16 14:56:11.182284	加载进度：######### [95%]
# 2019-12-16 14:56:11.182284	加载进度：######### [97%]
# 2019-12-16 14:56:11.182284	加载进度：######### [99%]
# 2019-12-16 14:56:11.182284	加载进度：########## [100%]
# 2019-12-16 14:56:11.182284	历史数据加载完成，数据量：222960
# 2019-12-16 14:56:11.213540	策略初始化完成
# 2019-12-16 14:56:11.213540	开始回放历史数据
# 2019-12-16 14:56:20.195911	历史数据回放结束
# 2019-12-16 14:56:20.195911	开始计算逐日盯市盈亏
# 2019-12-16 14:56:20.195911	逐日盯市盈亏计算完成
# 2019-12-16 14:56:20.211539	开始计算策略统计指标
# 2019-12-16 14:56:20.211539	------------------------------
# 2019-12-16 14:56:20.211539	首个交易日：	2015-04-24
# 2019-12-16 14:56:20.211539	最后交易日：	2018-12-28
# 2019-12-16 14:56:20.211539	总交易日：	902
# 2019-12-16 14:56:20.211539	盈利交易日：	192
# 2019-12-16 14:56:20.211539	亏损交易日：	222
# 2019-12-16 14:56:20.211539	起始资金：	500,000.00
# 2019-12-16 14:56:20.211539	结束资金：	816,321.39
# 2019-12-16 14:56:20.211539	总收益率：	63.26%
# 2019-12-16 14:56:20.211539	年化收益：	16.83%
# 2019-12-16 14:56:20.211539	最大回撤: 	-43,387.15
# 2019-12-16 14:56:20.211539	百分比最大回撤: -7.79%
# 2019-12-16 14:56:20.211539	最长回撤天数: 	49
# 2019-12-16 14:56:20.211539	总盈亏：	316,321.39
# 2019-12-16 14:56:20.211539	总手续费：	32,338.61
# 2019-12-16 14:56:20.211539	总滑点：	86,280.00
# 2019-12-16 14:56:20.211539	总成交金额：	1,077,953,700.00
# 2019-12-16 14:56:20.211539	总成交笔数：	1438
# 2019-12-16 14:56:20.211539	日均盈亏：	350.69
# 2019-12-16 14:56:20.211539	日均手续费：	35.85
# 2019-12-16 14:56:20.211539	日均滑点：	95.65
# 2019-12-16 14:56:20.211539	日均成交金额：	1,195,070.62
# 2019-12-16 14:56:20.211539	日均成交笔数：	1.5942350332594235
# 2019-12-16 14:56:20.211539	日均收益率：	0.05%
# 2019-12-16 14:56:20.211539	收益标准差：	0.60%
# 2019-12-16 14:56:20.211539	Sharpe Ratio：	1.40
# 2019-12-16 14:56:20.211539	收益回撤比：	8.12

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
#setting.add_parameter("atr_stop", 3, 6, 0.5) # 4
#setting.add_parameter("trailing_short", 0.3, 0.6, 0.05) # 0.4
#setting.add_parameter("trailing_long", 0.3, 0.6, 0.05) # 0.4
setting.add_parameter("atr_window", 20, 60, 4) # 44
setting.add_parameter("atr_ma_len", 16, 40, 2) # 22

engine2.run_optimization(setting)
# Out:
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 16}, 目标：1.4352150721685117
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 32}, 目标：1.434102184137379
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 34}, 目标：1.4139702801845824
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 40}, 目标：1.3971258848660566
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 38}, 目标：1.3905074505785386
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 38}, 目标：1.3702499365892344
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 40}, 目标：1.364750902491683
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 38}, 目标：1.3628886023841191
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 38}, 目标：1.3581196744008468
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 36}, 目标：1.3581051774668824
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 18}, 目标：1.354321748458312
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 40}, 目标：1.3522590525743277
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 40}, 目标：1.351987204186694
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 16}, 目标：1.3466168596572936
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 40}, 目标：1.3435953045566529
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 38}, 目标：1.3359506613953045
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 20}, 目标：1.334895017219982
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 22}, 目标：1.3340572213212853
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 26}, 目标：1.329201615880061
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 18}, 目标：1.3208531347050896
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 34}, 目标：1.3196718183647909
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 32}, 目标：1.3148201601012595
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 36}, 目标：1.3143068008788616
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 36}, 目标：1.3082223353474187
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 36}, 目标：1.3070478117495554
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 34}, 目标：1.3068775759458102
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 34}, 目标：1.3061289973050922
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 34}, 目标：1.303326538207579
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 30}, 目标：1.2993163995149517
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 18}, 目标：1.2980663922630302
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 30}, 目标：1.297645854762482
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 16}, 目标：1.2970646524473046
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 40}, 目标：1.2953462369796027
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 24}, 目标：1.295183846834247
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 38}, 目标：1.2949583120937822
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 18}, 目标：1.2935381551247664
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 30}, 目标：1.2901696700887346
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 22}, 目标：1.2898162806646734
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 28}, 目标：1.2894220642298104
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 40}, 目标：1.2885009142430266
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 40}, 目标：1.287222874061376
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 40}, 目标：1.2857312450058036
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 20}, 目标：1.285005250432953
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 18}, 目标：1.2839696279559578
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 32}, 目标：1.2838537554031708
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 34}, 目标：1.2838507061616529
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 28}, 目标：1.2828045385254159
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 28}, 目标：1.282001457854559
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 30}, 目标：1.2812717169102055
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 32}, 目标：1.281259183302744
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 30}, 目标：1.2788923648253079
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 28}, 目标：1.2765546792847697
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 16}, 目标：1.2746982668960176
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 24}, 目标：1.2715598171410347
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 36}, 目标：1.2696089897347618
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 30}, 目标：1.2684471418234873
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 32}, 目标：1.2665993385244187
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 16}, 目标：1.2658085436142719
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 24}, 目标：1.264415446218874
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 18}, 目标：1.2640558302184037
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 28}, 目标：1.263817190561788
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 24}, 目标：1.2614217523425912
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 26}, 目标：1.2604142451263332
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 26}, 目标：1.2593924800720007
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 28}, 目标：1.259071564155561
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 22}, 目标：1.258250471221515
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 32}, 目标：1.257911571408565
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 40}, 目标：1.2572542751884734
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 38}, 目标：1.257121457337836
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 32}, 目标：1.256412311890818
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 16}, 目标：1.2555496984683208
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 26}, 目标：1.255533575816781
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 26}, 目标：1.253726170330231
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 30}, 目标：1.2535584544874603
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 24}, 目标：1.2505111276888172
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 26}, 目标：1.2504346206541155
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 26}, 目标：1.2501195832054752
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 28}, 目标：1.2470339708739666
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 36}, 目标：1.2468280198123
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 16}, 目标：1.2466768046282883
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 34}, 目标：1.2465230352292822
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 28}, 目标：1.245738574535005
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 26}, 目标：1.2445682839349663
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 32}, 目标：1.2415619938303522
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 30}, 目标：1.2415526071707583
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 28}, 目标：1.2405924225863847
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 24}, 目标：1.2390844741469953
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 36}, 目标：1.238115910366538
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 24}, 目标：1.2372178678970989
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 38}, 目标：1.2367559073997152
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 32}, 目标：1.2350251121011873
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 20}, 目标：1.2341679694463166
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 30}, 目标：1.2340291995103159
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 22}, 目标：1.2324689108160685
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 36}, 目标：1.2317915028408915
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 26}, 目标：1.2315820161900695
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 28}, 目标：1.2313161850807115
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 24}, 目标：1.228309610780294
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 34}, 目标：1.2262922976841417
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 38}, 目标：1.2260027209046636
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 32}, 目标：1.2251117657307955
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 40}, 目标：1.225099352965862
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 32}, 目标：1.2211217730116324
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 16}, 目标：1.220818442091344
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 26}, 目标：1.2121298624576051
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 22}, 目标：1.2097225991909144
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 16}, 目标：1.2077867860445464
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 36}, 目标：1.2073262009047505
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 38}, 目标：1.2061579457784752
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 20}, 目标：1.2037130699066818
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 34}, 目标：1.2033069111887558
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 34}, 目标：1.2028592982381312
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 30}, 目标：1.2024448815720155
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 16}, 目标：1.197382859130929
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 20}, 目标：1.1968238539141591
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 26}, 目标：1.1961070395469469
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 40, 'atr_ma_len': 20}, 目标：1.1935755891532736
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 32, 'atr_ma_len': 22}, 目标：1.192441478765035
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 24}, 目标：1.191933949141293
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 22}, 目标：1.191498489571238
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 28}, 目标：1.1908114671527374
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 34}, 目标：1.1895661974842207
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 22}, 目标：1.1878733356356073
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 20}, 目标：1.1847243833074466
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 36}, 目标：1.1806703140138821
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 22}, 目标：1.1799819276751318
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 22}, 目标：1.1739555539823323
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 38}, 目标：1.1709017218774198
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 30}, 目标：1.1695049524094758
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 24, 'atr_ma_len': 24}, 目标：1.167735092241468
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 20, 'atr_ma_len': 36}, 目标：1.1606845725472168
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 44, 'atr_ma_len': 18}, 目标：1.1575784042656174
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 20}, 目标：1.1557338266791317
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 36, 'atr_ma_len': 16}, 目标：1.148728091198126
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 18}, 目标：1.1476165478458453
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 48, 'atr_ma_len': 20}, 目标：1.1454120143826803
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 22}, 目标：1.1349783709023278
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 20}, 目标：1.1147327177232487
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 18}, 目标：1.1118591208893946
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 28, 'atr_ma_len': 24}, 目标：1.1073061113728793
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 52, 'atr_ma_len': 20}, 目标：1.1059072817752214
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 56, 'atr_ma_len': 18}, 目标：1.1023273719191053
# 2019-12-16 15:00:14.392390	参数：{'atr_window': 60, 'atr_ma_len': 18}, 目标：1.0759144264198126
# [("{'atr_window': 24, 'atr_ma_len': 16}",
#   1.4352150721685117,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 202,
#    'loss_days': 207,
#    'capital': 500000,
#    'end_balance': 777849.7363999975,
#    'max_drawdown': -43131.77880000061,
#    'max_ddpercent': -7.692050223861405,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 277849.73639999767,
#    'daily_net_pnl': 308.0374017738333,
#    'total_commission': 32230.2636,
#    'daily_commission': 35.73199955654102,
#    'total_slippage': 85920.0,
#    'daily_slippage': 95.2549889135255,
#    'total_turnover': 1074342120.0,
#    'daily_turnover': 1191066.6518847006,
#    'total_trade_count': 1432,
#    'daily_trade_count': 1.5875831485587584,
#    'total_return': 55.56994727999949,
#    'annual_return': 14.785795285143989,
#    'daily_return': 0.04854140921686434,
#    'return_std': 0.5239634759807799,
#    'sharpe_ratio': 1.4352150721685117,
#    'return_drawdown_ratio': 7.224334951378334}),
#  ("{'atr_window': 28, 'atr_ma_len': 32}",
#   1.434102184137379,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 775079.8927999984,
#    'max_drawdown': -25140.243600000395,
#    'max_ddpercent': -4.449706259806321,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 275079.89279999817,
#    'daily_net_pnl': 304.966621729488,
#    'total_commission': 31040.1072,
#    'daily_commission': 34.41253569844789,
#    'total_slippage': 83040.0,
#    'daily_slippage': 92.06208425720621,
#    'total_turnover': 1034670240.0,
#    'daily_turnover': 1147084.5232815964,
#    'total_trade_count': 1384,
#    'daily_trade_count': 1.5343680709534369,
#    'total_return': 55.01597855999969,
#    'annual_return': 14.638397843015438,
#    'daily_return': 0.04777556887546098,
#    'return_std': 0.516097066602112,
#    'sharpe_ratio': 1.434102184137379,
#    'return_drawdown_ratio': 12.36395738230018}),
#  ("{'atr_window': 28, 'atr_ma_len': 34}",
#   1.4139702801845824,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 772479.1357999984,
#    'max_drawdown': -24486.095400000224,
#    'max_ddpercent': -4.258557014533781,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 272479.1357999983,
#    'daily_net_pnl': 302.08329911308016,
#    'total_commission': 30940.864199999996,
#    'daily_commission': 34.30251019955654,
#    'total_slippage': 82800.0,
#    'daily_slippage': 91.7960088691796,
#    'total_turnover': 1031362140.0,
#    'daily_turnover': 1143417.0066518846,
#    'total_trade_count': 1380,
#    'daily_trade_count': 1.5299334811529934,
#    'total_return': 54.49582715999968,
#    'annual_return': 14.499998357427852,
#    'daily_return': 0.04740294007390324,
#    'return_std': 0.5193625355223991,
#    'sharpe_ratio': 1.4139702801845824,
#    'return_drawdown_ratio': 12.7967823312014}),
#  ("{'atr_window': 60, 'atr_ma_len': 40}",
#   1.3971258848660566,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 208,
#    'loss_days': 209,
#    'capital': 500000,
#    'end_balance': 770848.5157999983,
#    'max_drawdown': -22961.68800000043,
#    'max_ddpercent': -4.1210069496588995,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 270848.5157999984,
#    'daily_net_pnl': 300.2755164079805,
#    'total_commission': 31131.4842,
#    'daily_commission': 34.513840576496676,
#    'total_slippage': 83160.0,
#    'daily_slippage': 92.1951219512195,
#    'total_turnover': 1037716140.0,
#    'daily_turnover': 1150461.3525498891,
#    'total_trade_count': 1386,
#    'daily_trade_count': 1.5365853658536586,
#    'total_return': 54.16970315999967,
#    'annual_return': 14.41322478758306,
#    'daily_return': 0.047168669227279775,
#    'return_std': 0.5230265142429448,
#    'sharpe_ratio': 1.3971258848660566,
#    'return_drawdown_ratio': 13.144773552125011}),
#  ("{'atr_window': 56, 'atr_ma_len': 38}",
#   1.3905074505785386,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 205,
#    'loss_days': 212,
#    'capital': 500000,
#    'end_balance': 779981.0023999984,
#    'max_drawdown': -21409.770000000135,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 42,
#    'total_net_pnl': 279981.00239999837,
#    'daily_net_pnl': 310.4002243902421,
#    'total_commission': 31298.9976,
#    'daily_commission': 34.69955388026607,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043299920.0,
#    'daily_turnover': 1156651.796008869,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 55.99620047999967,
#    'annual_return': 14.89921077073162,
#    'daily_return': 0.048474399470308245,
#    'return_std': 0.5400633899165304,
#    'sharpe_ratio': 1.3905074505785386,
#    'return_drawdown_ratio': 14.99845037915169}),
#  ("{'atr_window': 60, 'atr_ma_len': 38}",
#   1.3702499365892344,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 205,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 775379.6167999981,
#    'max_drawdown': -21409.770000000135,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 42,
#    'total_net_pnl': 275379.616799998,
#    'daily_net_pnl': 305.2989099778248,
#    'total_commission': 31340.383199999997,
#    'daily_commission': 34.74543592017738,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044679440.0,
#    'daily_turnover': 1158181.197339246,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 55.07592335999962,
#    'annual_return': 14.654347678935599,
#    'daily_return': 0.047818432071876894,
#    'return_std': 0.5406312705757067,
#    'sharpe_ratio': 1.3702499365892344,
#    'return_drawdown_ratio': 14.75195632060714}),
#  ("{'atr_window': 48, 'atr_ma_len': 40}",
#   1.364750902491683,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 773580.5491999986,
#    'max_drawdown': -21972.221400000504,
#    'max_ddpercent': -3.7334657290886613,
#    'max_drawdown_duration': 53,
#    'total_net_pnl': 273580.54919999855,
#    'daily_net_pnl': 303.3043782705084,
#    'total_commission': 31339.4508,
#    'daily_commission': 34.7444022172949,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044648360.0,
#    'daily_turnover': 1158146.7405764966,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 54.716109839999724,
#    'annual_return': 14.558610156984406,
#    'daily_return': 0.04756090025821571,
#    'return_std': 0.5398862878035694,
#    'sharpe_ratio': 1.364750902491683,
#    'return_drawdown_ratio': 14.65558111694678}),
#  ("{'atr_window': 24, 'atr_ma_len': 38}",
#   1.3628886023841191,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 764034.1375999982,
#    'max_drawdown': -28846.98780000047,
#    'max_ddpercent': -5.13194054833354,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 264034.13759999804,
#    'daily_net_pnl': 292.720773392459,
#    'total_commission': 31165.862399999998,
#    'daily_commission': 34.551953880266076,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1038862080.0,
#    'daily_turnover': 1151731.796008869,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 52.80682751999963,
#    'annual_return': 14.050597122838038,
#    'daily_return': 0.04618425616667195,
#    'return_std': 0.5249757160712812,
#    'sharpe_ratio': 1.3628886023841191,
#    'return_drawdown_ratio': 10.28983617847}),
#  ("{'atr_window': 52, 'atr_ma_len': 38}",
#   1.3581196744008468,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 760650.295999998,
#    'max_drawdown': -22362.922800000524,
#    'max_ddpercent': -4.011816576618695,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 260650.29599999805,
#    'daily_net_pnl': 288.96928603104,
#    'total_commission': 31309.703999999998,
#    'daily_commission': 34.71142350332594,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043656800.0,
#    'daily_turnover': 1157047.4501108648,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 52.1300591999996,
#    'annual_return': 13.870525729489916,
#    'daily_return': 0.045692155186531705,
#    'return_std': 0.5212057800954328,
#    'sharpe_ratio': 1.3581196744008468,
#    'return_drawdown_ratio': 12.994128271920326}),
#  ("{'atr_window': 60, 'atr_ma_len': 36}",
#   1.3581051774668824,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 773453.2483999981,
#    'max_drawdown': -21732.21420000051,
#    'max_ddpercent': -3.7487631089390607,
#    'max_drawdown_duration': 53,
#    'total_net_pnl': 273453.24839999794,
#    'daily_net_pnl': 303.1632465631906,
#    'total_commission': 31346.7516,
#    'daily_commission': 34.752496230598666,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044891720.0,
#    'daily_turnover': 1158416.5410199556,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 54.690649679999616,
#    'annual_return': 14.551835835033158,
#    'daily_return': 0.0475426547993439,
#    'return_std': 0.5423200303699222,
#    'sharpe_ratio': 1.3581051774668824,
#    'return_drawdown_ratio': 14.58898524411633}),
#  ("{'atr_window': 20, 'atr_ma_len': 18}",
#   1.354321748458312,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 202,
#    'capital': 500000,
#    'end_balance': 769860.0313999974,
#    'max_drawdown': -59451.89400000067,
#    'max_ddpercent': -10.6653337685738,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 269860.0313999973,
#    'daily_net_pnl': 299.1796356984449,
#    'total_commission': 31759.9686,
#    'daily_commission': 35.21060820399113,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1058665620.0,
#    'daily_turnover': 1173686.9401330377,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 53.972006279999476,
#    'annual_return': 14.36062251352536,
#    'daily_return': 0.04739677022255856,
#    'return_std': 0.542166296731044,
#    'sharpe_ratio': 1.354321748458312,
#    'return_drawdown_ratio': 5.060507945755248}),
#  ("{'atr_window': 44, 'atr_ma_len': 40}",
#   1.3522590525743277,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 759842.0305999981,
#    'max_drawdown': -24943.702200000524,
#    'max_ddpercent': -4.474797809890931,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 259842.03059999808,
#    'daily_net_pnl': 288.07320465631716,
#    'total_commission': 31337.969399999994,
#    'daily_commission': 34.7427598669623,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1044598980.0,
#    'daily_turnover': 1158091.9955654102,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 51.96840611999962,
#    'annual_return': 13.827513823503224,
#    'daily_return': 0.0455742879084862,
#    'return_std': 0.5221143323057983,
#    'sharpe_ratio': 1.3522590525743277,
#    'return_drawdown_ratio': 11.61357637324541}),
#  ("{'atr_window': 56, 'atr_ma_len': 40}",
#   1.351987204186694,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 761788.0903999986,
#    'max_drawdown': -22961.68800000043,
#    'max_ddpercent': -4.119232596266269,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 261788.0903999986,
#    'daily_net_pnl': 290.230698891351,
#    'total_commission': 31251.909599999995,
#    'daily_commission': 34.64734988913525,
#    'total_slippage': 83520.0,
#    'daily_slippage': 92.59423503325942,
#    'total_turnover': 1041730320.0,
#    'daily_turnover': 1154911.6629711753,
#    'total_trade_count': 1392,
#    'daily_trade_count': 1.5432372505543237,
#    'total_return': 52.357618079999725,
#    'annual_return': 13.931073546784848,
#    'daily_return': 0.0458578647622265,
#    'return_std': 0.5254687203155207,
#    'sharpe_ratio': 1.351987204186694,
#    'return_drawdown_ratio': 12.71052722962462}),
#  ("{'atr_window': 20, 'atr_ma_len': 16}",
#   1.3466168596572936,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 201,
#    'loss_days': 206,
#    'capital': 500000,
#    'end_balance': 763637.8339999972,
#    'max_drawdown': -48891.138000000676,
#    'max_ddpercent': -8.690333205112577,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 263637.83399999724,
#    'daily_net_pnl': 292.28141241684835,
#    'total_commission': 32162.165999999994,
#    'daily_commission': 35.656503325942346,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1072072200.0,
#    'daily_turnover': 1188550.110864745,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 52.72756679999944,
#    'annual_return': 14.029507796008719,
#    'daily_return': 0.0464970935690945,
#    'return_std': 0.5349182070569974,
#    'sharpe_ratio': 1.3466168596572936,
#    'return_drawdown_ratio': 6.067381486475051}),
#  ("{'atr_window': 52, 'atr_ma_len': 40}",
#   1.3435953045566529,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 758690.5081999983,
#    'max_drawdown': -21701.72580000048,
#    'max_ddpercent': -3.893200548260779,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 258690.50819999815,
#    'daily_net_pnl': 286.7965722838117,
#    'total_commission': 31289.491799999996,
#    'daily_commission': 34.689015299334805,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1042983060.0,
#    'daily_turnover': 1156300.509977827,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 51.738101639999655,
#    'annual_return': 13.766235469622968,
#    'daily_return': 0.045406147604002633,
#    'return_std': 0.5235423282273698,
#    'sharpe_ratio': 1.3435953045566529,
#    'return_drawdown_ratio': 13.289349212465504}),
#  ("{'atr_window': 48, 'atr_ma_len': 38}",
#   1.3359506613953045,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 756404.4895999985,
#    'max_drawdown': -24943.702200000524,
#    'max_ddpercent': -4.474797809890931,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 256404.48959999846,
#    'daily_net_pnl': 284.262183592016,
#    'total_commission': 31355.5104,
#    'daily_commission': 34.762206651884696,
#    'total_slippage': 83760.0,
#    'daily_slippage': 92.86031042128603,
#    'total_turnover': 1045183680.0,
#    'daily_turnover': 1158740.22172949,
#    'total_trade_count': 1396,
#    'daily_trade_count': 1.5476718403547671,
#    'total_return': 51.2808979199997,
#    'annual_return': 13.644584812416772,
#    'daily_return': 0.04507159556354149,
#    'return_std': 0.5226586401694665,
#    'sharpe_ratio': 1.3359506613953045,
#    'return_drawdown_ratio': 11.459936314139215}),
#  ("{'atr_window': 24, 'atr_ma_len': 20}",
#   1.334895017219982,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 208,
#    'capital': 500000,
#    'end_balance': 759524.0749999976,
#    'max_drawdown': -39460.58820000052,
#    'max_ddpercent': -7.134325428349536,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 259524.07499999757,
#    'daily_net_pnl': 287.7207039911281,
#    'total_commission': 31655.925,
#    'daily_commission': 35.095260532150775,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1055197500.0,
#    'daily_turnover': 1169842.0177383593,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 51.90481499999953,
#    'annual_return': 13.810593791574155,
#    'daily_return': 0.04589824462363056,
#    'return_std': 0.5326655197730237,
#    'sharpe_ratio': 1.334895017219982,
#    'return_drawdown_ratio': 7.2753640861049504}),
#  ("{'atr_window': 20, 'atr_ma_len': 22}",
#   1.3340572213212853,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 207,
#    'capital': 500000,
#    'end_balance': 760508.0149999975,
#    'max_drawdown': -42341.29020000063,
#    'max_ddpercent': -7.655145478621818,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 260508.01499999734,
#    'daily_net_pnl': 288.81154656318995,
#    'total_commission': 31631.984999999997,
#    'daily_commission': 35.068719512195116,
#    'total_slippage': 84480.0,
#    'daily_slippage': 93.65853658536585,
#    'total_turnover': 1054399500.0,
#    'daily_turnover': 1168957.3170731708,
#    'total_trade_count': 1408,
#    'daily_trade_count': 1.5609756097560976,
#    'total_return': 52.101602999999486,
#    'annual_return': 13.862954235033122,
#    'daily_return': 0.046041773530894975,
#    'return_std': 0.5346667871964228,
#    'sharpe_ratio': 1.3340572213212853,
#    'return_drawdown_ratio': 6.806089204379107}),
#  ("{'atr_window': 32, 'atr_ma_len': 26}",
#   1.329201615880061,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 767009.2645999973,
#    'max_drawdown': -29881.455000000657,
#    'max_ddpercent': -5.403664886979857,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 267009.2645999973,
#    'daily_net_pnl': 296.0191403547642,
#    'total_commission': 31130.735399999998,
#    'daily_commission': 34.513010421286026,
#    'total_slippage': 83280.0,
#    'daily_slippage': 92.32815964523282,
#    'total_turnover': 1037691180.0,
#    'daily_turnover': 1150433.6807095343,
#    'total_trade_count': 1388,
#    'daily_trade_count': 1.5388026607538803,
#    'total_return': 53.401852919999456,
#    'annual_return': 14.20891873702868,
#    'daily_return': 0.04661512195521271,
#    'return_std': 0.5433023518992091,
#    'sharpe_ratio': 1.329201615880061,
#    'return_drawdown_ratio': 9.882524922792927}),
#  ("{'atr_window': 40, 'atr_ma_len': 18}",
#   1.3208531347050896,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 210,
#    'capital': 500000,
#    'end_balance': 757560.4807999978,
#    'max_drawdown': -50130.12600000069,
#    'max_ddpercent': -8.92397763310703,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 257560.48079999775,
#    'daily_net_pnl': 285.54377028824587,
#    'total_commission': 31879.5192,
#    'daily_commission': 35.343147671840356,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062650640.0,
#    'daily_turnover': 1178104.9223946785,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 51.512096159999565,
#    'annual_return': 13.706100973835806,
#    'daily_return': 0.04524089762407134,
#    'return_std': 0.5306183964339812,
#    'sharpe_ratio': 1.3208531347050896,
#    'return_drawdown_ratio': 5.772324660350451}),
#  ("{'atr_window': 24, 'atr_ma_len': 34}",
#   1.3196718183647909,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 754403.545399998,
#    'max_drawdown': -28486.861800000304,
#    'max_ddpercent': -5.04204212538724,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 254403.54539999788,
#    'daily_net_pnl': 282.04384190687125,
#    'total_commission': 31256.454599999997,
#    'daily_commission': 34.652388691796006,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1041881820.0,
#    'daily_turnover': 1155079.623059867,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.8807090799996,
#    'annual_return': 13.538104411529826,
#    'daily_return': 0.044777932446744564,
#    'return_std': 0.5256585288264558,
#    'sharpe_ratio': 1.3196718183647909,
#    'return_drawdown_ratio': 10.091289960432817}),
#  ("{'atr_window': 32, 'atr_ma_len': 32}",
#   1.3148201601012595,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 754223.5249999983,
#    'max_drawdown': -26520.42540000053,
#    'max_ddpercent': -4.723088253090257,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 254223.52499999816,
#    'daily_net_pnl': 281.84426274944366,
#    'total_commission': 31196.475,
#    'daily_commission': 34.58589246119734,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1039882500.0,
#    'daily_turnover': 1152863.0820399113,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.84470499999965,
#    'annual_return': 13.5285246119733,
#    'daily_return': 0.04475147406451193,
#    'return_std': 0.5272864503590808,
#    'sharpe_ratio': 1.3148201601012595,
#    'return_drawdown_ratio': 10.765139729653072}),
#  ("{'atr_window': 52, 'atr_ma_len': 36}",
#   1.3143068008788616,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 752489.5975999981,
#    'max_drawdown': -27463.62660000054,
#    'max_ddpercent': -4.95405809512727,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252489.59759999806,
#    'daily_net_pnl': 279.9219485587562,
#    'total_commission': 31310.4024,
#    'daily_commission': 34.7121977827051,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043680080.0,
#    'daily_turnover': 1157073.2594235034,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.49791951999963,
#    'annual_return': 13.4362535308203,
#    'daily_return': 0.04449630736947833,
#    'return_std': 0.5244847163370944,
#    'sharpe_ratio': 1.3143068008788616,
#    'return_drawdown_ratio': 10.193243306869684}),
#  ("{'atr_window': 56, 'atr_ma_len': 36}",
#   1.3082223353474187,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 203,
#    'loss_days': 214,
#    'capital': 500000,
#    'end_balance': 751049.5507999983,
#    'max_drawdown': -27463.62660000054,
#    'max_ddpercent': -4.947632015161298,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 251049.55079999828,
#    'daily_net_pnl': 278.3254443458961,
#    'total_commission': 31310.4492,
#    'daily_commission': 34.712249667405764,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043681640.0,
#    'daily_turnover': 1157074.9889135256,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.20991015999967,
#    'annual_return': 13.359621328603017,
#    'daily_return': 0.04428394113974205,
#    'return_std': 0.5244092289346308,
#    'sharpe_ratio': 1.3082223353474187,
#    'return_drawdown_ratio': 10.148270931657551}),
#  ("{'atr_window': 28, 'atr_ma_len': 36}",
#   1.3070478117495554,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 752372.2639999983,
#    'max_drawdown': -27780.38760000025,
#    'max_ddpercent': -4.980464908122983,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252372.26399999828,
#    'daily_net_pnl': 279.7918669623041,
#    'total_commission': 31187.735999999997,
#    'daily_commission': 34.57620399113082,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1039591200.0,
#    'daily_turnover': 1152540.133037694,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.47445279999967,
#    'annual_return': 13.430009614190599,
#    'daily_return': 0.04447901919173455,
#    'return_std': 0.5271926521330228,
#    'sharpe_ratio': 1.3070478117495554,
#    'return_drawdown_ratio': 10.134486183745098}),
#  ("{'atr_window': 32, 'atr_ma_len': 34}",
#   1.3068775759458102,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 198,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 750691.0357999986,
#    'max_drawdown': -27780.387600000366,
#    'max_ddpercent': -4.9474780423338665,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 250691.03579999847,
#    'daily_net_pnl': 277.9279776053198,
#    'total_commission': 31128.964200000002,
#    'daily_commission': 34.5110467849224,
#    'total_slippage': 83280.0,
#    'daily_slippage': 92.32815964523282,
#    'total_turnover': 1037632140.0,
#    'daily_turnover': 1150368.2261640797,
#    'total_trade_count': 1388,
#    'daily_trade_count': 1.5388026607538803,
#    'total_return': 50.1382071599997,
#    'annual_return': 13.340542925055352,
#    'daily_return': 0.04423100699763072,
#    'return_std': 0.5243213492704712,
#    'sharpe_ratio': 1.3068775759458102,
#    'return_drawdown_ratio': 10.134093922395273}),
#  ("{'atr_window': 60, 'atr_ma_len': 34}",
#   1.3061289973050922,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 204,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 753989.1709999982,
#    'max_drawdown': -29683.909200000577,
#    'max_ddpercent': -5.354566343662814,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 253989.1709999982,
#    'daily_net_pnl': 281.5844467849204,
#    'total_commission': 31310.828999999998,
#    'daily_commission': 34.71267073170731,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1043694300.0,
#    'daily_turnover': 1157089.024390244,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.797834199999635,
#    'annual_return': 13.516053445676178,
#    'daily_return': 0.044717020572998305,
#    'return_std': 0.530386436036785,
#    'sharpe_ratio': 1.3061289973050922,
#    'return_drawdown_ratio': 9.486825064763538}),
#  ("{'atr_window': 36, 'atr_ma_len': 34}",
#   1.303326538207579,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 222,
#    'capital': 500000,
#    'end_balance': 750145.899199998,
#    'max_drawdown': -26760.418200000422,
#    'max_ddpercent': -4.758202336164025,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 250145.89919999812,
#    'daily_net_pnl': 277.32361330376733,
#    'total_commission': 31374.1008,
#    'daily_commission': 34.78281685144124,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1045803360.0,
#    'daily_turnover': 1159427.2283813746,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
#    'total_return': 50.02917983999959,
#    'annual_return': 13.311533438580822,
#    'daily_return': 0.04415047002335509,
#    'return_std': 0.5247926137155049,
#    'sharpe_ratio': 1.303326538207579,
#    'return_drawdown_ratio': 10.514302735669746}),
#  ("{'atr_window': 60, 'atr_ma_len': 30}",
#   1.2993163995149517,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 202,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 752644.5751999983,
#    'max_drawdown': -29320.27020000061,
#    'max_ddpercent': -5.237959869233035,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': 252644.57519999827,
#    'daily_net_pnl': 280.0937640798207,
#    'total_commission': 31275.424799999997,
#    'daily_commission': 34.6734199556541,
#    'total_slippage': 83640.0,
#    'daily_slippage': 92.72727272727273,
#    'total_turnover': 1042514160.0,
#    'daily_turnover': 1155780.6651884702,
#    'total_trade_count': 1394,
#    'daily_trade_count': 1.5454545454545454,
#    'total_return': 50.52891503999965,
#    'annual_return': 13.444500675831394,
#    'daily_return': 0.04451913796156451,
#    'return_std': 0.530807984804984,
#    'sharpe_ratio': 1.2993163995149517,
#    'return_drawdown_ratio': 9.646678535434889}),
#  ("{'atr_window': 24, 'atr_ma_len': 18}",
#   1.2980663922630302,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 210,
#    'capital': 500000,
#    'end_balance': 752580.1909999975,
#    'max_drawdown': -48952.39260000066,
#    'max_ddpercent': -8.802651560363723,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252580.19099999728,
#    'daily_net_pnl': 280.0223847006622,
#    'total_commission': 31879.808999999994,
#    'daily_commission': 35.34346895787139,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062660300.0,
#    'daily_turnover': 1178115.6319290465,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 50.5160381999995,
#    'annual_return': 13.441074465631797,
#    'daily_return': 0.04488001147938836,
#    'return_std': 0.5356260298342194,
#    'sharpe_ratio': 1.2980663922630302,
#    'return_drawdown_ratio': 5.738729728603752}),
#  ("{'atr_window': 28, 'atr_ma_len': 30}",
#   1.297645854762482,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 199,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 752944.3633999976,
#    'max_drawdown': -28500.049200000474,
#    'max_ddpercent': -5.125488492110252,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 252944.36339999767,
#    'daily_net_pnl': 280.42612350332337,
#    'total_commission': 31155.636599999998,
#    'daily_commission': 34.54061707317073,
#    'total_slippage': 83400.0,
#    'daily_slippage': 92.46119733924613,
#    'total_turnover': 1038521220.0,
#    'daily_turnover': 1151353.9024390243,
#    'total_trade_count': 1390,
#    'daily_trade_count': 1.541019955654102,
#    'total_return': 50.58887267999952,
#    'annual_return': 13.460453928159517,
#    'daily_return': 0.04456328805052636,
#    'return_std': 0.5320184142337466,
#    'sharpe_ratio': 1.297645854762482,
#    'return_drawdown_ratio': 9.870058777396885}),
#  ("{'atr_window': 28, 'atr_ma_len': 16}",
#   1.2970646524473046,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 751715.6203999978,
#    'max_drawdown': -47392.497000000556,
#    'max_ddpercent': -8.588832048367117,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 251715.62039999777,
#    'daily_net_pnl': 279.0638807095319,
#    'total_commission': 32204.3796,
#    'daily_commission': 35.70330332594235,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1073479320.0,
#    'daily_turnover': 1190110.110864745,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 50.34312407999957,
#    'annual_return': 13.395066274057536,
#    'daily_return': 0.04475257589266368,
#    'return_std': 0.5345176304207755,
#    'sharpe_ratio': 1.2970646524473046,
#    'return_drawdown_ratio': 5.861463327783975}),
#  ("{'atr_window': 32, 'atr_ma_len': 40}",
#   1.2953462369796027,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 753917.527399998,
#    'max_drawdown': -30955.38480000035,
#    'max_ddpercent': -5.533020540821168,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 253917.52739999813,
#    'daily_net_pnl': 281.50501929046357,
#    'total_commission': 31382.472599999997,
#    'daily_commission': 34.79209822616408,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1046082420.0,
#    'daily_turnover': 1159736.6075388025,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
#    'total_return': 50.78350547999961,
#    'annual_return': 13.512240925942248,
#    'daily_return': 0.0447064857707322,
#    'return_std': 0.5346755019298556,
#    'sharpe_ratio': 1.2953462369796027,
#    'return_drawdown_ratio': 9.178260789984835}),
#  ("{'atr_window': 20, 'atr_ma_len': 24}",
#   1.295183846834247,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 212,
#    'capital': 500000,
#    'end_balance': 754436.6233999974,
#    'max_drawdown': -35124.94319999986,
#    'max_ddpercent': -5.564454374446332,
#    'max_drawdown_duration': 92,
#    'total_net_pnl': 254436.62339999725,
#    'daily_net_pnl': 282.0805137472253,
#    'total_commission': 31703.3766,
#    'daily_commission': 35.147867627494456,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1056779220.0,
#    'daily_turnover': 1171595.5875831486,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 50.88732467999948,
#    'annual_return': 13.539864659866824,
#    'daily_return': 0.04478279337782512,
#    'return_std': 0.5356552689346846,
#    'sharpe_ratio': 1.295183846834247,
#    'return_drawdown_ratio': 9.145069984523472}),
#  ("{'atr_window': 28, 'atr_ma_len': 38}",
#   1.2949583120937822,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 749841.5017999981,
#    'max_drawdown': -29220.344400000293,
#    'max_ddpercent': -5.23018844078835,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 249841.501799998,
#    'daily_net_pnl': 276.9861439024368,
#    'total_commission': 31378.498199999995,
#    'daily_commission': 34.78769201773835,
#    'total_slippage': 83880.0,
#    'daily_slippage': 92.99334811529934,
#    'total_turnover': 1045949940.0,
#    'daily_turnover': 1159589.733924612,
#    'total_trade_count': 1398,
#    'daily_trade_count': 1.5498891352549888,
# ...
#    'capital': 500000,
#    'end_balance': 729131.9185999976,
#    'max_drawdown': -31966.872600000526,
#    'max_ddpercent': -5.773263414750239,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 229131.91859999768,
#    'daily_net_pnl': 254.02651729489764,
#    'total_commission': 31568.081399999995,
#    'daily_commission': 34.997872949002215,
#    'total_slippage': 84360.0,
#    'daily_slippage': 93.52549889135256,
#    'total_turnover': 1052269380.0,
#    'daily_turnover': 1166595.7649667405,
#    'total_trade_count': 1406,
#    'daily_trade_count': 1.558758314855876,
#    'total_return': 45.82638371999952,
#    'annual_return': 12.193272830155083,
#    'daily_return': 0.041000464930078265,
#    'return_std': 0.5424677917676795,
#    'sharpe_ratio': 1.1709017218774198,
#    'return_drawdown_ratio': 7.93769146284174}),
#  ("{'atr_window': 24, 'atr_ma_len': 30}",
#   1.1695049524094758,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 196,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 732481.1425999972,
#    'max_drawdown': -31561.393800000602,
#    'max_ddpercent': -5.728595712876029,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 232481.1425999973,
#    'daily_net_pnl': 257.73962594234735,
#    'total_commission': 31458.857399999997,
#    'daily_commission': 34.876782039911305,
#    'total_slippage': 84120.0,
#    'daily_slippage': 93.25942350332595,
#    'total_turnover': 1048628580.0,
#    'daily_turnover': 1162559.401330377,
#    'total_trade_count': 1402,
#    'daily_trade_count': 1.5543237250554325,
#    'total_return': 46.49622851999944,
#    'annual_return': 12.371502045232669,
#    'daily_return': 0.041508549490204584,
#    'return_std': 0.5498460543312058,
#    'sharpe_ratio': 1.1695049524094758,
#    'return_drawdown_ratio': 8.116514212286088}),
#  ("{'atr_window': 24, 'atr_ma_len': 24}",
#   1.167735092241468,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 727039.1359999974,
#    'max_drawdown': -38903.42880000069,
#    'max_ddpercent': -6.466969517876126,
#    'max_drawdown_duration': 149,
#    'total_net_pnl': 227039.13599999715,
#    'daily_net_pnl': 251.70635920177068,
#    'total_commission': 31680.863999999994,
#    'daily_commission': 35.12290909090908,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1056028800.0,
#    'daily_turnover': 1170763.6363636365,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 45.407827199999474,
#    'annual_return': 12.081905241685003,
#    'daily_return': 0.040681799113556134,
#    'return_std': 0.5397112119260619,
#    'sharpe_ratio': 1.167735092241468,
#    'return_drawdown_ratio': 7.021500112917225}),
#  ("{'atr_window': 20, 'atr_ma_len': 36}",
#   1.1606845725472168,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 727953.8869999978,
#    'max_drawdown': -30046.80420000048,
#    'max_ddpercent': -5.466786434566879,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 227953.88699999778,
#    'daily_net_pnl': 252.72049556540773,
#    'total_commission': 31666.112999999998,
#    'daily_commission': 35.1065554323725,
#    'total_slippage': 84600.0,
#    'daily_slippage': 93.79157427937916,
#    'total_turnover': 1055537100.0,
#    'daily_turnover': 1170218.5144124168,
#    'total_trade_count': 1410,
#    'daily_trade_count': 1.5631929046563193,
#    'total_return': 45.59077739999955,
#    'annual_return': 12.130583787139571,
#    'daily_return': 0.0408211999878176,
#    'return_std': 0.5448502770328274,
#    'sharpe_ratio': 1.1606845725472168,
#    'return_drawdown_ratio': 8.339593643484191}),
#  ("{'atr_window': 44, 'atr_ma_len': 18}",
#   1.1575784042656174,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 197,
#    'loss_days': 213,
#    'capital': 500000,
#    'end_balance': 725010.2209999979,
#    'max_drawdown': -49470.15660000057,
#    'max_ddpercent': -8.941164385770962,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 225010.22099999795,
#    'daily_net_pnl': 249.45700776052988,
#    'total_commission': 32089.779,
#    'daily_commission': 35.576251662971174,
#    'total_slippage': 85560.0,
#    'daily_slippage': 94.85587583148559,
#    'total_turnover': 1069659300.0,
#    'daily_turnover': 1185875.0554323725,
#    'total_trade_count': 1426,
#    'daily_trade_count': 1.580931263858093,
#    'total_return': 45.00204419999958,
#    'annual_return': 11.973936372505433,
#    'daily_return': 0.04037198142116664,
#    'return_std': 0.5403003757547479,
#    'sharpe_ratio': 1.1575784042656174,
#    'return_drawdown_ratio': 5.033130167209114}),
#  ("{'atr_window': 60, 'atr_ma_len': 20}",
#   1.1557338266791317,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 731587.4731999976,
#    'max_drawdown': -35929.38120000053,
#    'max_ddpercent': -6.488890420836905,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 231587.47319999756,
#    'daily_net_pnl': 256.7488616407955,
#    'total_commission': 31812.526799999996,
#    'daily_commission': 35.26887671840354,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1060417560.0,
#    'daily_turnover': 1175629.2239467849,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 46.31749463999952,
#    'annual_return': 12.32394535875819,
#    'daily_return': 0.04137320550237356,
#    'return_std': 0.5545835284594364,
#    'sharpe_ratio': 1.1557338266791317,
#    'return_drawdown_ratio': 7.137968379195671}),
#  ("{'atr_window': 36, 'atr_ma_len': 16}",
#   1.148728091198126,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 728270.2495999984,
#    'max_drawdown': -48437.62980000046,
#    'max_ddpercent': -8.844588488217079,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 228270.2495999984,
#    'daily_net_pnl': 253.07123015520887,
#    'total_commission': 32249.750399999997,
#    'daily_commission': 35.75360354767184,
#    'total_slippage': 86040.0,
#    'daily_slippage': 95.3880266075388,
#    'total_turnover': 1074991680.0,
#    'daily_turnover': 1191786.7849223947,
#    'total_trade_count': 1434,
#    'daily_trade_count': 1.58980044345898,
#    'total_return': 45.654049919999665,
#    'annual_return': 12.147419047450022,
#    'daily_return': 0.04086937040149301,
#    'return_std': 0.5511709590730796,
#    'sharpe_ratio': 1.148728091198126,
#    'return_drawdown_ratio': 5.1618059993204675}),
#  ("{'atr_window': 48, 'atr_ma_len': 18}",
#   1.1476165478458453,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 215,
#    'capital': 500000,
#    'end_balance': 725280.6223999986,
#    'max_drawdown': -50497.53120000049,
#    'max_ddpercent': -9.126850581564506,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 225280.62239999865,
#    'daily_net_pnl': 249.75678758314706,
#    'total_commission': 31999.377599999996,
#    'daily_commission': 35.47602838137472,
#    'total_slippage': 85320.0,
#    'daily_slippage': 94.58980044345898,
#    'total_turnover': 1066645920.0,
#    'daily_turnover': 1182534.2793791573,
#    'total_trade_count': 1422,
#    'daily_trade_count': 1.5764966740576496,
#    'total_return': 45.05612447999972,
#    'annual_return': 11.988325803991057,
#    'daily_return': 0.04041332207052059,
#    'return_std': 0.5455485062073804,
#    'sharpe_ratio': 1.1476165478458453,
#    'return_drawdown_ratio': 4.9366563062848225}),
#  ("{'atr_window': 48, 'atr_ma_len': 20}",
#   1.1454120143826803,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 729784.5133999983,
#    'max_drawdown': -33116.47200000059,
#    'max_ddpercent': -6.0636755985153865,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 229784.5133999983,
#    'daily_net_pnl': 254.75001485587396,
#    'total_commission': 31755.486599999997,
#    'daily_commission': 35.20563924611973,
#    'total_slippage': 84720.0,
#    'daily_slippage': 93.92461197339246,
#    'total_turnover': 1058516220.0,
#    'daily_turnover': 1173521.308203991,
#    'total_trade_count': 1412,
#    'daily_trade_count': 1.565410199556541,
#    'total_return': 45.95690267999966,
#    'annual_return': 12.228000713081949,
#    'daily_return': 0.04109964780215551,
#    'return_std': 0.5558812007346637,
#    'sharpe_ratio': 1.1454120143826803,
#    'return_drawdown_ratio': 7.579050352108483}),
#  ("{'atr_window': 28, 'atr_ma_len': 22}",
#   1.1349783709023278,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 192,
#    'loss_days': 217,
#    'capital': 500000,
#    'end_balance': 723268.9567999976,
#    'max_drawdown': -37048.64640000055,
#    'max_ddpercent': -6.770962144324557,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 223268.95679999748,
#    'daily_net_pnl': 247.52655964523004,
#    'total_commission': 31851.0432,
#    'daily_commission': 35.311577827050996,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1061701440.0,
#    'daily_turnover': 1177052.5942350333,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 44.653791359999516,
#    'annual_return': 11.881274862971045,
#    'daily_return': 0.040105396210930816,
#    'return_std': 0.5474202349582996,
#    'sharpe_ratio': 1.1349783709023278,
#    'return_drawdown_ratio': 6.594896029278273}),
#  ("{'atr_window': 56, 'atr_ma_len': 20}",
#   1.1147327177232487,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 722063.614999998,
#    'max_drawdown': -35929.38120000053,
#    'max_ddpercent': -6.488890420836905,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 222063.614999998,
#    'daily_net_pnl': 246.19026053214859,
#    'total_commission': 31916.385,
#    'daily_commission': 35.38401884700665,
#    'total_slippage': 85200.0,
#    'daily_slippage': 94.45676274944567,
#    'total_turnover': 1063879500.0,
#    'daily_turnover': 1179467.2949002218,
#    'total_trade_count': 1420,
#    'daily_trade_count': 1.5742793791574279,
#    'total_return': 44.41272299999961,
#    'annual_return': 11.817132505543134,
#    'daily_return': 0.0399204838317394,
#    'return_std': 0.5547926120573562,
#    'sharpe_ratio': 1.1147327177232487,
#    'return_drawdown_ratio': 6.844424873840214}),
#  ("{'atr_window': 52, 'atr_ma_len': 18}",
#   1.1118591208893946,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 195,
#    'loss_days': 216,
#    'capital': 500000,
#    'end_balance': 718695.5065999983,
#    'max_drawdown': -50497.53120000049,
#    'max_ddpercent': -9.126850581564506,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 218695.5065999983,
#    'daily_net_pnl': 242.45621574279193,
#    'total_commission': 32164.4934,
#    'daily_commission': 35.65908359201774,
#    'total_slippage': 85800.0,
#    'daily_slippage': 95.1219512195122,
#    'total_turnover': 1072149780.0,
#    'daily_turnover': 1188636.1197339245,
#    'total_trade_count': 1430,
#    'daily_trade_count': 1.5853658536585367,
#    'total_return': 43.739101319999676,
#    'annual_return': 11.637898355654016,
#    'daily_return': 0.039402138809928385,
#    'return_std': 0.5490041842485772,
#    'sharpe_ratio': 1.1118591208893946,
#    'return_drawdown_ratio': 4.792354266032261}),
#  ("{'atr_window': 28, 'atr_ma_len': 24}",
#   1.1073061113728793,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 191,
#    'loss_days': 220,
#    'capital': 500000,
#    'end_balance': 719732.7997999975,
#    'max_drawdown': -37048.64640000049,
#    'max_ddpercent': -6.777719445265888,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 219732.79979999742,
#    'daily_net_pnl': 243.60620820398827,
#    'total_commission': 31847.2002,
#    'daily_commission': 35.30731729490022,
#    'total_slippage': 84960.0,
#    'daily_slippage': 94.19068736141907,
#    'total_turnover': 1061573340.0,
#    'daily_turnover': 1176910.576496674,
#    'total_trade_count': 1416,
#    'daily_trade_count': 1.5698447893569845,
#    'total_return': 43.9465599599995,
#    'annual_return': 11.69309799379144,
#    'daily_return': 0.03956203453158815,
#    'return_std': 0.553498619069128,
#    'sharpe_ratio': 1.1073061113728793,
#    'return_drawdown_ratio': 6.48397448653549}),
#  ("{'atr_window': 52, 'atr_ma_len': 20}",
#   1.1059072817752214,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 192,
#    'loss_days': 221,
#    'capital': 500000,
#    'end_balance': 721376.763799998,
#    'max_drawdown': -35929.38120000047,
#    'max_ddpercent': -6.537068477898904,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 221376.76379999807,
#    'daily_net_pnl': 245.42878470066304,
#    'total_commission': 31883.236199999996,
#    'daily_commission': 35.34726851441241,
#    'total_slippage': 85080.0,
#    'daily_slippage': 94.32372505543238,
#    'total_turnover': 1062774540.0,
#    'daily_turnover': 1178242.2838137473,
#    'total_trade_count': 1418,
#    'daily_trade_count': 1.5720620842572062,
#    'total_return': 44.275352759999585,
#    'annual_return': 11.780581665631818,
#    'daily_return': 0.039814975367359,
#    'return_std': 0.557742006291562,
#    'sharpe_ratio': 1.1059072817752214,
#    'return_drawdown_ratio': 6.772967563318265}),
#  ("{'atr_window': 56, 'atr_ma_len': 18}",
#   1.1023273719191053,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 194,
#    'loss_days': 219,
#    'capital': 500000,
#    'end_balance': 716980.9057999982,
#    'max_drawdown': -50497.53120000055,
#    'max_ddpercent': -9.145695115194288,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 216980.90579999826,
#    'daily_net_pnl': 240.5553279379138,
#    'total_commission': 32079.094199999996,
#    'daily_commission': 35.56440598669623,
#    'total_slippage': 85560.0,
#    'daily_slippage': 94.85587583148559,
#    'total_turnover': 1069303140.0,
#    'daily_turnover': 1185480.199556541,
#    'total_trade_count': 1426,
#    'daily_trade_count': 1.580931263858093,
#    'total_return': 43.396181159999635,
#    'annual_return': 11.546655741019858,
#    'daily_return': 0.03913733140733933,
#    'return_std': 0.55002982459461,
#    'sharpe_ratio': 1.1023273719191053,
#    'return_drawdown_ratio': 4.744984455900238}),
#  ("{'atr_window': 60, 'atr_ma_len': 18}",
#   1.0759144264198126,
#   {'start_date': datetime.date(2015, 4, 24),
#    'end_date': datetime.date(2018, 12, 28),
#    'total_days': 902,
#    'profit_days': 193,
#    'loss_days': 220,
#    'capital': 500000,
#    'end_balance': 712583.6449999979,
#    'max_drawdown': -50616.282000000414,
#    'max_ddpercent': -9.16720227773621,
#    'max_drawdown_duration': 95,
#    'total_net_pnl': 212583.64499999792,
#    'daily_net_pnl': 235.680315964521,
#    'total_commission': 32036.354999999996,
#    'daily_commission': 35.51702328159645,
#    'total_slippage': 85440.0,
#    'daily_slippage': 94.72283813747228,
#    'total_turnover': 1067878500.0,
#    'daily_turnover': 1183900.7760532151,
#    'total_trade_count': 1424,
#    'daily_trade_count': 1.5787139689578713,
#    'total_return': 42.516728999999586,
#    'annual_return': 11.312655166297008,
#    'daily_return': 0.03845530171576409,
#    'return_std': 0.5537122264049725,
#    'sharpe_ratio': 1.0759144264198126,
#    'return_drawdown_ratio': 4.6379176232706465})]

# %%
# 样本外。2019
engine2 = BacktestingEngine()
engine2.set_parameters(
    vt_symbol="IH9999.CFFEX",
    interval="1m",
    start=datetime(2014, 1, 1),
    end=datetime(2019, 1, 1),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=500_000,
)
engine2.load_data()
engine2.add_strategy(TSMyoRBKStrategy,{'limited_size':8,'atr_stop': 4, 'atr_window': 24, 'atr_ma_len': 16, 'trailing_short':0.55,'trailing_long':0.55})
engine2.run_backtesting()
df2 = engine2.calculate_result()
engine2.calculate_statistics()
engine2.show_chart()
# Out:
# 2019-12-16 19:56:03.517048	开始加载历史数据
# 2019-12-16 19:56:03.517048	加载进度： [2%]
# 2019-12-16 19:56:03.517048	加载进度： [3%]
# 2019-12-16 19:56:03.517048	加载进度： [5%]
# 2019-12-16 19:56:03.518049	加载进度： [7%]
# 2019-12-16 19:56:03.518049	加载进度： [8%]
# 2019-12-16 19:56:03.518049	加载进度： [10%]
# 2019-12-16 19:56:03.518049	加载进度：# [12%]
# 2019-12-16 19:56:03.518049	加载进度：# [13%]
# 2019-12-16 19:56:03.518049	加载进度：# [15%]
# 2019-12-16 19:56:03.518049	加载进度：# [16%]
# 2019-12-16 19:56:03.518049	加载进度：# [18%]
# 2019-12-16 19:56:03.518049	加载进度：# [20%]
# 2019-12-16 19:56:03.518049	加载进度：## [21%]
# 2019-12-16 19:56:03.518049	加载进度：## [23%]
# 2019-12-16 19:56:03.518049	加载进度：## [25%]
# 2019-12-16 19:56:03.518049	加载进度：## [26%]
# 2019-12-16 19:56:03.518049	加载进度：## [28%]
# 2019-12-16 19:56:03.518049	加载进度：## [30%]
# 2019-12-16 19:56:03.518049	加载进度：### [31%]
# 2019-12-16 19:56:03.518049	加载进度：### [33%]
# 2019-12-16 19:56:03.518049	加载进度：### [35%]
# 2019-12-16 19:56:03.518049	加载进度：### [36%]
# 2019-12-16 19:56:03.518049	加载进度：### [38%]
# 2019-12-16 19:56:03.518049	加载进度：### [39%]
# 2019-12-16 19:56:03.518049	加载进度：#### [41%]
# 2019-12-16 19:56:03.519050	加载进度：#### [43%]
# 2019-12-16 19:56:03.519050	加载进度：#### [44%]
# 2019-12-16 19:56:03.519050	加载进度：#### [46%]
# 2019-12-16 19:56:03.519050	加载进度：#### [48%]
# 2019-12-16 19:56:03.519050	加载进度：#### [49%]
# 2019-12-16 19:56:03.519050	加载进度：##### [51%]
# 2019-12-16 19:56:03.519050	加载进度：##### [53%]
# 2019-12-16 19:56:03.519050	加载进度：##### [54%]
# 2019-12-16 19:56:03.519050	加载进度：##### [56%]
# 2019-12-16 19:56:03.519050	加载进度：##### [58%]
# 2019-12-16 19:56:03.519050	加载进度：##### [59%]
# 2019-12-16 19:56:03.520051	加载进度：###### [61%]
# 2019-12-16 19:56:03.520051	加载进度：###### [62%]
# 2019-12-16 19:56:03.520051	加载进度：###### [64%]
# 2019-12-16 19:56:03.520051	加载进度：###### [66%]
# 2019-12-16 19:56:03.520051	加载进度：###### [67%]
# 2019-12-16 19:56:03.520051	加载进度：###### [69%]
# 2019-12-16 19:56:03.520051	加载进度：####### [71%]
# 2019-12-16 19:56:03.520051	加载进度：####### [72%]
# 2019-12-16 19:56:03.521052	加载进度：####### [74%]
# 2019-12-16 19:56:03.521052	加载进度：####### [76%]
# 2019-12-16 19:56:03.521052	加载进度：####### [77%]
# 2019-12-16 19:56:03.525055	加载进度：####### [79%]
# 2019-12-16 19:56:03.526056	加载进度：######## [81%]
# 2019-12-16 19:56:03.526056	加载进度：######## [82%]
# 2019-12-16 19:56:03.526056	加载进度：######## [84%]
# 2019-12-16 19:56:03.527057	加载进度：######## [85%]
# 2019-12-16 19:56:03.527057	加载进度：######## [87%]
# 2019-12-16 19:56:03.527057	加载进度：######## [89%]
# 2019-12-16 19:56:03.527057	加载进度：######### [90%]
# 2019-12-16 19:56:03.527057	加载进度：######### [92%]
# 2019-12-16 19:56:03.528058	加载进度：######### [94%]
# 2019-12-16 19:56:03.528058	加载进度：######### [95%]
# 2019-12-16 19:56:03.528058	加载进度：######### [97%]
# 2019-12-16 19:56:03.528058	加载进度：######### [99%]
# 2019-12-16 19:56:03.528058	加载进度：########## [100%]
# 2019-12-16 19:56:03.528058	历史数据加载完成，数据量：222960
# 2019-12-16 19:56:03.560795	策略初始化完成
# 2019-12-16 19:56:03.560795	开始回放历史数据
# 2019-12-16 19:56:12.218797	历史数据回放结束
# 2019-12-16 19:56:12.218797	开始计算逐日盯市盈亏
# 2019-12-16 19:56:12.234415	逐日盯市盈亏计算完成
# 2019-12-16 19:56:12.234415	开始计算策略统计指标
# 2019-12-16 19:56:12.234415	------------------------------
# 2019-12-16 19:56:12.234415	首个交易日：	2015-04-24
# 2019-12-16 19:56:12.234415	最后交易日：	2018-12-28
# 2019-12-16 19:56:12.234415	总交易日：	902
# 2019-12-16 19:56:12.234415	盈利交易日：	192
# 2019-12-16 19:56:12.234415	亏损交易日：	217
# 2019-12-16 19:56:12.234415	起始资金：	500,000.00
# 2019-12-16 19:56:12.234415	结束资金：	788,543.70
# 2019-12-16 19:56:12.234415	总收益率：	57.71%
# 2019-12-16 19:56:12.234415	年化收益：	15.35%
# 2019-12-16 19:56:12.234415	最大回撤: 	-51,622.08
# 2019-12-16 19:56:12.234415	百分比最大回撤: -9.44%
# 2019-12-16 19:56:12.234415	最长回撤天数: 	95
# 2019-12-16 19:56:12.234415	总盈亏：	288,543.70
# 2019-12-16 19:56:12.234415	总手续费：	32,816.30
# 2019-12-16 19:56:12.234415	总滑点：	87,360.00
# 2019-12-16 19:56:12.234415	总成交金额：	1,093,876,560.00
# 2019-12-16 19:56:12.234415	总成交笔数：	1456
# 2019-12-16 19:56:12.234415	日均盈亏：	319.89
# 2019-12-16 19:56:12.234415	日均手续费：	36.38
# 2019-12-16 19:56:12.234415	日均滑点：	96.85
# 2019-12-16 19:56:12.234415	日均成交金额：	1,212,723.46
# 2019-12-16 19:56:12.234415	日均成交笔数：	1.6141906873614191
# 2019-12-16 19:56:12.234415	日均收益率：	0.05%
# 2019-12-16 19:56:12.234415	收益标准差：	0.58%
# 2019-12-16 19:56:12.234415	Sharpe Ratio：	1.35
# 2019-12-16 19:56:12.234415	收益回撤比：	6.12
